# %%
#pulled from
#https://github.com/GregBland/yfinance_article/blob/master/example_code.ipynb
import yfinance as yf
import matplotlib.pyplot as plt

import datetime as dt
import datetime

apple = yf.Ticker("aapl")

# show actions (dividends, splits)
apple.actions

# show dividends
apple.dividends

# show splits
apple.splits
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %%
import yfinance as yf

aapl = yf.Ticker("aapl")
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
import yfinance as yf

aapl = yf.Ticker("aapl")

# get stock info
aapl_historical = aapl.history(start="2020-06-02", end="2020-06-07", interval="1d")
aapl_historical
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2020-06-02  79.531640  80.198640  79.080360  80.173843   87642800          0
# 2020-06-03  80.501154  80.883007  79.915976  80.615211  104491200          0
# 2020-06-04  80.434213  80.739194  79.539091  79.920944   87560400          0
# 2020-06-05  80.176340  82.259163  80.146587  82.197174  137250400          0
#
#             Stock Splits
# Date
# 2020-06-02             0
# 2020-06-03             0
# 2020-06-04             0
# 2020-06-05             0

# %%
tickers = yf.Tickers('msft aapl goog')

# %%
tickers
# Out:
# yfinance.Tickers object <MSFT,AAPL,GOOG>

# %%
# TICKERS OBJECT IS BROKEN
#tickers.MSFT.info

# %%
data = yf.download("AMZN AAPL GOOG", start="2017-01-01", end="2017-04-30", group_by = 'column')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#             Adj Close                              Close              \
#                  AAPL        AMZN        GOOG       AAPL        AMZN
# Date
# 2017-01-03  27.372362  753.669983  786.140015  29.037500  753.669983
# 2017-01-04  27.341724  757.179993  786.900024  29.004999  757.179993
# 2017-01-05  27.480770  780.450012  794.020020  29.152500  780.450012
# 2017-01-06  27.787130  795.989990  806.150024  29.477501  795.989990
# 2017-01-09  28.041647  796.919983  806.650024  29.747499  796.919983
# ...               ...         ...         ...        ...         ...
# 2017-04-24  33.997528  907.409973  862.760010  35.910000  907.409973
# 2017-04-25  34.208176  907.619995  872.299988  36.132500  907.619995
# 2017-04-26  34.006989  909.289978  871.729980  35.919998  909.289978
# 2017-04-27  34.033024  918.380005  874.250000  35.947498  918.380005
# 2017-04-28  33.999893  924.989990  905.960022  35.912498  924.989990
#
#                              High                                Low  \
#                   GOOG       AAPL        AMZN        GOOG       AAPL
# Date
# 2017-01-03  786.140015  29.082500  758.760010  789.630005  28.690001
# 2017-01-04  786.900024  29.127501  759.679993  791.340027  28.937500
# 2017-01-05  794.020020  29.215000  782.400024  794.479980  28.952499
# 2017-01-06  806.150024  29.540001  799.440002  807.900024  29.117500
# 2017-01-09  806.650024  29.857500  801.770020  809.966003  29.485001
# ...                ...        ...         ...         ...        ...
# 2017-04-24  862.760010  35.987499  909.989990  863.450012  35.794998
# 2017-04-25  872.299988  36.224998  909.479980  875.000000  35.967499
# 2017-04-26  871.729980  36.150002  915.750000  876.049988  35.845001
# 2017-04-27  874.250000  36.040001  921.859985  875.400024  35.827499
# 2017-04-28  905.960022  36.075001  949.590027  916.849976  35.817501
#
#                                          Open                          \
#                   AMZN        GOOG       AAPL        AMZN        GOOG
# Date
# 2017-01-03  747.700012  775.799988  28.950001  757.919983  778.809998
# 2017-01-04  754.200012  783.159973  28.962500  758.390015  788.359985
# 2017-01-05  760.260010  785.020020  28.980000  761.549988  786.080017
# 2017-01-06  778.479980  792.203979  29.195000  782.359985  795.260010
# 2017-01-09  791.770020  802.830017  29.487499  798.000000  806.400024
# ...                ...         ...        ...         ...         ...
# 2017-04-24  903.820007  849.859985  35.875000  908.679993  851.200012
# 2017-04-25  903.000000  862.809998  35.977501  907.039978  865.000000
# 2017-04-26  907.559998  867.747986  36.117500  910.299988  874.229980
# 2017-04-27  912.109985  870.380005  35.980000  914.390015  873.599976
# 2017-04-28  924.330017  905.770020  36.022499  948.830017  910.659973
#
#                Volume
#                  AAPL     AMZN     GOOG
# Date
# 2017-01-03  115127600  3521100  1657300
# 2017-01-04   84472400  2510500  1073000
# 2017-01-05   88774400  5830100  1335200
# 2017-01-06  127007600  5986200  1640200
# 2017-01-09  134247600  3446100  1274600
# ...               ...      ...      ...
# 2017-04-24   68537200  3122900  1372500
# 2017-04-25   75486000  3380600  1672000
# 2017-04-26   80164800  2608900  1237200
# 2017-04-27   56985200  5305500  2026800
# 2017-04-28   83441600  7364700  3276300
#
# [81 rows x 18 columns]

# %%
aapl = yf.Ticker("aapl") 
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 147000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store, that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408-996-1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'ebitdaMargins': 0.31955,
#  'profitMargins': 0.25004,
#  'grossMargins': 0.41005,
#  'operatingCashflow': 104414003200,
#  'revenueGrowth': 0.364,
#  'operatingMargins': 0.28788,
#  'ebitda': 110934999040,
#  'targetLowPrice': 132,
#  'recommendationKey': 'buy',
#  'grossProfits': 104956000000,
#  'freeCashflow': 80625876992,
#  'targetMedianPrice': 169.28,
#  'currentPrice': 148.79,
#  'earningsGrowth': 1,
#  'currentRatio': 1.062,
#  'returnOnAssets': 0.19302,
#  'numberOfAnalystOpinions': 43,
#  'targetMeanPrice': 167.27,
#  'debtToEquity': 210.782,
#  'returnOnEquity': 1.27125,
#  'targetHighPrice': 190,
#  'totalCash': 61696000000,
#  'totalDebt': 135491002368,
#  'totalRevenue': 347155005440,
#  'totalCashPerShare': 3.732,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 20.61,
#  'quickRatio': 0.887,
#  'recommendationMean': 1.9,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 7.309,
#  'beta3Year': None,
#  'enterpriseToEbitda': 22.872,
#  '52WeekChange': 0.3948896,
#  'morningStarRiskRating': None,
#  'forwardEps': 5.71,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 16530199552,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 3.882,
#  'sharesShort': 96838699,
#  'sharesPercentSharesOut': 0.0058999998,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1601078400,
#  'heldPercentInstitutions': 0.5873,
#  'netIncomeToCommon': 86801997824,
#  'trailingEps': 5.108,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.34982395,
#  'priceToBook': 38.32818,
#  'heldPercentInsiders': 0.00071000005,
#  'nextFiscalYearEnd': 1664150400,
#  'yield': None,
#  'mostRecentQuarter': 1624665600,
#  'shortRatio': 1.46,
#  'sharesShortPreviousMonthDate': 1627603200,
#  'floatShares': 16513305231,
#  'beta': 1.201965,
#  'enterpriseValue': 2537285746688,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.932,
#  'priceToSalesTrailing12Months': 7.084813,
#  'dateShortInterest': 1630368000,
#  'pegRatio': 1.4,
#  'ytdReturn': None,
#  'forwardPE': 26.057793,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0058999998,
#  'sharesShortPriorMonth': 93114834,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 149.03,
#  'regularMarketOpen': 148.44,
#  'twoHundredDayAverage': 135.22101,
#  'trailingAnnualDividendYield': 0.0056028985,
#  'payoutRatio': 0.16309999,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 148.9684,
#  'navPrice': None,
#  'averageDailyVolume10Day': 92804642,
#  'regularMarketPreviousClose': 149.03,
#  'fiftyDayAverage': 149.21794,
#  'trailingAnnualDividendRate': 0.835,
#  'open': 148.44,
#  'toCurrency': None,
#  'averageVolume10days': 92804642,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.88,
#  'exDividendDate': 1628208000,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 147.221,
#  'currency': 'USD',
#  'trailingPE': 29.128817,
#  'regularMarketVolume': 67901433,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2459528331264,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 79180168,
#  'dayLow': 147.221,
#  'ask': 0,
#  'askSize': 3100,
#  'volume': 67901433,
#  'fiftyTwoWeekHigh': 157.26,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.27,
#  'fiftyTwoWeekLow': 103.1,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0058999998,
#  'bidSize': 1000,
#  'dayHigh': 148.9684,
#  'regularMarketPrice': 148.79,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
aapl = yf.Ticker("aapl")
aapl.info['forwardPE']
# Out:
# 26.057793

# %%
aapl.info['dividendRate']
# Out:
# 0.88

# %%
aapl.dividends
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2020-08-07    0.205000
# 2020-11-06    0.205000
# 2021-02-05    0.205000
# 2021-05-07    0.220000
# 2021-08-06    0.220000
# Name: Dividends, Length: 72, dtype: float64

# %%
aapl.financials
# Out:
#                                             2020-09-26      2019-09-28  \
# Research Development                     18752000000.0   16217000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        67091000000.0   65737000000.0
# Minority Interest                                 None            None
# Net Income                               57411000000.0   55256000000.0
# Selling General Administrative           19916000000.0   18245000000.0
# Gross Profit                            104956000000.0   98392000000.0
# Ebit                                     66288000000.0   63930000000.0
# Operating Income                         66288000000.0   63930000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2873000000.0   -3576000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        9680000000.0   10481000000.0
# Total Revenue                           274515000000.0  260174000000.0
# Total Operating Expenses                208227000000.0  196244000000.0
# Cost Of Revenue                         169559000000.0  161782000000.0
# Total Other Income Expense Net             803000000.0    1807000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           57411000000.0   55256000000.0
# Net Income Applicable To Common Shares   57411000000.0   55256000000.0
#
#                                             2018-09-29      2017-09-30
# Research Development                     14236000000.0   11581000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        72903000000.0   64089000000.0
# Minority Interest                                 None            None
# Net Income                               59531000000.0   48351000000.0
# Selling General Administrative           16705000000.0   15261000000.0
# Gross Profit                            101839000000.0   88186000000.0
# Ebit                                     70898000000.0   61344000000.0
# Operating Income                         70898000000.0   61344000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -3240000000.0   -2323000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                       13372000000.0   15738000000.0
# Total Revenue                           265595000000.0  229234000000.0
# Total Operating Expenses                194697000000.0  167890000000.0
# Cost Of Revenue                         163756000000.0  141048000000.0
# Total Other Income Expense Net            2005000000.0    2745000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           59531000000.0   48351000000.0
# Net Income Applicable To Common Shares   59531000000.0   48351000000.0

# %%
aapl.earnings
# Out:
#            Revenue     Earnings
# Year
# 2017  229234000000  48351000000
# 2018  265595000000  59531000000
# 2019  260174000000  55256000000
# 2020  274515000000  57411000000

# %%
aapl.quarterly_earnings
# Out:
#               Revenue     Earnings
# Quarter
# 3Q2020    64698000000  12673000000
# 4Q2020   111439000000  28755000000
# 1Q2021    89584000000  23630000000
# 2Q2021    81434000000  21744000000

# %%
aapl.cashflow
# Out:
#                                              2020-09-26    2019-09-28  \
# Investments                                5.335000e+09  5.809300e+10
# Change To Liabilities                     -1.981000e+09 -2.548000e+09
# Total Cashflows From Investing Activities -4.289000e+09  4.589600e+10
# Net Borrowings                             2.499000e+09 -7.819000e+09
# Total Cash From Financing Activities      -8.682000e+10 -9.097600e+10
# Change To Operating Activities             8.810000e+08 -8.960000e+08
# Issuance Of Stock                          8.800000e+08  7.810000e+08
# Net Income                                 5.741100e+10  5.525600e+10
# Change In Cash                            -1.043500e+10  2.431100e+10
# Repurchase Of Stock                       -7.599200e+10 -6.971400e+10
# Total Cash From Operating Activities       8.067400e+10  6.939100e+10
# Depreciation                               1.105600e+10  1.254700e+10
# Other Cashflows From Investing Activities -7.910000e+08 -1.078000e+09
# Dividends Paid                            -1.408100e+10 -1.411900e+10
# Change To Inventory                       -1.270000e+08 -2.890000e+08
# Change To Account Receivables              6.917000e+09  2.450000e+08
# Other Cashflows From Financing Activities -1.260000e+08 -1.050000e+08
# Change To Netincome                        6.517000e+09  5.076000e+09
# Capital Expenditures                      -7.309000e+09 -1.049500e+10
#
#                                              2018-09-29    2017-09-30
# Investments                                3.084500e+10 -3.354200e+10
# Change To Liabilities                      9.172000e+09  8.373000e+09
# Total Cashflows From Investing Activities  1.606600e+10 -4.644600e+10
# Net Borrowings                             4.320000e+08  2.901400e+10
# Total Cash From Financing Activities      -8.787600e+10 -1.797400e+10
# Change To Operating Activities             3.001600e+10 -8.480000e+09
# Issuance Of Stock                          6.690000e+08  5.550000e+08
# Net Income                                 5.953100e+10  4.835100e+10
# Change In Cash                             5.624000e+09 -1.950000e+08
# Repurchase Of Stock                       -7.526500e+10 -3.477400e+10
# Total Cash From Operating Activities       7.743400e+10  6.422500e+10
# Depreciation                               1.090300e+10  1.015700e+10
# Other Cashflows From Investing Activities -7.450000e+08 -1.240000e+08
# Dividends Paid                            -1.371200e+10 -1.276900e+10
# Change To Inventory                        8.280000e+08 -2.723000e+09
# Change To Account Receivables             -5.322000e+09 -2.093000e+09
# Other Cashflows From Financing Activities -1.050000e+08 -1.050000e+08
# Change To Netincome                       -2.769400e+10  1.064000e+10
# Capital Expenditures                      -1.331300e+10 -1.245100e+10

# %%
aapl.balance_sheet
# Out:
#                              2020-09-26    2019-09-28    2018-09-29  \
# Total Liab                 2.585490e+11  2.480280e+11  2.585780e+11
# Total Stockholder Equity   6.533900e+10  9.048800e+10  1.071470e+11
# Other Current Liab         4.786700e+10  4.324200e+10  3.929300e+10
# Total Assets               3.238880e+11  3.385160e+11  3.657250e+11
# Common Stock               5.077900e+10  4.517400e+10  4.020100e+10
# Other Current Assets       1.126400e+10  1.235200e+10  1.208700e+10
# Retained Earnings          1.496600e+10  4.589800e+10  7.040000e+10
# Other Liab                 4.610800e+10  5.050300e+10  4.891400e+10
# Treasury Stock            -4.060000e+08 -5.840000e+08 -3.454000e+09
# Other Assets               3.395200e+10  3.297800e+10  2.228300e+10
# Cash                       3.801600e+10  4.884400e+10  2.591300e+10
# Total Current Liabilities  1.053920e+11  1.057180e+11  1.159290e+11
# Short Long Term Debt       8.773000e+09  1.026000e+10  8.784000e+09
# Other Stockholder Equity  -4.060000e+08 -5.840000e+08 -3.454000e+09
# Property Plant Equipment   4.533600e+10  3.737800e+10  4.130400e+10
# Total Current Assets       1.437130e+11  1.628190e+11  1.313390e+11
# Long Term Investments      1.008870e+11  1.053410e+11  1.707990e+11
# Net Tangible Assets        6.533900e+10  9.048800e+10  1.071470e+11
# Short Term Investments     5.292700e+10  5.171300e+10  4.038800e+10
# Net Receivables            3.744500e+10  4.580400e+10  4.899500e+10
# Long Term Debt             9.866700e+10  9.180700e+10  9.373500e+10
# Inventory                  4.061000e+09  4.106000e+09  3.956000e+09
# Accounts Payable           4.229600e+10  4.623600e+10  5.588800e+10
#
#                              2017-09-30
# Total Liab                 2.412720e+11
# Total Stockholder Equity   1.340470e+11
# Other Current Liab         3.809900e+10
# Total Assets               3.753190e+11
# Common Stock               3.586700e+10
# Other Current Assets       1.393600e+10
# Retained Earnings          9.833000e+10
# Other Liab                 4.325100e+10
# Treasury Stock            -1.500000e+08
# Other Assets               1.817700e+10
# Cash                       2.028900e+10
# Total Current Liabilities  1.008140e+11
# Short Long Term Debt       6.496000e+09
# Other Stockholder Equity  -1.500000e+08
# Property Plant Equipment   3.378300e+10
# Total Current Assets       1.286450e+11
# Long Term Investments      1.947140e+11
# Net Tangible Assets        1.340470e+11
# Short Term Investments     5.389200e+10
# Net Receivables            3.567300e+10
# Long Term Debt             9.720700e+10
# Inventory                  4.855000e+09
# Accounts Payable           4.424200e+10

# %%
import pandas as pd

tickers_list = ["aapl", "goog", "amzn", "BAC", "BA"] # example list
tickers_data = {} # empty dictionary

# %%
for ticker in tickers_list:
    ticker_object = yf.Ticker(ticker)

    #convert info() output from dictionary to dataframe
    temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
    temp.reset_index(inplace=True)
    temp.columns = ["Attribute", "Recent"]
    
    # add (ticker, dataframe) to main dictionary
    tickers_data[ticker] = temp

tickers_data
# Out:
# {'aapl':                Attribute                                             Recent
#  0                    zip                                              95014
#  1                 sector                                         Technology
#  2      fullTimeEmployees                                             147000
#  3    longBusinessSummary  Apple Inc. designs, manufactures, and markets ...
#  4                   city                                          Cupertino
#  ..                   ...                                                ...
#  146        dividendYield                                             0.0059
#  147              bidSize                                               1000
#  148              dayHigh                                           148.9684
#  149   regularMarketPrice                                             148.79
#  150             logo_url                https://logo.clearbit.com/apple.com
#
#  [151 rows x 2 columns],
#  'goog':                Attribute                                             Recent
#  0                    zip                                              94043
#  1                 sector                             Communication Services
#  2      fullTimeEmployees                                             144056
#  3    longBusinessSummary  Alphabet Inc. provides online advertising serv...
#  4                   city                                      Mountain View
#  ..                   ...                                                ...
#  146        dividendYield                                               None
#  147              bidSize                                                900
#  148              dayHigh                                               2904
#  149   regularMarketPrice                                            2887.47
#  150             logo_url                  https://logo.clearbit.com/abc.xyz
#
#  [151 rows x 2 columns],
#  'amzn':                Attribute                                             Recent
#  0                    zip                                         98109-5210
#  1                 sector                                  Consumer Cyclical
#  2      fullTimeEmployees                                            1335000
#  3    longBusinessSummary  Amazon.com, Inc. engages in the retail sale of...
#  4                   city                                            Seattle
#  ..                   ...                                                ...
#  146        dividendYield                                               None
#  147              bidSize                                                800
#  148              dayHigh                                            3492.55
#  149   regularMarketPrice                                            3488.24
#  150             logo_url               https://logo.clearbit.com/amazon.com
#
#  [151 rows x 2 columns],
#  'BAC':                Attribute                                             Recent
#  0                    zip                                              28255
#  1                 sector                                 Financial Services
#  2      fullTimeEmployees                                             212000
#  3    longBusinessSummary  Bank of America Corporation, through its subsi...
#  4                   city                                          Charlotte
#  ..                   ...                                                ...
#  147        dividendYield                                             0.0208
#  148              bidSize                                               3200
#  149              dayHigh                                              40.81
#  150   regularMarketPrice                                              40.45
#  151             logo_url        https://logo.clearbit.com/bankofamerica.com
#
#  [152 rows x 2 columns],
#  'BA':                Attribute                                             Recent
#  0                    zip                                         60606-1596
#  1                 sector                                        Industrials
#  2      fullTimeEmployees                                             141000
#  3    longBusinessSummary  The Boeing Company, together with its subsidia...
#  4                   city                                            Chicago
#  ..                   ...                                                ...
#  145        dividendYield                                               None
#  146              bidSize                                                900
#  147              dayHigh                                              216.3
#  148   regularMarketPrice                                             213.36
#  149             logo_url               https://logo.clearbit.com/boeing.com
#
#  [150 rows x 2 columns]}

# %%
# combine all the info dataframes for each ticker into a single data frame
combined_data = pd.concat(tickers_data)
combined_data = combined_data.reset_index()
combined_data
# Out:
#     level_0  level_1            Attribute  \
# 0      aapl        0                  zip
# 1      aapl        1               sector
# 2      aapl        2    fullTimeEmployees
# 3      aapl        3  longBusinessSummary
# 4      aapl        4                 city
# ..      ...      ...                  ...
# 750      BA      145        dividendYield
# 751      BA      146              bidSize
# 752      BA      147              dayHigh
# 753      BA      148   regularMarketPrice
# 754      BA      149             logo_url
#
#                                                 Recent
# 0                                                95014
# 1                                           Technology
# 2                                               147000
# 3    Apple Inc. designs, manufactures, and markets ...
# 4                                            Cupertino
# ..                                                 ...
# 750                                               None
# 751                                                900
# 752                                              216.3
# 753                                             213.36
# 754               https://logo.clearbit.com/boeing.com
#
# [755 rows x 4 columns]

# %%
del combined_data["level_1"] # clean up unnecessary column
combined_data.columns = ["Ticker", "Attribute", "Recent"] # update column names

combined_data
# Out:
#     Ticker            Attribute  \
# 0     aapl                  zip
# 1     aapl               sector
# 2     aapl    fullTimeEmployees
# 3     aapl  longBusinessSummary
# 4     aapl                 city
# ..     ...                  ...
# 750     BA        dividendYield
# 751     BA              bidSize
# 752     BA              dayHigh
# 753     BA   regularMarketPrice
# 754     BA             logo_url
#
#                                                 Recent
# 0                                                95014
# 1                                           Technology
# 2                                               147000
# 3    Apple Inc. designs, manufactures, and markets ...
# 4                                            Cupertino
# ..                                                 ...
# 750                                               None
# 751                                                900
# 752                                              216.3
# 753                                             213.36
# 754               https://logo.clearbit.com/boeing.com
#
# [755 rows x 3 columns]

# %%
employees = combined_data[combined_data["Attribute"]=="fullTimeEmployees"].reset_index()
del employees["index"] # clean up unnecessary column

employees
# Out:
#   Ticker          Attribute   Recent
# 0   aapl  fullTimeEmployees   147000
# 1   goog  fullTimeEmployees   144056
# 2   amzn  fullTimeEmployees  1335000
# 3    BAC  fullTimeEmployees   212000
# 4     BA  fullTimeEmployees   141000

# %%
employees_sorted = employees.sort_values('Recent',ascending=False)
employees_sorted
# Out:
#   Ticker          Attribute   Recent
# 2   amzn  fullTimeEmployees  1335000
# 3    BAC  fullTimeEmployees   212000
# 0   aapl  fullTimeEmployees   147000
# 1   goog  fullTimeEmployees   144056
# 4     BA  fullTimeEmployees   141000

# %%
aapl.info["marketCap"]
# Out:
# 2459528331264

# %%
aapl.info["volume"]
# Out:
# 67901433

# %%
aapl.info["averageVolume"]
# Out:
# 79180168

# %%
aapl.info["averageVolume10days"]
# Out:
# 92804642

# %%
aapl_historical = aapl.history(period="max", interval="1wk")
aapl_historical
# Out:
#                   Open        High         Low       Close       Volume  \
# Date
# 1980-12-08    0.100600    0.101037    0.100600    0.100600  469033600.0
# 1980-12-15    0.095789    0.099288    0.088353    0.098851  490134400.0
# 1980-12-22    0.103662    0.124657    0.103662    0.124219  187891200.0
# 1980-12-29    0.125969    0.126406    0.119408    0.120720  219452800.0
# 1981-01-05    0.118534    0.118534    0.105849    0.111535  197904000.0
# 29  AAPL230915P00230000 2021-09-16 14:42:21   230.0      86.50  0.0  0.0
# 30  AAPL230915P00250000 2021-09-15 17:07:52   250.0     104.62  0.0  0.0
#
#     change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.0            0.0      61             0           0.125009
# 1      0.0            0.0      10             0           0.062509
# 2      0.0            0.0       1             0           0.062509
# 3      0.0            0.0       4             0           0.062509
# 4      0.0            0.0       2             0           0.062509
# 5      0.0            0.0       6             0           0.062509
# 6      0.0            0.0      71             0           0.062509
# 7      0.0            0.0       9             0           0.062509
# 8      0.0            0.0       1             0           0.031260
# 9      0.0            0.0       5             0           0.031260
# 10     0.0            0.0      11             0           0.031260
# 11     0.0            0.0       4             0           0.015635
# 12     0.0            0.0     250             0           0.015635
# 13     0.0            0.0       9             0           0.007822
# 14     0.0            0.0       2             0           0.003916
# 15     0.0            0.0       2             0           0.000010
# 16     0.0            0.0       1             0           0.000010
# 17     0.0            0.0       6             0           0.000010
# 18     0.0            0.0       1             0           0.000010
# 19     0.0            0.0       1             0           0.000010
# 20     0.0            0.0      43             0           0.000010
# 21     0.0            0.0       5             0           0.000010
# 22     0.0            0.0      44             0           0.000010
# 23     0.0            0.0       5             0           0.000010
# 24     0.0            0.0       2             0           0.000010
# 25     0.0            0.0      22             0           0.000010
# 26     0.0            0.0       8             0           0.000010
# 27     0.0            0.0      10             0           0.000010
# 28     0.0            0.0      10             0           0.000010
# 29     0.0            0.0       1             0           0.000010
# 30     0.0            0.0       2             0           0.000010
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25        True      REGULAR      USD
# 26        True      REGULAR      USD
# 27        True      REGULAR      USD
# 28        True      REGULAR      USD
# 29        True      REGULAR      USD
# 30        True      REGULAR      USD

# %%
opt
# Out:
# Options(calls=         contractSymbol       lastTradeDate  strike  lastPrice  bid  ask  \
# 0   AAPL230915C00075000 2021-09-16 19:57:32    75.0      75.85  0.0  0.0
# 1   AAPL230915C00080000 2021-09-15 16:37:48    80.0      70.58  0.0  0.0
# 2   AAPL230915C00085000 2021-09-16 18:51:46    85.0      66.60  0.0  0.0
# 3   AAPL230915C00090000 2021-09-16 14:14:40    90.0      62.00  0.0  0.0
# 4   AAPL230915C00095000 2021-09-16 19:24:15    95.0      58.60  0.0  0.0
# 5   AAPL230915C00100000 2021-09-16 18:12:34   100.0      54.34  0.0  0.0
# 14       False      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25        True      REGULAR      USD
# 26        True      REGULAR      USD
# 27        True      REGULAR      USD
# 28        True      REGULAR      USD
# 29        True      REGULAR      USD
# 30        True      REGULAR      USD  )

# %%
#### OTHER METHODS NOT USED IN ARTICLE ####

# %%
# show actions (dividends, splits)
aapl.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11   0.000536           0.0
# 1987-06-16   0.000000           2.0
# 1987-11-17   0.000714           0.0
# 1988-11-21   0.000893           0.0
# 1989-11-17   0.000982           0.0
# 1990-11-16   0.001071           0.0
# 2012-08-09   0.094643           0.0
# 2013-05-09   0.108929           0.0
# 2014-05-08   0.117500           0.0
# 2014-06-09   0.000000           7.0
# 2015-05-07   0.130000           0.0
# 2016-05-05   0.142500           0.0
# 2017-05-11   0.157500           0.0
# 2018-05-11   0.182500           0.0
# 2019-05-10   0.192500           0.0
# 2020-05-08   0.205000           0.0
# 2020-08-31   0.000000           4.0
# 2021-05-07   0.220000           0.0

# %%
# show splits
aapl.splits
# Out:
# Date
# 1987-06-16    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %%
aapl.financials
# Out:
#                                             2020-09-26      2019-09-28  \
# Research Development                     18752000000.0   16217000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        67091000000.0   65737000000.0
# Minority Interest                                 None            None
# Net Income                               57411000000.0   55256000000.0
# Selling General Administrative           19916000000.0   18245000000.0
# Gross Profit                            104956000000.0   98392000000.0
# Ebit                                     66288000000.0   63930000000.0
# Operating Income                         66288000000.0   63930000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2873000000.0   -3576000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        9680000000.0   10481000000.0
# Total Revenue                           274515000000.0  260174000000.0
# Total Operating Expenses                208227000000.0  196244000000.0
# Cost Of Revenue                         169559000000.0  161782000000.0
# Total Other Income Expense Net             803000000.0    1807000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           57411000000.0   55256000000.0
# Net Income Applicable To Common Shares   57411000000.0   55256000000.0
#
#                                             2018-09-29      2017-09-30
# Research Development                     14236000000.0   11581000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        72903000000.0   64089000000.0
# Minority Interest                                 None            None
# Net Income                               59531000000.0   48351000000.0
# Selling General Administrative           16705000000.0   15261000000.0
# Gross Profit                            101839000000.0   88186000000.0
# Ebit                                     70898000000.0   61344000000.0
# Operating Income                         70898000000.0   61344000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -3240000000.0   -2323000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                       13372000000.0   15738000000.0
# Total Revenue                           265595000000.0  229234000000.0
# Total Operating Expenses                194697000000.0  167890000000.0
# Cost Of Revenue                         163756000000.0  141048000000.0
# Total Other Income Expense Net            2005000000.0    2745000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           59531000000.0   48351000000.0
# Net Income Applicable To Common Shares   59531000000.0   48351000000.0

# %%
# show financials BROKEN
CAGR = ((aapl.financials.loc['Total Revenue'][3]/aapl.financials.loc['Total Revenue'][0])**(1/4)-1)*100
EPS =  aapl.financials.loc['Net Income']/aapl.balance_sheet.loc['Common Stock']

# %%
start_date = dt.datetime.strptime(EPS.index[3].strftime('%Y-%m-%d'), "%Y-%m-%d").date()
end_date   = dt.datetime.strptime(EPS.index[0].strftime('%Y-%m-%d'), "%Y-%m-%d").date()

dates_ = [ start_date + datetime.timedelta(n) for n in range(int ((end_date - start_date).days))]

# %%
#pd.to_datetime(data.index)

# %%
data = yf.download("AAPL", start=(EPS.index[3]-datetime.timedelta(15)).strftime('%Y-%m-%d'), end=(EPS.index[0]+datetime.timedelta(5)).strftime('%Y-%m-%d'), group_by = 'column')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
newdata = data.reindex(dates_)
newdata.index = pd.to_datetime(dates_)
#data.interpolate(method='time')
newdata = newdata.interpolate(method='time')
newdata = newdata.fillna(method='bfill',axis=0)

date_ = []
for i in range(0,len(newdata.index)):
    date_.append(newdata.index[i].isoformat())
    
newdata.index = date_

# %%
newdata.index
# Out:
# Index(['2017-09-30T00:00:00', '2017-10-01T00:00:00', '2017-10-02T00:00:00',
#        '2017-10-03T00:00:00', '2017-10-04T00:00:00', '2017-10-05T00:00:00',
#        '2017-10-06T00:00:00', '2017-10-07T00:00:00', '2017-10-08T00:00:00',
#        '2017-10-09T00:00:00',
#        ...
#        '2020-09-16T00:00:00', '2020-09-17T00:00:00', '2020-09-18T00:00:00',
#        '2020-09-19T00:00:00', '2020-09-20T00:00:00', '2020-09-21T00:00:00',
#        '2020-09-22T00:00:00', '2020-09-23T00:00:00', '2020-09-24T00:00:00',
#        '2020-09-25T00:00:00'],
#       dtype='object', length=1092)

# %%
start_ = dt.datetime.strptime(EPS.index[3].strftime('%Y-%m-%d'), "%Y-%m-%d").isoformat()
y1 = dt.datetime.strptime(EPS.index[2].strftime('%Y-%m-%d'), "%Y-%m-%d").isoformat()
y2 = dt.datetime.strptime(EPS.index[1].strftime('%Y-%m-%d'), "%Y-%m-%d").isoformat()
end_ = dt.datetime.strptime(EPS.index[0].strftime('%Y-%m-%d'), "%Y-%m-%d").isoformat()

# %%
prices_ = [newdata.loc[start_:].iloc[0]['Adj Close'],newdata.loc[:y1].iloc[-1]['Adj Close'],newdata.loc[:y2].iloc[-1]['Adj Close'],newdata.loc[:end_].iloc[-1]['Adj Close']]

# %%
P_E = EPS/prices_

# %%
print("P/E")
plt.plot(P_E)
plt.xticks(rotation = 60)
plt.show()
      
print("CAGR")
print(CAGR)
# Out:
# P/E
# CAGR
# -4.406527456139986

# %%
aapl.history(start="2020-06-02", end="2020-06-07", interval="1d",auto_adjust=True)
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2020-06-02  79.531640  80.198640  79.080360  80.173843   87642800          0
# 2020-06-03  80.501154  80.883007  79.915976  80.615211  104491200          0
# 2020-06-04  80.434213  80.739194  79.539091  79.920944   87560400          0
# 2020-06-05  80.176340  82.259163  80.146587  82.197174  137250400          0
#
#             Stock Splits
# Date
# 2020-06-02             0
# 2020-06-03             0
# 2020-06-04             0
# 2020-06-05             0

# %%
aapl.quarterly_financials
# Out:
#                                            2021-06-26     2021-03-27  \
# Research Development                     5717000000.0   5262000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       24369000000.0  28011000000.0
# Minority Interest                                None           None
# Net Income                              21744000000.0  23630000000.0
# Selling General Administrative           5412000000.0   5314000000.0
# Gross Profit                            35255000000.0  38079000000.0
# Ebit                                    24126000000.0  27503000000.0
# Operating Income                        24126000000.0  27503000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -665000000.0   -670000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       2625000000.0   4381000000.0
# Total Revenue                           81434000000.0  89584000000.0
# Total Operating Expenses                57308000000.0  62081000000.0
# Cost Of Revenue                         46179000000.0  51505000000.0
# Total Other Income Expense Net            243000000.0    508000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          21744000000.0  23630000000.0
# Net Income Applicable To Common Shares  21744000000.0  23630000000.0
#
#                                             2020-12-26     2020-09-26
# Research Development                      5163000000.0   4978000000.0
# Effect Of Accounting Charges                      None           None
# Income Before Tax                        33579000000.0  14901000000.0
# Minority Interest                                 None           None
# Net Income                               28755000000.0  12673000000.0
# Selling General Administrative            5631000000.0   4936000000.0
# Gross Profit                             44328000000.0  24689000000.0
# Ebit                                     33534000000.0  14775000000.0
# Operating Income                         33534000000.0  14775000000.0
# Other Operating Expenses                          None           None
# Interest Expense                          -638000000.0   -634000000.0
# Extraordinary Items                               None           None
# Non Recurring                                     None           None
# Other Items                                       None           None
# Income Tax Expense                        4824000000.0   2228000000.0
# Total Revenue                           111439000000.0  64698000000.0
# Total Operating Expenses                 77905000000.0  49923000000.0
# Cost Of Revenue                          67111000000.0  40009000000.0
# Total Other Income Expense Net              45000000.0    126000000.0
# Discontinued Operations                           None           None
# Net Income From Continuing Ops           28755000000.0  12673000000.0
# Net Income Applicable To Common Shares   28755000000.0  12673000000.0

# %%
# show quarterly_financials BROKEN
aapl.quarterly_financials
# Out:
#                                            2021-06-26     2021-03-27  \
# Research Development                     5717000000.0   5262000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       24369000000.0  28011000000.0
# Minority Interest                                None           None
# Net Income                              21744000000.0  23630000000.0
# Selling General Administrative           5412000000.0   5314000000.0
# Gross Profit                            35255000000.0  38079000000.0
# Ebit                                    24126000000.0  27503000000.0
# Operating Income                        24126000000.0  27503000000.0
# Other Operating Expenses                         None           None
# Interest Expense                         -665000000.0   -670000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       2625000000.0   4381000000.0
# Total Revenue                           81434000000.0  89584000000.0
# Total Operating Expenses                57308000000.0  62081000000.0
# Cost Of Revenue                         46179000000.0  51505000000.0
# Total Other Income Expense Net            243000000.0    508000000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          21744000000.0  23630000000.0
# Net Income Applicable To Common Shares  21744000000.0  23630000000.0
#
#                                             2020-12-26     2020-09-26
# Research Development                      5163000000.0   4978000000.0
# Effect Of Accounting Charges                      None           None
# Income Before Tax                        33579000000.0  14901000000.0
# Minority Interest                                 None           None
# Net Income                               28755000000.0  12673000000.0
# Selling General Administrative            5631000000.0   4936000000.0
# Gross Profit                             44328000000.0  24689000000.0
# Ebit                                     33534000000.0  14775000000.0
# Operating Income                         33534000000.0  14775000000.0
# Other Operating Expenses                          None           None
# Interest Expense                          -638000000.0   -634000000.0
# Extraordinary Items                               None           None
# Non Recurring                                     None           None
# Other Items                                       None           None
# Income Tax Expense                        4824000000.0   2228000000.0
# Total Revenue                           111439000000.0  64698000000.0
# Total Operating Expenses                 77905000000.0  49923000000.0
# Cost Of Revenue                          67111000000.0  40009000000.0
# Total Other Income Expense Net              45000000.0    126000000.0
# Discontinued Operations                           None           None
# Net Income From Continuing Ops           28755000000.0  12673000000.0
# Net Income Applicable To Common Shares   28755000000.0  12673000000.0

# %%
# show major holders 
aapl.major_holders
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  58.73%       % of Shares Held by Institutions
# 2  58.77%        % of Float Held by Institutions
# 3    4981  Number of Institutions Holding Shares

# %%
# show institutional holders
aapl.institutional_holders
# Out:
#                                 Holder      Shares Date Reported   % Out  \
# 0           Vanguard Group, Inc. (The)  1264936543    2021-06-29  0.0765
# 1                       Blackrock Inc.  1028698316    2021-06-29  0.0622
# 2              Berkshire Hathaway, Inc   887135554    2021-06-29  0.0537
# 3             State Street Corporation   622579947    2021-06-29  0.0377
# 4                             FMR, LLC   350462986    2021-06-29  0.0212
# 5        Geode Capital Management, LLC   254162496    2021-06-29  0.0154
# 6           Northern Trust Corporation   193253001    2021-06-29  0.0117
# 7        Price (T.Rowe) Associates Inc   192697039    2021-06-29  0.0117
# 8    Norges Bank Investment Management   167580974    2020-12-30  0.0101
# 9  Bank Of New York Mellon Corporation   153929495    2021-06-29  0.0093
#
#           Value
# 0  173245708929
# 1  140890521359
# 2  121502085475
# 3   85268549541
# 4   47999410562
# 5   34810095452
# 6   26467931016
# 7   26391786461
# 8   22236319440
# 9   21082183635

# %%
# show balance sheet BROKEN
aapl.balance_sheet
# Out:
#                              2020-09-26    2019-09-28    2018-09-29  \
# Total Liab                 2.585490e+11  2.480280e+11  2.585780e+11
# Total Stockholder Equity   6.533900e+10  9.048800e+10  1.071470e+11
# Other Current Liab         4.786700e+10  4.324200e+10  3.929300e+10
# Total Assets               3.238880e+11  3.385160e+11  3.657250e+11
# Common Stock               5.077900e+10  4.517400e+10  4.020100e+10
# Other Current Assets       1.126400e+10  1.235200e+10  1.208700e+10
# Retained Earnings          1.496600e+10  4.589800e+10  7.040000e+10
# Other Liab                 4.610800e+10  5.050300e+10  4.891400e+10
# Treasury Stock            -4.060000e+08 -5.840000e+08 -3.454000e+09
# Other Assets               3.395200e+10  3.297800e+10  2.228300e+10
# Cash                       3.801600e+10  4.884400e+10  2.591300e+10
# Total Current Liabilities  1.053920e+11  1.057180e+11  1.159290e+11
# Short Long Term Debt       8.773000e+09  1.026000e+10  8.784000e+09
# Other Stockholder Equity  -4.060000e+08 -5.840000e+08 -3.454000e+09
# Property Plant Equipment   4.533600e+10  3.737800e+10  4.130400e+10
# Total Current Assets       1.437130e+11  1.628190e+11  1.313390e+11
# Long Term Investments      1.008870e+11  1.053410e+11  1.707990e+11
# Net Tangible Assets        6.533900e+10  9.048800e+10  1.071470e+11
# Short Term Investments     5.292700e+10  5.171300e+10  4.038800e+10
# Net Receivables            3.744500e+10  4.580400e+10  4.899500e+10
# Long Term Debt             9.866700e+10  9.180700e+10  9.373500e+10
# Inventory                  4.061000e+09  4.106000e+09  3.956000e+09
# Accounts Payable           4.229600e+10  4.623600e+10  5.588800e+10
#
#                              2017-09-30
# Total Liab                 2.412720e+11
# Total Stockholder Equity   1.340470e+11
# Other Current Liab         3.809900e+10
# Total Assets               3.753190e+11
# Common Stock               3.586700e+10
# Other Current Assets       1.393600e+10
# Retained Earnings          9.833000e+10
# Other Liab                 4.325100e+10
# Treasury Stock            -1.500000e+08
# Other Assets               1.817700e+10
# Cash                       2.028900e+10
# Total Current Liabilities  1.008140e+11
# Short Long Term Debt       6.496000e+09
# Other Stockholder Equity  -1.500000e+08
# Property Plant Equipment   3.378300e+10
# Total Current Assets       1.286450e+11
# Long Term Investments      1.947140e+11
# Net Tangible Assets        1.340470e+11
# Short Term Investments     5.389200e+10
# Net Receivables            3.567300e+10
# Long Term Debt             9.720700e+10
# Inventory                  4.855000e+09
# Accounts Payable           4.424200e+10

# %%
# BROKEN
aapl.quarterly_balance_sheet
# Out:
#                              2021-06-26    2021-03-27    2020-12-26  \
# Total Liab                 2.655600e+11  2.679800e+11  2.878300e+11
# Total Stockholder Equity   6.428000e+10  6.917800e+10  6.622400e+10
# Other Current Liab         5.130600e+10  5.325500e+10  5.589900e+10
# Total Assets               3.298400e+11  3.371580e+11  3.540540e+11
# Common Stock               5.498900e+10  5.420300e+10  5.174400e+10
# Other Current Assets       1.364100e+10  1.337600e+10  1.368700e+10
# Retained Earnings          9.233000e+09  1.526100e+10  1.430100e+10
# Other Liab                 3.835400e+10  3.985300e+10  4.304200e+10
# Treasury Stock             5.800000e+07 -2.860000e+08  1.790000e+08
# Other Assets               4.485400e+10  4.333900e+10  4.327000e+10
# Cash                       3.405000e+10  3.846600e+10  3.601000e+10
# Total Current Liabilities  1.077540e+11  1.063850e+11  1.325070e+11
# Short Long Term Debt       8.039000e+09  8.003000e+09  7.762000e+09
# Other Stockholder Equity   5.800000e+07 -2.860000e+08  1.790000e+08
# Property Plant Equipment   3.861500e+10  3.781500e+10  3.793300e+10
# Total Current Assets       1.144230e+11  1.214650e+11  1.541060e+11
# Long Term Investments      1.319480e+11  1.345390e+11  1.187450e+11
# Net Tangible Assets        6.428000e+10  6.917800e+10  6.622400e+10
# Short Term Investments     2.764600e+10  3.136800e+10  4.081600e+10
# Net Receivables            3.390800e+10  3.303600e+10  5.862000e+10
# Long Term Debt             1.057520e+11  1.086420e+11  9.928100e+10
# Inventory                  5.178000e+09  5.219000e+09  4.973000e+09
# Accounts Payable           4.040900e+10  4.012700e+10  6.384600e+10
#
#                              2020-09-26
# Total Liab                 2.585490e+11
# Total Stockholder Equity   6.533900e+10
# Other Current Liab         4.786700e+10
# Total Assets               3.238880e+11
# Common Stock               5.077900e+10
# Other Current Assets       1.126400e+10
# Retained Earnings          1.496600e+10
# Other Liab                 4.610800e+10
# Treasury Stock            -4.060000e+08
# Other Assets               3.395200e+10
# Cash                       3.801600e+10
# Total Current Liabilities  1.053920e+11
# Short Long Term Debt       8.773000e+09
# Other Stockholder Equity  -4.060000e+08
# Property Plant Equipment   4.533600e+10
# Total Current Assets       1.437130e+11
# Long Term Investments      1.008870e+11
# Net Tangible Assets        6.533900e+10
# Short Term Investments     5.292700e+10
# Net Receivables            3.744500e+10
# Long Term Debt             9.866700e+10
# Inventory                  4.061000e+09
# Accounts Payable           4.229600e+10

# %%
# show cashflow BROKEN
aapl.cashflow
# Out:
#                                              2020-09-26    2019-09-28  \
# Investments                                5.335000e+09  5.809300e+10
# Change To Liabilities                     -1.981000e+09 -2.548000e+09
# Total Cashflows From Investing Activities -4.289000e+09  4.589600e+10
# Net Borrowings                             2.499000e+09 -7.819000e+09
# Total Cash From Financing Activities      -8.682000e+10 -9.097600e+10
# Change To Operating Activities             8.810000e+08 -8.960000e+08
# Issuance Of Stock                          8.800000e+08  7.810000e+08
# Net Income                                 5.741100e+10  5.525600e+10
# Change In Cash                            -1.043500e+10  2.431100e+10
# Repurchase Of Stock                       -7.599200e+10 -6.971400e+10
# Total Cash From Operating Activities       8.067400e+10  6.939100e+10
# Depreciation                               1.105600e+10  1.254700e+10
# Other Cashflows From Investing Activities -7.910000e+08 -1.078000e+09
# Dividends Paid                            -1.408100e+10 -1.411900e+10
# Change To Inventory                       -1.270000e+08 -2.890000e+08
# Change To Account Receivables              6.917000e+09  2.450000e+08
# Other Cashflows From Financing Activities -1.260000e+08 -1.050000e+08
# Change To Netincome                        6.517000e+09  5.076000e+09
# Capital Expenditures                      -7.309000e+09 -1.049500e+10
#
#                                              2018-09-29    2017-09-30
# Investments                                3.084500e+10 -3.354200e+10
# Change To Liabilities                      9.172000e+09  8.373000e+09
# Total Cashflows From Investing Activities  1.606600e+10 -4.644600e+10
# Net Borrowings                             4.320000e+08  2.901400e+10
# Total Cash From Financing Activities      -8.787600e+10 -1.797400e+10
# Change To Operating Activities             3.001600e+10 -8.480000e+09
# Issuance Of Stock                          6.690000e+08  5.550000e+08
# Net Income                                 5.953100e+10  4.835100e+10
# Change In Cash                             5.624000e+09 -1.950000e+08
# Repurchase Of Stock                       -7.526500e+10 -3.477400e+10
# Total Cash From Operating Activities       7.743400e+10  6.422500e+10
# Depreciation                               1.090300e+10  1.015700e+10
# Other Cashflows From Investing Activities -7.450000e+08 -1.240000e+08
# Dividends Paid                            -1.371200e+10 -1.276900e+10
# Change To Inventory                        8.280000e+08 -2.723000e+09
# Change To Account Receivables             -5.322000e+09 -2.093000e+09
# Other Cashflows From Financing Activities -1.050000e+08 -1.050000e+08
# Change To Netincome                       -2.769400e+10  1.064000e+10
# Capital Expenditures                      -1.331300e+10 -1.245100e+10

# %%
# BROKEN
aapl.quarterly_cashflow
# Out:
#                                              2021-06-26    2021-03-27  \
# Investments                                5.747000e+09 -7.895000e+09
# Change To Liabilities                      3.070000e+08 -2.336600e+10
# Total Cashflows From Investing Activities  3.572000e+09 -1.036800e+10
# Total Cash From Financing Activities      -2.939600e+10 -1.132600e+10
# Change To Operating Activities            -6.048000e+09  1.126500e+10
# Net Income                                 2.174400e+10  2.363000e+10
# Change In Cash                            -4.730000e+09  2.287000e+09
# Repurchase Of Stock                       -2.559500e+10 -1.884700e+10
# Total Cash From Operating Activities       2.109400e+10  2.398100e+10
# Depreciation                               2.832000e+09  2.797000e+09
# Other Cashflows From Investing Activities -7.800000e+07 -2.040000e+08
# Dividends Paid                            -3.767000e+09 -3.447000e+09
# Change To Inventory                        1.300000e+07 -2.760000e+08
# Change To Account Receivables              1.031000e+09  8.598000e+09
# Other Cashflows From Financing Activities -3.400000e+07 -1.600000e+07
# Change To Netincome                        1.215000e+09  1.333000e+09
# Capital Expenditures                      -2.093000e+09 -2.269000e+09
# Net Borrowings                                      NaN  1.042300e+10
# Issuance Of Stock                                   NaN  5.610000e+08
#
#                                              2020-12-26    2020-09-26
# Investments                               -5.279000e+09  7.468000e+09
# Change To Liabilities                      2.301100e+10  7.157000e+09
# Total Cashflows From Investing Activities -8.584000e+09  5.531000e+09
# Total Cash From Financing Activities      -3.224900e+10 -2.135700e+10
# Change To Operating Activities            -5.761000e+09 -4.911000e+09
# Net Income                                 2.875500e+10  1.267300e+10
# Change In Cash                            -2.070000e+09  4.750000e+09
# Repurchase Of Stock                       -2.763600e+10 -1.758700e+10
# Total Cash From Operating Activities       3.876300e+10  2.057600e+10
# Depreciation                               2.666000e+09  2.702000e+09
# Other Cashflows From Investing Activities  2.040000e+08 -1.020000e+08
# Dividends Paid                            -3.613000e+09 -3.511000e+09
# Change To Inventory                       -9.500000e+08 -1.370000e+08
# Change To Account Receivables             -1.094500e+10  1.768000e+09
# Other Cashflows From Financing Activities -2.200000e+07 -6.000000e+06
# Change To Netincome                        1.987000e+09  1.324000e+09
# Capital Expenditures                      -3.500000e+09 -1.784000e+09
# Net Borrowings                            -9.780000e+08 -7.030000e+08
# Issuance Of Stock                          5.610000e+08  4.500000e+08

# %%
# show earnings BROKEN
aapl.earnings
# Out:
#            Revenue     Earnings
# Year
# 2017  229234000000  48351000000
# 2018  265595000000  59531000000
# 2019  260174000000  55256000000
# 2020  274515000000  57411000000

# %%
# BROKEN
aapl.quarterly_earnings
# Out:
#               Revenue     Earnings
# Quarter
# 3Q2020    64698000000  12673000000
# 4Q2020   111439000000  28755000000
# 1Q2021    89584000000  23630000000
# 2Q2021    81434000000  21744000000

# %%
# show sustainability BROKEN
aapl.sustainability
# Out:
#                                      Value
# 2021-9
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                           7.99
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                               53
# governanceScore                       8.64
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             16.92
# highestControversy                       3
# esgPerformance                  UNDER_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# percentile                           13.68
# peerGroup              Technology Hardware
# smallArms                            False
# environmentScore                      0.29
# governancePercentile                  None
# militaryContract                     False

# %%
# show analysts recommendations
aapl.recommendations
# Out:
#                                   Firm      To Grade    From Grade Action
# Date
# 2012-02-09 08:17:00  Canaccord Genuity           Buy                 main
# 2012-03-08 07:33:00     FBN Securities    Outperform                 main
# 2012-03-13 06:08:00          Jefferies           Buy                 main
# 2012-03-14 06:13:00     Morgan Stanley    Overweight                 main
# 2012-03-14 08:21:00  Canaccord Genuity           Buy                 main
# ...                                ...           ...           ...    ...
# 2021-07-28 14:04:02      Piper Sandler    Overweight                 main
# 2021-07-28 14:08:03      Deutsche Bank           Buy                 main
# 2021-07-28 14:20:34       Loop Capital           Buy                 main
# 2021-09-01 13:06:05     Wolfe Research  Peer Perform  Underperform     up
# 2021-09-09 13:49:40      Piper Sandler    Overweight                 main
#
# [806 rows x 4 columns]

# %%
# show next event (earnings, etc)
aapl.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-10-27 10:59:00  2021-11-01 12:00:00
# Earnings Average                 1.23                 1.23
# Earnings Low                     1.05                 1.05
# Earnings High                    1.34                 1.34
# Revenue Average           84903200000          84903200000
# Revenue Low               77654100000          77654100000
# Revenue High              90905000000          90905000000

# %%
# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
aapl.isin
# Out:
# 'US0378331005'

# %%
# show options expirations
aapl.options
# Out:
# ('2021-09-17',
#  '2021-09-24',
#  '2021-10-01',
#  '2021-10-08',
#  '2021-10-15',
#  '2021-10-22',
#  '2021-10-29',
#  '2021-11-19',
#  '2021-12-17',
#  '2022-01-21',
#  '2022-03-18',
#  '2022-04-14',
#  '2022-06-17',
#  '2022-09-16',
#  '2023-01-20',
#  '2023-03-17',
#  '2023-06-16',
#  '2023-09-15')

# %%
# get option chain for specific expiration
opt = aapl.option_chain()
opt
# Out:
# Options(calls=          contractSymbol       lastTradeDate   strike  lastPrice    bid   ask  \
# 0    AAPL210917C00027500 2021-09-16 19:55:00    27.50     121.25   0.00   0.0
# 1    AAPL210917C00028750 2021-09-14 13:48:14    28.75     121.75   0.00   0.0
# 2    AAPL210917C00030000 2021-09-15 13:31:56    30.00     118.70   0.00   0.0
# 3    AAPL210917C00031250 2021-09-14 16:09:47    31.25     118.75   0.00   0.0
# 4    AAPL210917C00032500 2021-08-30 13:33:58    32.50     116.46   0.00   0.0
# ..                   ...                 ...      ...        ...    ...   ...
# 133  AAPL210917C00720000 2020-08-28 19:25:09   720.00      26.60  25.80  26.7
# 134  AAPL210917C00740000 2020-08-28 15:33:47   740.00      24.50  23.55  24.4
# 135  AAPL210917C00800000 2020-08-28 19:17:58   800.00      19.11  18.30  19.1
# 136  AAPL210917C00900000 2020-08-27 15:03:20   900.00      13.13  12.85  13.6
# 137  AAPL210917C01000000 2020-08-28 19:58:31  1000.00      10.20  10.00  10.4
#
#        change  percentChange  volume  openInterest  impliedVolatility  \
# 0    0.000000       0.000000       1           0.0           0.000010
# 1    0.000000       0.000000       6           0.0           0.000010
# 2    0.000000       0.000000       1           0.0           0.000010
# 3    0.000000       0.000000       6           0.0           0.000010
# 4    0.000000       0.000000      20           0.0           0.000010
# ..        ...            ...     ...           ...                ...
# 133 -0.449999      -1.663582      11         110.0          27.036134
# 134 -0.500000      -2.000000       2           NaN          26.465822
# 135 -0.289999      -1.494840      43           6.0          25.152346
# 136 -0.570000      -4.160582      25           5.0          23.818362
# 137 -0.250000      -2.392345      65           NaN          23.181643
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 133       False      REGULAR      USD
# 134       False      REGULAR      USD
# 135       False      REGULAR      USD
# 136       False      REGULAR      USD
# 137       False      REGULAR      USD
#
# [138 rows x 14 columns], puts=          contractSymbol       lastTradeDate  strike  lastPrice     bid  \
# 0    AAPL210917P00027500 2021-09-16 15:09:23   27.50       0.01    0.00
# 1    AAPL210917P00028750 2021-08-25 21:34:45   28.75       0.01    0.00
# 2    AAPL210917P00030000 2021-08-25 21:34:46   30.00       0.01    0.01
# 3    AAPL210917P00031250 2021-08-25 21:34:46   31.25       0.01    0.00
# 4    AAPL210917P00032500 2021-08-20 14:39:17   32.50       0.01    0.00
# ..                   ...                 ...     ...        ...     ...
# 126  AAPL210917P00560000 2020-08-28 19:40:53  560.00     116.00  118.50
# 127  AAPL210917P00580000 2020-08-25 13:59:05  580.00     133.25  132.60
# 128  AAPL210917P00600000 2020-08-25 17:44:08  600.00     146.15  147.40
# 129  AAPL210917P00640000 2020-08-27 16:29:02  640.00     177.33  178.30
# 130  AAPL210917P00700000 2020-08-28 14:57:19  700.00     227.82  228.40
#
#         ask     change  percentChange  volume  openInterest  \
# 0      0.00   0.000000       0.000000    10.0             0
# 1      0.00   0.000000       0.000000    10.0             0
# 2      0.00   0.000000       0.000000    60.0             0
# 3      0.00   0.000000       0.000000    20.0             0
# 4      0.00   0.000000       0.000000     2.0             0
# ..      ...        ...            ...     ...           ...
# 126  120.00 -47.800003     -29.181930     2.0             1
# 127  134.15   0.000000       0.000000     NaN             2
# 128  149.00  -1.650009      -1.116380    10.0           121
# 129  180.25   0.000000       0.000000     1.0             0
# 130  230.60  -0.069992      -0.030713    43.0            67
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             0.500005       False      REGULAR      USD
# 1             0.500005       False      REGULAR      USD
# 2             9.500004       False      REGULAR      USD
# 3             0.500005       False      REGULAR      USD
# 4             0.500005       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 126           0.000010        True      REGULAR      USD
# 127           0.000010        True      REGULAR      USD
# 128           0.000010        True      REGULAR      USD
# 129           0.000010        True      REGULAR      USD
# 130           0.000010        True      REGULAR      USD
#
# [131 rows x 14 columns])
