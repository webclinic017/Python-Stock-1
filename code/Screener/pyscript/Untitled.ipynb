# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Get the data
#from pyodide.http import open_url

df_ = pd.read_csv('http://127.0.0.1:8000/sample.csv')
print(df_)
#url = 'https://raw.githubusercontent.com/alanjones2/uk-historical-weather/main/data/Heathrow.csv'
#url_content = open_url(url)
#df = pd.read_csv(url_content)
# Out:
#            Date      Open      High       Low    Close*        VOLUME
# 0     25-May-22  3,929.59  3,999.33  3,925.03  3,978.73    100,000.00
# 1     24-May-22  3,942.94  3,955.68  3,875.13  3,941.48    200,000.00
# 2     23-May-22  3,919.42  3,981.88  3,909.04  3,973.75    300,000.00
# 3     20-May-22  3,927.76  3,943.42  3,810.32  3,901.36    400,000.00
# 4     19-May-22  3,899.00  3,945.96  3,876.58  3,900.79    500,000.00
# ...         ...       ...       ...       ...       ...           ...
# 1165   9-Oct-17  2,551.39  2,551.82  2,541.60  2,544.73  1,500,000.00
# 1166   6-Oct-17  2,547.44  2,549.41  2,543.79  2,549.33  1,600,000.00
# 1167   5-Oct-17  2,540.86  2,552.51  2,540.02  2,552.07  1,700,000.00
# 1168   4-Oct-17  2,533.48  2,540.53  2,531.80  2,537.74  1,800,000.00
# 1169   3-Oct-17  2,530.34  2,535.13  2,528.85  2,534.58  1,900,000.00
#
# [1170 rows x 6 columns]

# %%
from http.server import BaseHTTPRequestHandler, HTTPServer # python3
class HandleRequests(BaseHTTPRequestHandler):
    def _set_headers(self):
        self.send_response(200)
        self.send_header('Content-type', 'text/html')
        self.end_headers()

    def do_GET(self):
        self._set_headers()
        self.wfile.write("received get request")

    def do_POST(self):
        '''Reads post request body'''
        self._set_headers()
        content_len = int(self.headers.getheader('content-length', 0))
        post_body = self.rfile.read(content_len)
        self.wfile.write("received post request:<br>{}".format(post_body))

    def do_PUT(self):
        self.do_POST()

host = ''
port = 80
HTTPServer((host, port), HandleRequests).serve_forever()
# Out:
# 127.0.0.1 - - [26/Jun/2022 18:54:28] "GET / HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54635)
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 747, in __init__
#     self.handle()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 427, in handle
#     self.handle_one_request()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 415, in handle_one_request
#     method()
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_19800\4050432816.py", line 10, in do_GET
#     self.wfile.write("received get request")
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 826, in write
#     self._sock.sendall(b)
# TypeError: a bytes-like object is required, not 'str'
# ----------------------------------------
# 127.0.0.1 - - [26/Jun/2022 18:54:34] "GET /favicon.ico HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54636)
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 747, in __init__
#     self.handle()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 427, in handle
#     self.handle_one_request()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 415, in handle_one_request
#     method()
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_19800\4050432816.py", line 10, in do_GET
#     self.wfile.write("received get request")
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 826, in write
#     self._sock.sendall(b)
# TypeError: a bytes-like object is required, not 'str'
# ----------------------------------------
# 127.0.0.1 - - [26/Jun/2022 18:54:37] "GET / HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54641)
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 747, in __init__
#     self.handle()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 427, in handle
#     self.handle_one_request()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 415, in handle_one_request
#     method()
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_19800\4050432816.py", line 10, in do_GET
#     self.wfile.write("received get request")
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 826, in write
#     self._sock.sendall(b)
# TypeError: a bytes-like object is required, not 'str'
# ----------------------------------------
# 127.0.0.1 - - [26/Jun/2022 18:54:37] "GET /favicon.ico HTTP/1.1" 200 -
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 54642)
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 747, in __init__
#     self.handle()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 427, in handle
#     self.handle_one_request()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\http\server.py", line 415, in handle_one_request
#     method()
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_19800\4050432816.py", line 10, in do_GET
#     self.wfile.write("received get request")
#   File "C:\Users\User\AppData\Local\Programs\Python\Python39\lib\socketserver.py", line 826, in write
#     self._sock.sendall(b)
# TypeError: a bytes-like object is required, not 'str'
# ----------------------------------------
#
# KeyboardInterrupt
