# %%
from IPython.display import HTML
from IPython.display import display, HTML
from PIL import Image
from dask.distributed import Client
from dask.distributed import as_completed
from datetime import datetime
from dateutil.relativedelta import relativedelta
from matplotlib.dates import DateFormatter
from pandas.io.formats.style import Styler
from pivottablejs import pivot_ui
from pmdarima.arima import auto_arima
from scipy import stats
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
import datetime as dt
import matplotlib
import matplotlib as mp
import matplotlib as mpl
import matplotlib.dates as md
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pandas_market_calendars as mcal
import pickle
import rpy2
import seaborn as sns
import sqlite3
import statsmodels.api as sm
import warnings
pd.options.display.max_columns = 50
pd.options.display.max_rows = 200

# %%
dict_sectors = {'Basic Materials':'VAW', 'Communication Services':'VOX', 'Consumer Cyclical':'VCR',
       'Consumer Defensive':'VDC', 'Energy':'VDE', 'Financial Services':'VFH', 'Healthcare':'VHT',
       'Industrials':'VIS', 'Real Estate':'VNQ', 'Technology':'VGT', 'Utilities':'VPU', 'error':'error'}

dict_indexes = {'SPTM':'SP1500', 'SPY':'SP500', 'SLY':'SP600', 'MDYG':'SP400','error':'error'}

dict_sectors_reverse = {'VAW':'Basic Materials',
 'VOX':'Communication Services',
 'VCR':'Consumer Cyclical',
 'VDC':'Consumer Defensive',
 'VDE':'Energy',
 'VFH':'Financial Services',
 'VHT':'Healthcare',
 'VIS':'Industrials',
 'VNQ':'Real Estate',
 'VGT':'Technology',
 'VPU':'Utilities',
 'error': 'error'}

# %%
def evaluate_ets(npa_):
    train,test,model_func,flag_ = npa_
    
    try:
        if(len(flag)==2):
            if(flag[1] is None):
                model = model_func(np.log(train['Adj Close']),initialization_method='heuristic',seasonal=flag[0],trend=flag[1],dates=train.index).fit()
            else:
                model = model_func(np.log(train['Adj Close']),initialization_method='heuristic',seasonal=flag[0],seasonal_periods=52,trend=flag[1],dates=train.index).fit()
        else:
            model = model_func(np.log(train['Adj Close']),initialization_method='heuristic',seasonal=flag[0],seasonal_periods=52,trend=flag[1],damped_trend=flag[2],dates=train.index).fit()

        fc_ets_ = np.exp(model.get_prediction(start=test.index[0],end=test.index[-1]).summary_frame())
        rmse_ = mean_squared_error(test, fc_ets_['mean'], squared=True)
    except:
        #not enough data points
        rmse_ = np.nan
    
    return([flag,rmse_])

# %%
def time_to_int(dateobj):
    total = int(dateobj.strftime('%S'))
    total += int(dateobj.strftime('%M')) * 60
    total += int(dateobj.strftime('%H')) * 60 * 60
    total += (int(dateobj.strftime('%j')) - 1) * 60 * 60 * 24
    total += (int(dateobj.strftime('%Y')) - 1970) * 60 * 60 * 24 * 365
    return total

def myfunc(x):
    return slope * x + intercept

# %%
def highlight_cells(val, color_if_true, color_if_false, threshold_):
    color = color_if_true if val >= threshold_ else color_if_false
    return 'background-color: {}'.format(color)

# %%
db_filename = 'todo.db'

db_is_new = not os.path.exists(db_filename)

conn = sqlite3.connect(db_filename)

if db_is_new:
    print('Need to create schema')
else:
    print('Database exists, assume schema does, too.')

conn.close()
# Out:
# Database exists, assume schema does, too.

# %%
si = ['03-31','06-30','09-30','12-31']
               
[start,end, prices_df, sp1500_index_df, sp500, sp600, sp400, market_data, completed_fred_pvt, completed_bonds, completed_bonds_pvt, sectors, indexes, screener_sorted] = pickle.load(open('./data_object.pkl', 'rb'))

prices = prices_df
#prices = pd.read_excel('SP1500_screener_multiple.xlsx',sheet_name="SP1500_Sectors_Indexes_Prices")

# %%
def colored(r, g, b, text):
    return f"\033[38;2;{r};{g};{b}m{text}\033[0m"

# %%
def display_side_by_side(dfs:list, captions:list, tablespacing=5):
    """Display tables side by side to save vertical space
    Input:
        dfs: list of pandas.DataFrame
        captions: list of table captions
    """
    output = ""
    for (caption, df) in zip(captions, dfs):
        output += df.style.set_table_attributes("style='display:inline'").set_caption(caption)._repr_html_()
        output += tablespacing * "\xa0"
    display(HTML(output))

# %%
cm = sns.color_palette("blend:red,yellow,green", as_cmap=True)

def b_g(s, cmap=cm, low=0, high=0):
    # Pass the columns from Dataframe A 
    a = A.loc[:,s.name].copy()
    #rng = a.max() - a.min()
    rng = np.nanmax(A.values.ravel()) - np.nanmin(A.values.ravel())
    norm = mp.colors.Normalize(np.nanmin(A.values.ravel()) - (rng * low),
                        np.nanmax(A.values.ravel()) + (rng * high))
    normed = norm(a.values)
    #c = [mp.colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    c = [mp.colors.rgb2hex(x) for x in plt.cm.get_cmap(cm)(normed)]
    return ['background-color: %s' % color for color in c]

# %%
nyse = mcal.get_calendar('NYSE')
nyse_dates = nyse.schedule(start_date=start, end_date=end)

# %%
stock_fundamentals = market_data
screener = screener_sorted
fundamentals = stock_fundamentals
stock_indexes = sp1500_index_df

spdr_indexes = indexes
spdr_indexes.columns=['Symbol']
vanguard_sectors = sectors
vanguard_sectors.columns=['Symbol']

# %%
sector_performance_return = pd.DataFrame()
sector_performance_Q_smoothed_return = pd.DataFrame()

for v in [*spdr_indexes['Symbol'],*vanguard_sectors['Symbol']]:
    subset = prices[prices['Symbol'] == v]
    #subset_ = subset.set_index('Date').asfreq('Q')[['Adj Close']].pct_change()
    subset_ = subset.asfreq('D').interpolate().asfreq('Q')[['Adj Close']].pct_change()
    #print(subset_)
    #subset_qs = subset.set_index('Date')[['Adj Close']].pct_change().rolling(63).mean()
    subset_qs = subset[['Adj Close']].pct_change().rolling(63).mean()
    subset_.index = subset_.index.values.astype('M8[D]')
    subset_qs.index = subset_qs.index.values.astype('M8[D]')
    dt_str = subset_.index[-1].strftime('%Y-%m-%d')
    #tail = subset[subset.set_index('Date').index>=dt_str]
    tail = subset[subset.index>=dt_str]
    #dt_str = subset.set_index('Date').index[-1].strftime('%Y-%m-%d')
    dt_str = subset.index[-1].strftime('%Y-%m-%d')
    #tail_ = pd.DataFrame([(tail.set_index('Date')['Adj Close'][-1]-tail.set_index('Date')['Adj Close'][0])/tail.set_index('Date')['Adj Close'][0]],index=[datetime.strptime(dt_str, '%Y-%m-%d')],columns=['Adj Close'])
    tail_ = pd.DataFrame([(tail['Adj Close'][-1]-tail['Adj Close'][0])/tail['Adj Close'][0]],index=[datetime.strptime(dt_str, '%Y-%m-%d')],columns=['Adj Close'])
    subset__ = pd.concat([subset_,tail_],axis=0)
    sector_performance_return = pd.concat([sector_performance_return,subset__],axis=1)
    sector_performance_Q_smoothed_return = pd.concat([sector_performance_Q_smoothed_return,subset_qs],axis=1)

# %%
sector_performance_Q_smoothed_return.columns = [*[i for i in spdr_indexes.index],*[v for v in vanguard_sectors.index]]
sector_performance_return.columns = [*[i for i in spdr_indexes.index],*[v for v in vanguard_sectors.index]]

# %%
from scipy import stats as st
from scipy.stats import t

std_indexes = pd.DataFrame()
seasonal_indexes = pd.DataFrame()

warnings.filterwarnings('ignore')
for spr in sector_performance_return.columns:
    #print(spr)
    s = sector_performance_return[[spr]]
    #print(s)
    years = []
    quarters = []
    for d in sector_performance_return[spr].index:

        d_ = d.strftime('%Y-%m-%d')
        #print(d_)

        datem = dt.datetime.strptime(d_, "%Y-%m-%d")
        years.append(str(datem.year))
        #print(datem.year)       # 2021
        m = datem.month
        d = datem.day
        if(len(str(m))==1):
            m = '0'+str(m)
        else:
            m = str(m)
        if(len(str(d))==1):
            d = '0'+str(d)
        else:
            d = str(d)
        quarters.append(m+"-"+d)

    s['Years'] = years
    s['Quarters'] = quarters
    ct = pd.crosstab(s['Years'], s['Quarters'],values=s[spr],aggfunc=np.mean).mean(axis=0).sort_index()
    ct.columns = [spr]
    
    ct_std = pd.crosstab(s['Years'], s['Quarters'],values=s[spr],aggfunc=np.mean).std(axis=0).sort_index()
    ct_std.columns = [spr]
    
    std_indexes = pd.concat([std_indexes,ct_std],axis=1)
    seasonal_indexes = pd.concat([seasonal_indexes,ct],axis=1)

seasonal_indexes.columns = sector_performance_return.columns

std_indexes.columns = sector_performance_return.columns
    
seasonal_indexes = seasonal_indexes.T

std_indexes = std_indexes.T

si = ['03-31','06-30','09-30','12-31']

print("Seasonal Indexes")

seasonal_index_values_sorted = []
seasonal_index_names_sorted = []
#B = seasonal_indexes[si]
for c in seasonal_indexes[si].columns:
    seasonal_index_values_sorted.append(seasonal_indexes[si][c].sort_values(ascending=False).values)
    seasonal_index_names_sorted.append(seasonal_indexes[si][c].sort_values(ascending=False).index.values)

temp_seasonal_index_values_sorted = pd.DataFrame(seasonal_index_values_sorted).T
temp_seasonal_index_values_sorted.columns = seasonal_indexes[si].columns

temp_seasonal_index_names_sorted = pd.DataFrame(seasonal_index_names_sorted).T
temp_seasonal_index_names_sorted.columns = seasonal_indexes[si].columns

A = temp_seasonal_index_values_sorted
B = temp_seasonal_index_names_sorted 

display(B.style.apply(b_g,cmap=cm))

display(seasonal_indexes[si].style.background_gradient(cmap = cm,axis=0))

print("Note if the final data in the prices ends on a quarter, this will aggregate into the seasonal_index above and there will be no comparison")
print("Current")

display(seasonal_indexes[seasonal_indexes.columns.difference(si)].sort_values(by=seasonal_indexes[seasonal_indexes.columns.difference(si)].columns[0],ascending=False).style.background_gradient(cmap = cm,axis=0))    

#calculate p-value
n=5

print("standard deviations")
display(std_indexes[si])
t_scores = (seasonal_indexes[si])/(std_indexes[si]*np.sqrt(n))
print("t scores")
display(t_scores)
print("p values")
p_values = pd.DataFrame(t.cdf(t_scores, df=n-2),index=seasonal_indexes[si].index,columns=seasonal_indexes[si].columns)

display(p_values.style.applymap(highlight_cells, color_if_true='green', color_if_false='yellow', threshold_=.5))

p_values.hist()
# Out:
# Seasonal Indexes
# <style  type="text/css" >
# #T_598da_row0_col0{
#             background-color:  #d0e800;
#         }#T_598da_row0_col1{
#             background-color:  #008000;
#         }#T_598da_row0_col2{
#             background-color:  #a8d400;
#         }#T_598da_row0_col3{
#             background-color:  #acd600;
#         }#T_598da_row1_col0{
#             background-color:  #ff9000;
#         }#T_598da_row1_col1{
#             background-color:  #048200;
#         }#T_598da_row1_col2,#T_598da_row4_col3{
#             background-color:  #daed00;
#         }#T_598da_row1_col3{
#             background-color:  #b2d900;
#         }#T_598da_row2_col0{
#             background-color:  #ff7800;
#         }#T_598da_row2_col1{
#             background-color:  #50a800;
#         }#T_598da_row2_col2,#T_598da_row9_col3{
#             background-color:  #f0f800;
#         }#T_598da_row2_col3,#T_598da_row12_col1{
#             background-color:  #c8e400;
#         }#T_598da_row3_col0{
#             background-color:  #ff5c00;
#         }#T_598da_row3_col1{
#             background-color:  #7abd00;
#         }#T_598da_row3_col2{
#             background-color:  #f2f900;
#         }#T_598da_row3_col3{
#             background-color:  #cae500;
#         }#T_598da_row4_col0{
#             background-color:  #ff5a00;
#         }#T_598da_row4_col1{
#             background-color:  #7ebf00;
#         }#T_598da_row4_col2{
#             background-color:  #feff00;
#         }#T_598da_row5_col0{
#             background-color:  #ff5600;
#         }#T_598da_row5_col1,#T_598da_row6_col1{
#             background-color:  #82c100;
#         }#T_598da_row5_col2{
#             background-color:  #fffe00;
#         }#T_598da_row5_col3{
#             background-color:  #deef00;
#         }#T_598da_row6_col0,#T_598da_row7_col0{
#             background-color:  #ff4400;
#         }#T_598da_row6_col2{
#             background-color:  #fffa00;
#         }#T_598da_row6_col3,#T_598da_row7_col3{
#             background-color:  #e2f100;
#         }#T_598da_row7_col1{
#             background-color:  #84c200;
#         }#T_598da_row7_col2{
#             background-color:  #ffec00;
#         }#T_598da_row8_col0{
#             background-color:  #ff4200;
#         }#T_598da_row8_col1{
#             background-color:  #88c400;
#         }#T_598da_row8_col2{
#             background-color:  #ffdc00;
#         }#T_598da_row8_col3{
#             background-color:  #eaf500;
#         }#T_598da_row9_col0{
#             background-color:  #ff3e00;
#         }#T_598da_row9_col1{
#             background-color:  #90c800;
#         }#T_598da_row9_col2{
#             background-color:  #ffd600;
#         }#T_598da_row10_col0{
#             background-color:  #ff3c00;
#         }#T_598da_row10_col1{
#             background-color:  #92c900;
#         }#T_598da_row10_col2{
#             background-color:  #ffc400;
#         }#T_598da_row10_col3{
#             background-color:  #fafd00;
#         }#T_598da_row11_col0{
#             background-color:  #ff3a00;
#         }#T_598da_row11_col1{
#             background-color:  #c0e000;
#         }#T_598da_row11_col2{
#             background-color:  #ffbe00;
#         }#T_598da_row11_col3{
#             background-color:  #fcfe00;
#         }#T_598da_row12_col0{
#             background-color:  #ff2a00;
#         }#T_598da_row12_col2,#T_598da_row13_col2{
#             background-color:  #ffba00;
#         }#T_598da_row12_col3{
#             background-color:  #fffc00;
#         }#T_598da_row13_col0{
#             background-color:  #ff2800;
#         }#T_598da_row13_col1{
#             background-color:  #ffee00;
#         }#T_598da_row13_col3{
#             background-color:  #fff600;
#         }#T_598da_row14_col0{
#             background-color:  #ff1400;
#         }#T_598da_row14_col1{
#             background-color:  #ffd000;
#         }#T_598da_row14_col2{
#             background-color:  #ff0000;
#         }#T_598da_row14_col3{
#             background-color:  #ffb600;
#         }</style><table id="T_598da_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >03-31</th>        <th class="col_heading level0 col1" >06-30</th>        <th class="col_heading level0 col2" >09-30</th>        <th class="col_heading level0 col3" >12-31</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_598da_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_598da_row0_col0" class="data row0 col0" >Energy ETF</td>
#                         <td id="T_598da_row0_col1" class="data row0 col1" >Information Technology ETF</td>
#                         <td id="T_598da_row0_col2" class="data row0 col2" >Information Technology ETF</td>
#                         <td id="T_598da_row0_col3" class="data row0 col3" >Information Technology ETF</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_598da_row1_col0" class="data row1 col0" >Information Technology ETF</td>
#                         <td id="T_598da_row1_col1" class="data row1 col1" >Consumer Discretionary ETF</td>
#                         <td id="T_598da_row1_col2" class="data row1 col2" >Consumer Discretionary ETF</td>
#                         <td id="T_598da_row1_col3" class="data row1 col3" >Financials ETF</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_598da_row2_col0" class="data row2 col0" >Utilities ETF</td>
#                         <td id="T_598da_row2_col1" class="data row2 col1" >Energy ETF</td>
#                         <td id="T_598da_row2_col2" class="data row2 col2" >SP500</td>
#                         <td id="T_598da_row2_col3" class="data row2 col3" >Materials ETF</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_598da_row3_col0" class="data row3 col0" >SP1500</td>
#                         <td id="T_598da_row3_col1" class="data row3 col1" >Materials ETF</td>
#                         <td id="T_598da_row3_col2" class="data row3 col2" >Industrials ETF</td>
#                         <td id="T_598da_row3_col3" class="data row3 col3" >SP600</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_598da_row4_col0" class="data row4 col0" >Industrials ETF</td>
#                         <td id="T_598da_row4_col1" class="data row4 col1" >SP1500</td>
#                         <td id="T_598da_row4_col2" class="data row4 col2" >SP1500</td>
#                         <td id="T_598da_row4_col3" class="data row4 col3" >Consumer Discretionary ETF</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_598da_row5_col0" class="data row5 col0" >SP500</td>
#                         <td id="T_598da_row5_col1" class="data row5 col1" >SP500</td>
#                         <td id="T_598da_row5_col2" class="data row5 col2" >Health Care ETF</td>
#                         <td id="T_598da_row5_col3" class="data row5 col3" >SP400</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_598da_row6_col0" class="data row6 col0" >SP600</td>
#                         <td id="T_598da_row6_col1" class="data row6 col1" >SP600</td>
#                         <td id="T_598da_row6_col2" class="data row6 col2" >Utilities ETF</td>
#                         <td id="T_598da_row6_col3" class="data row6 col3" >SP500</td>
#             </tr>
#             <tr>
#                         <th id="T_598da_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_598da_row7_col0" class="data row7 col0" >Health Care ETF</td>
#                         <td id="T_598da_row7_col1" class="data row7 col1" >SP400</td>
# <style  type="text/css" >
# #T_cd0f6_row0_col0{
#             background-color:  #ff8000;
#             color:  #000000;
#         }#T_cd0f6_row0_col1{
#             background-color:  #d6eb00;
#             color:  #000000;
#         }#T_cd0f6_row0_col2{
#             background-color:  #7ebf00;
#             color:  #000000;
#         }#T_cd0f6_row0_col3,#T_cd0f6_row8_col2{
#             background-color:  #b4da00;
#             color:  #000000;
#         }#T_cd0f6_row1_col0{
#             background-color:  #ff7800;
#             color:  #000000;
#         }#T_cd0f6_row1_col1{
#             background-color:  #daed00;
#             color:  #000000;
#         }#T_cd0f6_row1_col2,#T_cd0f6_row10_col2{
#             background-color:  #6cb600;
#             color:  #000000;
#         }#T_cd0f6_row1_col3{
#             background-color:  #b2d900;
#             color:  #000000;
#         }#T_cd0f6_row2_col0,#T_cd0f6_row9_col0{
#             background-color:  #ff5600;
#             color:  #000000;
#         }#T_cd0f6_row2_col1{
#             background-color:  #dcee00;
#             color:  #000000;
#         }#T_cd0f6_row2_col2,#T_cd0f6_row13_col2{
#             background-color:  #e8f400;
#             color:  #000000;
#         }#T_cd0f6_row2_col3{
#             background-color:  #62b100;
#             color:  #000000;
#         }#T_cd0f6_row3_col0{
#             background-color:  #ff4a00;
#             color:  #000000;
#         }#T_cd0f6_row3_col1,#T_cd0f6_row6_col3{
#             background-color:  #deef00;
#             color:  #000000;
#         }#T_cd0f6_row3_col2{
#             background-color:  #e2f100;
#             color:  #000000;
#         }#T_cd0f6_row3_col3{
#             background-color:  #a4d200;
#             color:  #000000;
#         }#T_cd0f6_row4_col0,#T_cd0f6_row4_col3,#T_cd0f6_row7_col2,#T_cd0f6_row14_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_cd0f6_row4_col1{
#             background-color:  #f4fa00;
#             color:  #000000;
#         }#T_cd0f6_row4_col2{
#             background-color:  #d8ec00;
#             color:  #000000;
#         }#T_cd0f6_row5_col0{
#             background-color:  #ff4200;
#             color:  #f1f1f1;
#         }#T_cd0f6_row5_col1{
#             background-color:  #088400;
#             color:  #f1f1f1;
#         }#T_cd0f6_row5_col2{
#             background-color:  #4ca600;
#             color:  #000000;
#         }#T_cd0f6_row5_col3{
#             background-color:  #98cc00;
#             color:  #000000;
#         }#T_cd0f6_row6_col0{
#             background-color:  #ff5000;
#             color:  #000000;
#         }#T_cd0f6_row6_col1{
#             background-color:  #ff3200;
#             color:  #f1f1f1;
#         }#T_cd0f6_row6_col2{
#             background-color:  #a0d000;
#             color:  #000000;
#         }#T_cd0f6_row7_col0,#T_cd0f6_row11_col1,#T_cd0f6_row11_col2,#T_cd0f6_row11_col3{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_cd0f6_row7_col1{
#             background-color:  #88c400;
#             color:  #000000;
#         }#T_cd0f6_row7_col3{
#             background-color:  #fffc00;
#             color:  #000000;
#         }#T_cd0f6_row8_col0{
#             background-color:  #ff4600;
#             color:  #f1f1f1;
#         }#T_cd0f6_row8_col1{
#             background-color:  #ffba00;
#             color:  #000000;
#         }#T_cd0f6_row8_col3{
#             background-color:  #148a00;
#             color:  #f1f1f1;
#         }#T_cd0f6_row9_col1{
#             background-color:  #e6f300;
#             color:  #000000;
#         }#T_cd0f6_row9_col2{
#             background-color:  #82c100;
#             color:  #000000;
#         }#T_cd0f6_row9_col3{
#             background-color:  #cee700;
#             color:  #000000;
#         }#T_cd0f6_row10_col0{
#             background-color:  #ff7e00;
#             color:  #000000;
#         }#T_cd0f6_row10_col1{
#             background-color:  #ffac00;
#             color:  #000000;
#         }#T_cd0f6_row10_col3{
#             background-color:  #ffe200;
#             color:  #000000;
#         }#T_cd0f6_row11_col0{
#             background-color:  #ffe000;
#             color:  #000000;
#         }#T_cd0f6_row12_col0{
#             background-color:  #ff2200;
#             color:  #f1f1f1;
#         }#T_cd0f6_row12_col1{
#             background-color:  #d0e800;
#             color:  #000000;
#         }#T_cd0f6_row12_col2{
#             background-color:  #c0e000;
#             color:  #000000;
#         }#T_cd0f6_row12_col3{
#             background-color:  #5aad00;
#             color:  #000000;
#         }#T_cd0f6_row13_col0{
#             background-color:  #ff2400;
#             color:  #f1f1f1;
#         }#T_cd0f6_row13_col1{
#             background-color:  #f6fb00;
#             color:  #000000;
#         }#T_cd0f6_row13_col3{
#             background-color:  #ffd400;
#             color:  #000000;
#         }#T_cd0f6_row14_col0{
#             background-color:  #ffb600;
#             color:  #000000;
#         }#T_cd0f6_row14_col2{
#             background-color:  #8ac500;
#             color:  #000000;
#         }#T_cd0f6_row14_col3{
#             background-color:  #fff800;
#             color:  #000000;
#         }</style><table id="T_cd0f6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >03-31</th>        <th class="col_heading level0 col1" >06-30</th>        <th class="col_heading level0 col2" >09-30</th>        <th class="col_heading level0 col3" >12-31</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cd0f6_level0_row0" class="row_heading level0 row0" >SP1500</th>
#                         <td id="T_cd0f6_row0_col0" class="data row0 col0" >-0.010622</td>
#                         <td id="T_cd0f6_row0_col1" class="data row0 col1" >0.081757</td>
#                         <td id="T_cd0f6_row0_col2" class="data row0 col2" >0.041626</td>
#                         <td id="T_cd0f6_row0_col3" class="data row0 col3" >0.049958</td>
#             </tr>
#             <tr>
#                         <th id="T_cd0f6_level0_row1" class="row_heading level0 row1" >SP500</th>
#                         <td id="T_cd0f6_row1_col0" class="data row1 col0" >-0.011990</td>
#                         <td id="T_cd0f6_row1_col1" class="data row1 col1" >0.080771</td>
#                         <td id="T_cd0f6_row1_col2" class="data row1 col2" >0.045646</td>
#                         <td id="T_cd0f6_row1_col3" class="data row1 col3" >0.050086</td>
#             </tr>
#             <tr>
#                         <th id="T_cd0f6_level0_row2" class="row_heading level0 row2" >SP600</th>
#                         <td id="T_cd0f6_row2_col0" class="data row2 col0" >-0.017768</td>
#                         <td id="T_cd0f6_row2_col1" class="data row2 col1" >0.080509</td>
#                         <td id="T_cd0f6_row2_col2" class="data row2 col2" >0.019158</td>
#                         <td id="T_cd0f6_row2_col3" class="data row2 col3" >0.057970</td>
#             </tr>
#             <tr>
#                         <th id="T_cd0f6_level0_row3" class="row_heading level0 row3" >SP400</th>
#                         <td id="T_cd0f6_row3_col0" class="data row3 col0" >-0.019859</td>
#                         <td id="T_cd0f6_row3_col1" class="data row3 col1" >0.080174</td>
#                         <td id="T_cd0f6_row3_col2" class="data row3 col2" >0.020554</td>
#                         <td id="T_cd0f6_row3_col3" class="data row3 col3" >0.051549</td>
#             </tr>
#             <tr>
#                         <th id="T_cd0f6_level0_row4" class="row_heading level0 row4" >Communication Services ETF</th>
#                         <td id="T_cd0f6_row4_col0" class="data row4 col0" >-0.032872</td>
#                         <td id="T_cd0f6_row4_col1" class="data row4 col1" >0.075995</td>
#                         <td id="T_cd0f6_row4_col2" class="data row4 col2" >0.022591</td>
#                         <td id="T_cd0f6_row4_col3" class="data row4 col3" >0.017899</td>
#             </tr>
#             <tr>
#                         <th id="T_cd0f6_level0_row5" class="row_heading level0 row5" >Consumer Discretionary ETF</th>
# Note if the final data in the prices ends on a quarter, this will aggregate into the seasonal_index above and there will be no comparison
# Current
# <style  type="text/css" >
# #T_0c0e2_row0_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_0c0e2_row1_col0{
#             background-color:  #7cbe00;
#             color:  #000000;
#         }#T_0c0e2_row2_col0{
#             background-color:  #c2e100;
#             color:  #000000;
#         }#T_0c0e2_row3_col0{
#             background-color:  #d6eb00;
#             color:  #000000;
#         }#T_0c0e2_row4_col0{
#             background-color:  #ffea00;
#             color:  #000000;
#         }#T_0c0e2_row5_col0{
#             background-color:  #ffde00;
#             color:  #000000;
#         }#T_0c0e2_row6_col0{
#             background-color:  #ffc000;
#             color:  #000000;
#         }#T_0c0e2_row7_col0{
#             background-color:  #ffb200;
#             color:  #000000;
#         }#T_0c0e2_row8_col0{
#             background-color:  #ffaa00;
#             color:  #000000;
#         }#T_0c0e2_row9_col0,#T_0c0e2_row10_col0{
#             background-color:  #ffa400;
#             color:  #000000;
#         }#T_0c0e2_row11_col0{
#             background-color:  #ffa000;
#             color:  #000000;
#         }#T_0c0e2_row12_col0{
#             background-color:  #ff4e00;
#             color:  #000000;
#         }#T_0c0e2_row13_col0{
#             background-color:  #ff4200;
#             color:  #f1f1f1;
#         }#T_0c0e2_row14_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_0c0e2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >06-17</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c0e2_level0_row0" class="row_heading level0 row0" >Energy ETF</th>
#                         <td id="T_0c0e2_row0_col0" class="data row0 col0" >-0.043815</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row1" class="row_heading level0 row1" >Consumer Staples ETF</th>
#                         <td id="T_0c0e2_row1_col0" class="data row1 col0" >-0.096218</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row2" class="row_heading level0 row2" >Utilities ETF</th>
#                         <td id="T_0c0e2_row2_col0" class="data row2 col0" >-0.125888</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row3" class="row_heading level0 row3" >Health Care ETF</th>
#                         <td id="T_0c0e2_row3_col0" class="data row3 col0" >-0.134327</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row4" class="row_heading level0 row4" >Materials ETF</th>
#                         <td id="T_0c0e2_row4_col0" class="data row4 col0" >-0.161041</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row5" class="row_heading level0 row5" >SP600</th>
#                         <td id="T_0c0e2_row5_col0" class="data row5 col0" >-0.165794</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row6" class="row_heading level0 row6" >Industrials ETF</th>
#                         <td id="T_0c0e2_row6_col0" class="data row6 col0" >-0.178228</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row7" class="row_heading level0 row7" >SP1500</th>
#                         <td id="T_0c0e2_row7_col0" class="data row7 col0" >-0.184779</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row8" class="row_heading level0 row8" >Financials ETF</th>
#                         <td id="T_0c0e2_row8_col0" class="data row8 col0" >-0.187815</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row9" class="row_heading level0 row9" >SP500</th>
#                         <td id="T_0c0e2_row9_col0" class="data row9 col0" >-0.189930</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row10" class="row_heading level0 row10" >Real Estate ETF</th>
#                         <td id="T_0c0e2_row10_col0" class="data row10 col0" >-0.190735</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row11" class="row_heading level0 row11" >SP400</th>
#                         <td id="T_0c0e2_row11_col0" class="data row11 col0" >-0.192427</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row12" class="row_heading level0 row12" >Communication Services ETF</th>
#                         <td id="T_0c0e2_row12_col0" class="data row12 col0" >-0.226489</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row13" class="row_heading level0 row13" >Information Technology ETF</th>
#                         <td id="T_0c0e2_row13_col0" class="data row13 col0" >-0.232112</td>
#             </tr>
#             <tr>
#                         <th id="T_0c0e2_level0_row14" class="row_heading level0 row14" >Consumer Discretionary ETF</th>
#                         <td id="T_0c0e2_row14_col0" class="data row14 col0" >-0.260025</td>
#             </tr>
#     </tbody></table>
# standard deviations
#                                03-31     06-30     09-30     12-31
# SP1500                      0.134644  0.072380  0.037999  0.110320
# SP500                       0.127411  0.070450  0.039033  0.106496
# SP600                       0.199479  0.088447  0.037096  0.179394
# SP400                       0.157662  0.100224  0.037075  0.138781
# Communication Services ETF  0.138244  0.095192  0.045269  0.123434
# Consumer Discretionary ETF  0.151791  0.146922  0.083611  0.127243
# Consumer Staples ETF        0.096633  0.035421  0.049261  0.063730
# Energy ETF                  0.369457  0.166709  0.099129  0.202483
# Financials ETF              0.192299  0.053666  0.014462  0.140299
# Health Care ETF             0.079810  0.054107  0.065798  0.098650
# Industrials ETF             0.178470  0.072339  0.066050  0.134044
# Information Technology ETF  0.135329  0.113409  0.054569  0.136753
# Materials ETF               0.163483  0.099766  0.065317  0.127072
# Real Estate ETF             0.161483  0.056090  0.032025  0.078165
# Utilities ETF               0.092016  0.021473  0.033841  0.054883
# t scores
#                                03-31     06-30     09-30     12-31
# SP1500                     -0.035281  0.505153  0.489908  0.202519
# SP500                      -0.042087  0.512730  0.522980  0.210329
# SP600                      -0.039834  0.407076  0.230960  0.144515
# SP400                      -0.056330  0.357747  0.247928  0.166115
# Communication Services ETF -0.106341  0.357027  0.223180  0.064848
# Consumer Discretionary ETF -0.062503  0.366041  0.280865  0.185493
# Consumer Staples ETF       -0.086371  0.447954  0.315992  0.322196
# Energy ETF                  0.067680  0.258283 -0.179260  0.093682
# Financials ETF             -0.048166  0.508740  0.933164  0.208614
# Health Care ETF            -0.100433  0.650529  0.278976  0.215182
# Industrials ETF            -0.027615  0.360421  0.307577  0.133187
# Information Technology ETF  0.020546  0.480423  0.562966  0.220841
# Materials ETF              -0.072960  0.371283  0.191302  0.206478
# Real Estate ETF            -0.073157  0.604012  0.271246  0.220111
# Utilities ETF              -0.006140  0.544116  0.518265  0.342246
# p values
# <style  type="text/css" >
# #T_d0e56_row0_col0,#T_d0e56_row1_col0,#T_d0e56_row2_col0,#T_d0e56_row3_col0,#T_d0e56_row4_col0,#T_d0e56_row5_col0,#T_d0e56_row6_col0,#T_d0e56_row7_col2,#T_d0e56_row8_col0,#T_d0e56_row9_col0,#T_d0e56_row10_col0,#T_d0e56_row12_col0,#T_d0e56_row13_col0,#T_d0e56_row14_col0{
#             background-color:  yellow;
#         }#T_d0e56_row0_col1,#T_d0e56_row0_col2,#T_d0e56_row0_col3,#T_d0e56_row1_col1,#T_d0e56_row1_col2,#T_d0e56_row1_col3,#T_d0e56_row2_col1,#T_d0e56_row2_col2,#T_d0e56_row2_col3,#T_d0e56_row3_col1,#T_d0e56_row3_col2,#T_d0e56_row3_col3,#T_d0e56_row4_col1,#T_d0e56_row4_col2,#T_d0e56_row4_col3,#T_d0e56_row5_col1,#T_d0e56_row5_col2,#T_d0e56_row5_col3,#T_d0e56_row6_col1,#T_d0e56_row6_col2,#T_d0e56_row6_col3,#T_d0e56_row7_col0,#T_d0e56_row7_col1,#T_d0e56_row7_col3,#T_d0e56_row8_col1,#T_d0e56_row8_col2,#T_d0e56_row8_col3,#T_d0e56_row9_col1,#T_d0e56_row9_col2,#T_d0e56_row9_col3,#T_d0e56_row10_col1,#T_d0e56_row10_col2,#T_d0e56_row10_col3,#T_d0e56_row11_col0,#T_d0e56_row11_col1,#T_d0e56_row11_col2,#T_d0e56_row11_col3,#T_d0e56_row12_col1,#T_d0e56_row12_col2,#T_d0e56_row12_col3,#T_d0e56_row13_col1,#T_d0e56_row13_col2,#T_d0e56_row13_col3,#T_d0e56_row14_col1,#T_d0e56_row14_col2,#T_d0e56_row14_col3{
#             background-color:  green;
#         }</style><table id="T_d0e56_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >03-31</th>        <th class="col_heading level0 col1" >06-30</th>        <th class="col_heading level0 col2" >09-30</th>        <th class="col_heading level0 col3" >12-31</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d0e56_level0_row0" class="row_heading level0 row0" >SP1500</th>
#                         <td id="T_d0e56_row0_col0" class="data row0 col0" >0.487036</td>
#                         <td id="T_d0e56_row0_col1" class="data row0 col1" >0.675887</td>
#                         <td id="T_d0e56_row0_col2" class="data row0 col2" >0.671106</td>
#                         <td id="T_d0e56_row0_col3" class="data row0 col3" >0.573766</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row1" class="row_heading level0 row1" >SP500</th>
#                         <td id="T_d0e56_row1_col0" class="data row1 col0" >0.484537</td>
#                         <td id="T_d0e56_row1_col1" class="data row1 col1" >0.678247</td>
#                         <td id="T_d0e56_row1_col2" class="data row1 col2" >0.681422</td>
#                         <td id="T_d0e56_row1_col3" class="data row1 col3" >0.576557</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row2" class="row_heading level0 row2" >SP600</th>
#                         <td id="T_d0e56_row2_col0" class="data row2 col0" >0.485364</td>
#                         <td id="T_d0e56_row2_col1" class="data row2 col1" >0.644372</td>
#                         <td id="T_d0e56_row2_col2" class="data row2 col2" >0.583899</td>
#                         <td id="T_d0e56_row2_col3" class="data row2 col3" >0.552872</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row3" class="row_heading level0 row3" >SP400</th>
#                         <td id="T_d0e56_row3_col0" class="data row3 col0" >0.479310</td>
#                         <td id="T_d0e56_row3_col1" class="data row3 col1" >0.627889</td>
#                         <td id="T_d0e56_row3_col2" class="data row3 col2" >0.589904</td>
#                         <td id="T_d0e56_row3_col3" class="data row3 col3" >0.560685</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row4" class="row_heading level0 row4" >Communication Services ETF</th>
#                         <td id="T_d0e56_row4_col0" class="data row4 col0" >0.461012</td>
#                         <td id="T_d0e56_row4_col1" class="data row4 col1" >0.627646</td>
#                         <td id="T_d0e56_row4_col2" class="data row4 col2" >0.581136</td>
#                         <td id="T_d0e56_row4_col3" class="data row4 col3" >0.523813</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row5" class="row_heading level0 row5" >Consumer Discretionary ETF</th>
#                         <td id="T_d0e56_row5_col0" class="data row5 col0" >0.477047</td>
#                         <td id="T_d0e56_row5_col1" class="data row5 col1" >0.630688</td>
#                         <td id="T_d0e56_row5_col2" class="data row5 col2" >0.601465</td>
#                         <td id="T_d0e56_row5_col3" class="data row5 col3" >0.567662</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row6" class="row_heading level0 row6" >Consumer Staples ETF</th>
#                         <td id="T_d0e56_row6_col0" class="data row6 col0" >0.468307</td>
#                         <td id="T_d0e56_row6_col1" class="data row6 col1" >0.657720</td>
#                         <td id="T_d0e56_row6_col2" class="data row6 col2" >0.613641</td>
#                         <td id="T_d0e56_row6_col3" class="data row6 col3" >0.615774</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row7" class="row_heading level0 row7" >Energy ETF</th>
#                         <td id="T_d0e56_row7_col0" class="data row7 col0" >0.524851</td>
#                         <td id="T_d0e56_row7_col1" class="data row7 col1" >0.593553</td>
#                         <td id="T_d0e56_row7_col2" class="data row7 col2" >0.434579</td>
#                         <td id="T_d0e56_row7_col3" class="data row7 col3" >0.534366</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row8" class="row_heading level0 row8" >Financials ETF</th>
#                         <td id="T_d0e56_row8_col0" class="data row8 col0" >0.482306</td>
#                         <td id="T_d0e56_row8_col1" class="data row8 col1" >0.677006</td>
#                         <td id="T_d0e56_row8_col2" class="data row8 col2" >0.790214</td>
#                         <td id="T_d0e56_row8_col3" class="data row8 col3" >0.575945</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row9" class="row_heading level0 row9" >Health Care ETF</th>
#                         <td id="T_d0e56_row9_col0" class="data row9 col0" >0.463168</td>
#                         <td id="T_d0e56_row9_col1" class="data row9 col1" >0.719135</td>
#                         <td id="T_d0e56_row9_col2" class="data row9 col2" >0.600805</td>
#                         <td id="T_d0e56_row9_col3" class="data row9 col3" >0.578288</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row10" class="row_heading level0 row10" >Industrials ETF</th>
#                         <td id="T_d0e56_row10_col0" class="data row10 col0" >0.489852</td>
#                         <td id="T_d0e56_row10_col1" class="data row10 col1" >0.628793</td>
#                         <td id="T_d0e56_row10_col2" class="data row10 col2" >0.610739</td>
#                         <td id="T_d0e56_row10_col3" class="data row10 col3" >0.548761</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row11" class="row_heading level0 row11" >Information Technology ETF</th>
#                         <td id="T_d0e56_row11_col0" class="data row11 col0" >0.507551</td>
#                         <td id="T_d0e56_row11_col1" class="data row11 col1" >0.668108</td>
#                         <td id="T_d0e56_row11_col2" class="data row11 col2" >0.693606</td>
#                         <td id="T_d0e56_row11_col3" class="data row11 col3" >0.580304</td>
#             </tr>
#             <tr>
#                         <th id="T_d0e56_level0_row12" class="row_heading level0 row12" >Materials ETF</th>
#                         <td id="T_d0e56_row12_col0" class="data row12 col0" >0.473215</td>
#                         <td id="T_d0e56_row12_col1" class="data row12 col1" >0.632451</td>
#                         <td id="T_d0e56_row12_col2" class="data row12 col2" >0.569748</td
# array([[<AxesSubplot:title={'center':'03-31'}>,
#         <AxesSubplot:title={'center':'06-30'}>],
#        [<AxesSubplot:title={'center':'09-30'}>,
#         <AxesSubplot:title={'center':'12-31'}>]], dtype=object)

# %%
cycles_ = ['Expansion','Slowdown','Recession','Recovery']

path=r"C:\Users\User\Documents\wiki\wiki\dev\python\Python-Stock\reports\figures\Business cycles.png"
display(Image.open(path))
path=r"C:\Users\User\Documents\wiki\wiki\Finance\Business Cycles-2.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=795x657 at 0x252CFF77D00>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1984x1118 at 0x252CDB05A90>

# %%
sector_performance_return_pvt = sector_performance_return[sector_performance_return.iloc[-1].sort_values(ascending=False).index]

sector_performance_return_pvt_heatmap = sector_performance_return_pvt.style.background_gradient(cmap = cm,axis=None)
display(sector_performance_return_pvt_heatmap)

sector_performances = pd.DataFrame()
sector_performances_values = pd.DataFrame()
for c in sector_performance_return.T.columns:
    #print(c)
    temp = pd.DataFrame(sector_performance_return.T[c].sort_values(ascending=False).index,columns=[c])
    #print(temp)
    temp2 = pd.DataFrame(sector_performance_return.T[c].sort_values(ascending=False),columns=[c])
    #print(temp2)
    temp2.reset_index(drop=True,inplace=True)    
    sector_performances = pd.concat([sector_performances,temp],axis=1)
    sector_performances_values = pd.concat([sector_performances_values,temp2],axis=1)
    
A = sector_performances_values
B = sector_performances

df = B.style.apply(b_g,cmap='RdYlGn')

display(df)
# Out:
# <style  type="text/css" >
# #T_ea0a4_row0_col0,#T_ea0a4_row0_col1,#T_ea0a4_row0_col2,#T_ea0a4_row0_col3,#T_ea0a4_row0_col4,#T_ea0a4_row0_col5,#T_ea0a4_row0_col6,#T_ea0a4_row0_col7,#T_ea0a4_row0_col8,#T_ea0a4_row0_col9,#T_ea0a4_row0_col10,#T_ea0a4_row0_col11,#T_ea0a4_row0_col12,#T_ea0a4_row0_col13,#T_ea0a4_row0_col14{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_ea0a4_row1_col0,#T_ea0a4_row4_col0,#T_ea0a4_row10_col0{
#             background-color:  #fffc00;
#             color:  #000000;
#         }#T_ea0a4_row1_col1,#T_ea0a4_row7_col2,#T_ea0a4_row9_col5,#T_ea0a4_row10_col9{
#             background-color:  #d0e800;
#             color:  #000000;
#         }#T_ea0a4_row1_col2,#T_ea0a4_row4_col13,#T_ea0a4_row6_col0,#T_ea0a4_row6_col2,#T_ea0a4_row6_col12{
#             background-color:  #cae500;
#             color:  #000000;
#         }#T_ea0a4_row1_col3,#T_ea0a4_row3_col0,#T_ea0a4_row3_col8,#T_ea0a4_row3_col11,#T_ea0a4_row10_col10,#T_ea0a4_row15_col1,#T_ea0a4_row15_col2,#T_ea0a4_row16_col14,#T_ea0a4_row17_col8{
#             background-color:  #acd600;
#             color:  #000000;
#         }#T_ea0a4_row1_col4,#T_ea0a4_row1_col14,#T_ea0a4_row14_col8,#T_ea0a4_row17_col1{
#             background-color:  #c6e300;
#             color:  #000000;
#         }#T_ea0a4_row1_col5,#T_ea0a4_row1_col10,#T_ea0a4_row3_col3,#T_ea0a4_row9_col3{
#             background-color:  #cce600;
#             color:  #000000;
#         }#T_ea0a4_row1_col6,#T_ea0a4_row1_col13,#T_ea0a4_row9_col4,#T_ea0a4_row17_col5,#T_ea0a4_row19_col8{
#             background-color:  #bedf00;
#             color:  #000000;
#         }#T_ea0a4_row1_col7,#T_ea0a4_row1_col9,#T_ea0a4_row1_col11,#T_ea0a4_row2_col2,#T_ea0a4_row6_col5,#T_ea0a4_row6_col8,#T_ea0a4_row6_col11,#T_ea0a4_row9_col11,#T_ea0a4_row14_col5,#T_ea0a4_row16_col1,#T_ea0a4_row16_col2,#T_ea0a4_row17_col11{
#             background-color:  #c4e200;
#             color:  #000000;
#         }#T_ea0a4_row1_col8,#T_ea0a4_row2_col3,#T_ea0a4_row3_col5,#T_ea0a4_row9_col7,#T_ea0a4_row9_col9,#T_ea0a4_row9_col14,#T_ea0a4_row17_col6{
#             background-color:  #c0e000;
#             color:  #000000;
#         }#T_ea0a4_row1_col12,#T_ea0a4_row4_col9,#T_ea0a4_row18_col11{
#             background-color:  #e4f200;
#             color:  #000000;
#         }#T_ea0a4_row2_col0,#T_ea0a4_row3_col4,#T_ea0a4_row3_col9,#T_ea0a4_row6_col7,#T_ea0a4_row16_col7{
#             background-color:  #aed700;
#             color:  #000000;
#         }#T_ea0a4_row2_col1,#T_ea0a4_row4_col8,#T_ea0a4_row10_col4,#T_ea0a4_row18_col14,#T_ea0a4_row20_col4{
#             background-color:  #deef00;
#             color:  #000000;
#         }#T_ea0a4_row2_col4,#T_ea0a4_row3_col6,#T_ea0a4_row3_col7,#T_ea0a4_row6_col14,#T_ea0a4_row9_col8,#T_ea0a4_row11_col4,#T_ea0a4_row11_col11,#T_ea0a4_row14_col11{
#             background-color:  #b0d800;
#             color:  #000000;
#         }#T_ea0a4_row2_col5,#T_ea0a4_row14_col3,#T_ea0a4_row16_col9,#T_ea0a4_row17_col14{
#             background-color:  #b2d900;
#             color:  #000000;
#         }#T_ea0a4_row2_col6,#T_ea0a4_row2_col8,#T_ea0a4_row5_col2,#T_ea0a4_row5_col7,#T_ea0a4_row9_col13,#T_ea0a4_row11_col0{
#             background-color:  #b8dc00;
#             color:  #000000;
#         }#T_ea0a4_row2_col7,#T_ea0a4_row2_col9,#T_ea0a4_row5_col9,#T_ea0a4_row5_col11{
#             background-color:  #bcde00;
#             color:  #000000;
#         }#T_ea0a4_row2_col10,#T_ea0a4_row5_col1,#T_ea0a4_row6_col4,#T_ea0a4_row10_col7,#T_ea0a4_row11_col10,#T_ea0a4_row18_col13{
#             background-color:  #d2e900;
#             color:  #000000;
#         }#T_ea0a4_row2_col11,#T_ea0a4_row5_col4,#T_ea0a4_row5_col12,#T_ea0a4_row9_col1,#T_ea0a4_row9_col2,#T_ea0a4_row9_col6,#T_ea0a4_row9_col12,#T_ea0a4_row11_col1,#T_ea0a4_row20_col2{
#             background-color:  #c2e100;
#             color:  #000000;
#         }#T_ea0a4_row2_col12,#T_ea0a4_row2_col14,#T_ea0a4_row3_col10,#T_ea0a4_row9_col10,#T_ea0a4_row10_col8,#T_ea0a4_row10_col13,#T_ea0a4_row14_col10,#T_ea0a4_row16_col13{
#             background-color:  #cee700;
#             color:  #000000;
#         }#T_ea0a4_row2_col13,#T_ea0a4_row5_col13,#T_ea0a4_row8_col3,#T_ea0a4_row11_col5,#T_ea0a4_row17_col7,#T_ea0a4_row19_col6{
#             background-color:  #a8d400;
#             color:  #000000;
#         }#T_ea0a4_row3_col1{
#             background-color:  #b4da00;
#             color:  #000000;
#         }#T_ea0a4_row3_col2,#T_ea0a4_row3_col12,#T_ea0a4_row6_col10,#T_ea0a4_row11_col2,#T_ea0a4_row18_col3,#T_ea0a4_row18_col7,#T_ea0a4_row18_col10{
#             background-color:  #d6eb00;
#             color:  #000000;
#         }#T_ea0a4_row3_col13,#T_ea0a4_row10_col2,#T_ea0a4_row11_col7,#T_ea0a4_row14_col9,#T_ea0a4_row15_col10{
#             background-color:  #a2d100;
#             color:  #000000;
#         }#T_ea0a4_row3_col14,#T_ea0a4_row14_col1,#T_ea0a4_row14_col12,#T_ea0a4_row19_col14{
#             background-color:  #9ecf00;
#             color:  #000000;
#         }#T_ea0a4_row4_col1,#T_ea0a4_row4_col4{
#             background-color:  #fffe00;
#             color:  #000000;
#         }#T_ea0a4_row4_col2,#T_ea0a4_row4_col6,#T_ea0a4_row10_col3{
#             background-color:  #eaf500;
#             color:  #000000;
#         }#T_ea0a4_row4_col3,#T_ea0a4_row4_col7,#T_ea0a4_row18_col12,#T_ea0a4_row20_col1{
#             background-color:  #e2f100;
#             color:  #000000;
#         }#T_ea0a4_row4_col5,#T_ea0a4_row5_col8,#T_ea0a4_row10_col11{
#             background-color:  #dcee00;
#             color:  #000000;
#         }#T_ea0a4_row4_col10,#T_ea0a4_row4_col12{
#             background-color:  #fff800;
#             color:  #000000;
#         }#T_ea0a4_row4_col11,#T_ea0a4_row4_col14,#T_ea0a4_row10_col5,#T_ea0a4_row10_col12{
#             background-color:  #d8ec00;
#             color:  #000000;
#         }#T_ea0a4_row5_col0,#T_ea0a4_row8_col7{
#             background-color:  #80c000;
#             color:  #000000;
#         }#T_ea0a4_row5_col3,#T_ea0a4_row10_col1,#T_ea0a4_row11_col6,#T_ea0a4_row11_col14{
#             background-color:  #b6db00;
#             color:  #000000;
#         }#T_ea0a4_row5_col5,#T_ea0a4_row16_col4,#T_ea0a4_row19_col9{
#             background-color:  #9acd00;
#             color:  #000000;
#         }#T_ea0a4_row5_col6,#T_ea0a4_row17_col2{
#             background-color:  #daed00;
#             color:  #000000;
#         }#T_ea0a4_row5_col10,#T_ea0a4_row6_col6,#T_ea0a4_row11_col8,#T_ea0a4_row13_col1{
#             background-color:  #a0d000;
#             color:  #000000;
#         }#T_ea0a4_row5_col14,#T_ea0a4_row11_col9,#T_ea0a4_row16_col10{
#             background-color:  #a4d200;
#             color:  #000000;
#         }#T_ea0a4_row6_col1,#T_ea0a4_row14_col2,#T_ea0a4_row17_col4,#T_ea0a4_row19_col0,#T_ea0a4_row19_col5{
#             background-color:  #badd00;
#             color:  #000000;
#         }#T_ea0a4_row6_col3,#T_ea0a4_row8_col12,#T_ea0a4_row11_col13,#T_ea0a4_row15_col13,#T_ea0a4_row19_col4{
#             background-color:  #88c400;
#             color:  #000000;
#         }#T_ea0a4_row6_col9,#T_ea0a4_row19_col3,#T_ea0a4_row19_col11{
#             background-color:  #aad500;
#             color:  #000000;
#         }#T_ea0a4_row6_col13,#T_ea0a4_row16_col6,#T_ea0a4_row17_col10,#T_ea0a4_row19_col1{
#             background-color:  #94ca00;
#             color:  #000000;
#         }#T_ea0a4_row7_col0{
#             background-color:  #ff9000;
#             color:  #000000;
#         }#T_ea0a4_row7_col1{
#             background-color:  #f6fb00;
#             color:  #000000;
#         }#T_ea0a4_row7_col3{
#             background-color:  #ffea00;
#             color:  #000000;
#         }#T_ea0a4_row7_col4{
#             background-color:  #ffd000;
#             color:  #000000;
#         }#T_ea0a4_row7_col5,#T_ea0a4_row12_col9,#T_ea0a4_row21_col11{
#             background-color:  #ffba00;
#             color:  #000000;
#         }#T_ea0a4_row7_col6,#T_ea0a4_row21_col7{
#             background-color:  #ffc000;
#             color:  #000000;
#         }#T_ea0a4_row7_col7,#T_ea0a4_row7_col12{
#             background-color:  #ffd600;
#             color:  #0
# <style  type="text/css" >
# #T_a86bd_row0_col0,#T_a86bd_row1_col0,#T_a86bd_row2_col0,#T_a86bd_row3_col0,#T_a86bd_row4_col0,#T_a86bd_row5_col0,#T_a86bd_row6_col0,#T_a86bd_row7_col0,#T_a86bd_row8_col0,#T_a86bd_row9_col0,#T_a86bd_row10_col0,#T_a86bd_row11_col0,#T_a86bd_row12_col0,#T_a86bd_row13_col0,#T_a86bd_row14_col0{
#             background-color:  #000000;
#         }#T_a86bd_row0_col1,#T_a86bd_row1_col10,#T_a86bd_row2_col3,#T_a86bd_row3_col3,#T_a86bd_row4_col3,#T_a86bd_row7_col17,#T_a86bd_row8_col16,#T_a86bd_row13_col15,#T_a86bd_row14_col15{
#             background-color:  #acd600;
#         }#T_a86bd_row0_col2,#T_a86bd_row4_col5,#T_a86bd_row6_col11,#T_a86bd_row6_col17,#T_a86bd_row8_col19,#T_a86bd_row14_col8{
#             background-color:  #a8d400;
#         }#T_a86bd_row0_col3,#T_a86bd_row4_col14,#T_a86bd_row5_col14,#T_a86bd_row7_col19{
#             background-color:  #9ecf00;
#         }#T_a86bd_row0_col4,#T_a86bd_row9_col1,#T_a86bd_row10_col6,#T_a86bd_row11_col6,#T_a86bd_row12_col6{
#             background-color:  #cae500;
#         }#T_a86bd_row0_col5,#T_a86bd_row6_col8{
#             background-color:  #80c000;
#         }#T_a86bd_row0_col6,#T_a86bd_row1_col11,#T_a86bd_row2_col19,#T_a86bd_row8_col8,#T_a86bd_row8_col15{
#             background-color:  #88c400;
#         }#T_a86bd_row0_col7,#T_a86bd_row5_col10,#T_a86bd_row12_col1,#T_a86bd_row13_col9{
#             background-color:  #d0e800;
#         }#T_a86bd_row0_col8{
#             background-color:  #5aad00;
#         }#T_a86bd_row0_col9,#T_a86bd_row2_col2,#T_a86bd_row5_col6,#T_a86bd_row7_col3,#T_a86bd_row7_col11,#T_a86bd_row8_col3,#T_a86bd_row8_col11,#T_a86bd_row8_col14{
#             background-color:  #b0d800;
#         }#T_a86bd_row0_col10,#T_a86bd_row1_col3,#T_a86bd_row3_col11,#T_a86bd_row6_col14,#T_a86bd_row12_col15{
#             background-color:  #a2d100;
#         }#T_a86bd_row0_col11{
#             background-color:  #82c100;
#         }#T_a86bd_row0_col12,#T_a86bd_row1_col12{
#             background-color:  #ffde00;
#         }#T_a86bd_row0_col13,#T_a86bd_row0_col20{
#             background-color:  #008000;
#         }#T_a86bd_row0_col14{
#             background-color:  #6ab500;
#         }#T_a86bd_row0_col15{
#             background-color:  #269300;
#         }#T_a86bd_row0_col16{
#             background-color:  #1e8f00;
#         }#T_a86bd_row0_col17,#T_a86bd_row9_col8{
#             background-color:  #8ec700;
#         }#T_a86bd_row0_col18,#T_a86bd_row13_col16,#T_a86bd_row14_col13{
#             background-color:  #c8e400;
#         }#T_a86bd_row0_col19,#T_a86bd_row1_col19{
#             background-color:  #86c300;
#         }#T_a86bd_row0_col21,#T_a86bd_row6_col20{
#             background-color:  #f0f800;
#         }#T_a86bd_row1_col1,#T_a86bd_row2_col1,#T_a86bd_row2_col9,#T_a86bd_row10_col17,#T_a86bd_row13_col19{
#             background-color:  #bedf00;
#         }#T_a86bd_row1_col2,#T_a86bd_row4_col6,#T_a86bd_row5_col3,#T_a86bd_row6_col3,#T_a86bd_row9_col16{
#             background-color:  #aed700;
#         }#T_a86bd_row1_col4,#T_a86bd_row2_col4,#T_a86bd_row9_col10,#T_a86bd_row10_col10{
#             background-color:  #d8ec00;
#         }#T_a86bd_row1_col5,#T_a86bd_row4_col16,#T_a86bd_row5_col19{
#             background-color:  #9acd00;
#         }#T_a86bd_row1_col6,#T_a86bd_row1_col17,#T_a86bd_row3_col16,#T_a86bd_row4_col19{
#             background-color:  #94ca00;
#         }#T_a86bd_row1_col7{
#             background-color:  #f6fb00;
#         }#T_a86bd_row1_col8,#T_a86bd_row1_col16,#T_a86bd_row4_col15,#T_a86bd_row9_col13{
#             background-color:  #6eb700;
#         }#T_a86bd_row1_col9,#T_a86bd_row4_col2,#T_a86bd_row5_col2,#T_a86bd_row6_col5,#T_a86bd_row7_col5,#T_a86bd_row11_col11{
#             background-color:  #b8dc00;
#         }#T_a86bd_row1_col13{
#             background-color:  #1a8d00;
#         }#T_a86bd_row1_col14,#T_a86bd_row2_col14,#T_a86bd_row3_col14,#T_a86bd_row10_col15{
#             background-color:  #92c900;
#         }#T_a86bd_row1_col15{
#             background-color:  #2c9600;
#         }#T_a86bd_row1_col18,#T_a86bd_row6_col10,#T_a86bd_row12_col5,#T_a86bd_row13_col2,#T_a86bd_row13_col6,#T_a86bd_row13_col11{
#             background-color:  #d2e900;
#         }#T_a86bd_row1_col20,#T_a86bd_row6_col9,#T_a86bd_row7_col9,#T_a86bd_row8_col9,#T_a86bd_row9_col2,#T_a86bd_row9_col9,#T_a86bd_row10_col5,#T_a86bd_row11_col5,#T_a86bd_row12_col11{
#             background-color:  #c2e100;
#         }#T_a86bd_row1_col21{
#             background-color:  #fff200;
#         }#T_a86bd_row2_col5,#T_a86bd_row2_col6,#T_a86bd_row2_col11,#T_a86bd_row13_col13{
#             background-color:  #a0d000;
#         }#T_a86bd_row2_col7,#T_a86bd_row9_col20{
#             background-color:  #f8fc00;
#         }#T_a86bd_row2_col8{
#             background-color:  #72b900;
#         }#T_a86bd_row2_col10,#T_a86bd_row5_col5,#T_a86bd_row9_col11,#T_a86bd_row10_col11{
#             background-color:  #b6db00;
#         }#T_a86bd_row2_col12,#T_a86bd_row3_col12{
#             background-color:  #ffd800;
#         }#T_a86bd_row2_col13{
#             background-color:  #229100;
#         }#T_a86bd_row2_col15{
#             background-color:  #46a300;
#         }#T_a86bd_row2_col16{
#             background-color:  #78bc00;
#         }#T_a86bd_row2_col17{
#             background-color:  #96cb00;
#         }#T_a86bd_row2_col18,#T_a86bd_row3_col18,#T_a86bd_row7_col10,#T_a86bd_row8_col10{
#             background-color:  #d4ea00;
#         }#T_a86bd_row2_col20,#T_a86bd_row4_col4,#T_a86bd_row7_col18,#T_a86bd_row12_col10,#T_a86bd_row14_col2{
#             background-color:  #deef00;
#         }#T_a86bd_row2_col21{
#             background-color:  #ffe000;
#         }#T_a86bd_row3_col1,#T_a86bd_row3_col9,#T_a86bd_row4_col9,#T_a86bd_row5_col9,#T_a86bd_row8_col2,#T_a86bd_row10_col3,#T_a86bd_row11_col17{
#             background-color:  #c0e000;
#         }#T_a86bd_row3_col2,#T_a86bd_row8_col17,#T_a86bd_row9_col14,#T_a86bd_row10_col16{
#             background-color:  #b2d900;
#         }#T_a86bd_row3_col4,#T_a86bd_row11_col10,#T_a86bd_row14_col5{
#             background-color:  #dcee00;
#         }#T_a86bd_row3_col5,#T_a86bd_row4_col11,#T_a86bd_row5_col16{
#             background-color:  #a4d200;
#         }#T_a86bd_row3_col6,#T_a86bd_row9_col19,#T_a86bd_row10_col19{
#             background-color:  #aad500;
#         }#T_a86bd_row3_col7{
#             background-color:  #ffea00;
#         }#T_a86bd_row3_col8,#T_a86bd_row6_col15,#T_a86bd_row7_col15{
#             background-color:  #74ba00;
#         }#T_a86bd_row3_col10,#T_a86bd_row4_col10,#T_a86bd_row11_col2,#T_a86bd_row12_col2,#T_a86bd_row12_col3,#T_a86bd_row12_col9,#T_a86bd_row13_col14,#T_a86bd_row14_col16{
#             background-color:  #cee700;
#         }#T_a86bd_row3_col13{
#             background-color:  #42a100;
#         }#T_a86bd_row3_col15{
#             background-color:  #5eaf00;
#         }#T_a86bd_row3_col17,#T_a86bd_row11_col8,#T_a86bd_row12_col8{
#             background-color:  #98cc00;
#         }#T_a86bd_row3_col19,#T_a86bd_row10_col8{
#             background-color:  #90c800;
#         }#T_a86bd_row3_col20,#T_a86bd_row5_col4,#T_a86bd_row6_col4,#T_a86bd_row9_col18{
#             background-color:  #e2f100;
#         }#T_a86bd_row3_col21{
#             background-color:  #ffdc00;
#         }#T_a86bd_row4_col1,#T_a86bd_row5_col1,#T_a86bd_row6_col1,#T_a86bd_row7_col6,#T_a86bd_row8_col6,#T_a86bd_row9_col6,#T_a86bd_row10_col2,#T_a86bd_row10_col9,#T_a86bd_row11_col14,#T_a86bd_row11_col16,#T_a86bd_row12_col16,#T_a86bd_row12_col17{
#             background-color:  #c4e200;
#         }#T_a86bd_row4_col7,#T_a86bd_row5_col7{
#             background-color:  #ffda00;
#         }#T_a86bd_row4_col8{
#             background-color:  #7cbe00;
#         }#T_a86bd_row4_col12,#T_a86bd_row8_col21,#T_a86bd_row14_col14{
#             background-color:  #ffbe00;
#         }#T_a86bd_row4_col13{
#             background-color:  #44a200;
#         }#T_a86bd_row4_col17,#T_a86bd_row5_col11,#T_a86bd_row5_col17,#T_a86bd_row6_col16,#T_a86bd_row7_col14,#T_a86bd_row7_col16{
#             background-color:  #a6d300;
#         }#T_a86bd_row4_col18,#T_a86bd_row5_col18,#T_a86bd_row6_col18,#

# %%
#cm = sns.color_palette("blend:red,yellow,green", as_cmap=True)
#pd.crosstab(shares_viz['Year'], shares_viz['Month'])

#seasonal_indexes[si]
seasonally_adjusted = pd.DataFrame()

for s in sector_performance_return.columns:
    
    s_ = pd.DataFrame(sector_performance_return[s])
    #print(sector_performance_return[s])
    years = []
    quarters = []
    
    for d in s_.index:
        d_ = d.strftime('%Y-%m-%d')
        #print(d_)

        datem = dt.datetime.strptime(d_, "%Y-%m-%d")
        years.append(str(datem.year))
        #print(datem.year)       # 2021
        m = datem.month
        d = datem.day
        if(len(str(m))==1):
            m = '0'+str(m)
        else:
            m = str(m)
        if(len(str(d))==1):
            d = '0'+str(d)
        else:
            d = str(d)
        quarters.append(m+"-"+d)
        
    s_['Quarter'] = quarters
    si_ = seasonal_indexes.loc[s]
    
    modified = pd.DataFrame()
    #print(si_.index)
    for s_i_ in si_.index:
        #print(s_i_)
        #when it finds the last date (which hopefully isn't a quarter date)
        if(np.sum(np.array(si)==s_i_)==0):
            #print("don't modify")
            #print(s_i_)
            match = []
            for entry in si:
                if(int(s_i_.rsplit("-")[0])<=int(entry.rsplit("-")[0])):
                    match = entry
                    break            

            delta_months = int(match.rsplit("-")[0])-int(s_i_.rsplit("-")[0])
            delta_days_ = int(match.rsplit("-")[1])-int(s_i_.rsplit("-")[1])
            
            delta_days = int(delta_months*(91.25/3)+delta_days_)
            #daily interest
            
            #print(delta_days)
            #print(seasonal_indexes.loc[s].loc[match])
            seasonal_index_to_daily = (1+seasonal_indexes.loc[s].loc[match])**(1/91.25)-1
            #print("Seasonal Index to Daily Discounted Interest Rate:",seasonal_index_to_daily)
            daily_extrapolated = (1+seasonal_index_to_daily)**delta_days-1
            #print(daily_extrapolated)
            #print("Daily ^ delta_days:",daily_extrapolated)
            
            #print(match)
            #print(s_i_)
            seasonally_adjusted_column = pd.DataFrame([seasonal_indexes.loc[s].loc[match] - daily_extrapolated],columns=[s],index=[s_.index[-1]])
            
            
        else:
            seasonally_adjusted_column = pd.DataFrame(s_[s][s_['Quarter']==s_i_] - seasonal_indexes.loc[s].loc[s_i_],columns=[s])
        modified = pd.concat([modified,seasonally_adjusted_column],axis=0)
        modified.sort_index(inplace=True)
    #print(modified)
    seasonally_adjusted = pd.concat([seasonally_adjusted,modified],axis=1)

print("Comparative to Seasonal Indexes, tells you who is over or underperforming.")
print("This is Seasonal Index - Extrapolated Current Quarter.")
print("+: seasonal > current")
print("-: current > seasonal")

print("Note if the final data in the prices ends on a quarter, this will aggregate into the seasonal_index above and there will be no comparison")
    
    
std_indexes_seas_adj = pd.DataFrame()
seasonal_indexes_seas_adj = pd.DataFrame()

temp_ = pd.DataFrame(seasonally_adjusted.T.iloc[:,-1])
temp_.columns = pd.DataFrame(seasonally_adjusted.T.iloc[:,-1]).columns.strftime('%Y-%m-%d')
display(temp_.sort_values(by=temp_.columns[0],ascending=False).style.background_gradient(cmap = cm,axis=0))

#display(seasonally_adjusted[seasonally_adjusted.columns.difference(si)].style.background_gradient(cmap = cm,axis=0))

for spr in seasonally_adjusted.columns:
    #print(spr)
    s = seasonally_adjusted[[spr]]
    #print(s)
    years = []
    quarters = []
    for d in seasonally_adjusted[spr].index:
        d_ = d.strftime('%Y-%m-%d')
        #print(d_)

        datem = dt.datetime.strptime(d_, "%Y-%m-%d")
        years.append(str(datem.year))
        #print(datem.year)       # 2021
        m = datem.month
        d = datem.day
        if(len(str(m))==1):
            m = '0'+str(m)
        else:
            m = str(m)
        if(len(str(d))==1):
            d = '0'+str(d)
        else:
            d = str(d)
        quarters.append(m+"-"+d)

    s['Years'] = years
    s['Quarters'] = quarters
    ct = pd.crosstab(s['Years'], s['Quarters'],values=s[spr],aggfunc=np.mean).mean(axis=0).sort_index()
    ct.columns = [spr]
    #print(ct)
    
    ct_std = pd.crosstab(s['Years'], s['Quarters'],values=s[spr],aggfunc=np.mean).std(axis=0).sort_index()
    ct_std.columns = [spr]
    
    std_indexes_seas_adj = pd.concat([std_indexes_seas_adj,ct_std],axis=1)
    seasonal_indexes_seas_adj = pd.concat([seasonal_indexes_seas_adj,ct],axis=1)

seasonal_indexes_seas_adj.columns = seasonally_adjusted.columns

std_indexes_seas_adj.columns = seasonally_adjusted.columns
    
seasonal_indexes_seas_adj = seasonal_indexes_seas_adj.T

std_indexes_seas_adj = std_indexes_seas_adj.T

sector_performances_sea_adj = pd.DataFrame()
sector_performances_values_sea_adj = pd.DataFrame()
for c in seasonally_adjusted.T.columns:
    temp = pd.DataFrame(seasonally_adjusted.T[c].sort_values(ascending=False).index,columns=[c])
    temp2 = pd.DataFrame(seasonally_adjusted.T[c].sort_values(ascending=False),columns=[c])
    temp2.reset_index(drop=True,inplace=True)    
    sector_performances_sea_adj = pd.concat([sector_performances_sea_adj,temp],axis=1)
    sector_performances_values_sea_adj = pd.concat([sector_performances_values_sea_adj,temp2],axis=1)

A = sector_performances_values_sea_adj
B = sector_performances_sea_adj

df_sea_adj = B.style.apply(b_g,cmap='RdYlGn')
display(df_sea_adj)
# Out:
# Comparative to Seasonal Indexes, tells you who is over or underperforming.
# This is Seasonal Index - Extrapolated Current Quarter.
# +: seasonal > current
# -: current > seasonal
# Note if the final data in the prices ends on a quarter, this will aggregate into the seasonal_index above and there will be no comparison
# <style  type="text/css" >
# #T_fd3f3_row0_col0{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_fd3f3_row1_col0{
#             background-color:  #088400;
#             color:  #f1f1f1;
#         }#T_fd3f3_row2_col0{
#             background-color:  #88c400;
#             color:  #000000;
#         }#T_fd3f3_row3_col0{
#             background-color:  #d0e800;
#             color:  #000000;
#         }#T_fd3f3_row4_col0{
#             background-color:  #d6eb00;
#             color:  #000000;
#         }#T_fd3f3_row5_col0,#T_fd3f3_row6_col0{
#             background-color:  #dcee00;
#             color:  #000000;
#         }#T_fd3f3_row7_col0{
#             background-color:  #deef00;
#             color:  #000000;
#         }#T_fd3f3_row8_col0{
#             background-color:  #e6f300;
#             color:  #000000;
#         }#T_fd3f3_row9_col0{
#             background-color:  #f4fa00;
#             color:  #000000;
#         }#T_fd3f3_row10_col0{
#             background-color:  #f6fb00;
#             color:  #000000;
#         }#T_fd3f3_row11_col0{
#             background-color:  #ffba00;
#             color:  #000000;
#         }#T_fd3f3_row12_col0{
#             background-color:  #ffaa00;
#             color:  #000000;
#         }#T_fd3f3_row13_col0{
#             background-color:  #ff3000;
#             color:  #f1f1f1;
#         }#T_fd3f3_row14_col0{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_fd3f3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2022-06-17</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd3f3_level0_row0" class="row_heading level0 row0" >Information Technology ETF</th>
#                         <td id="T_fd3f3_row0_col0" class="data row0 col0" >0.105318</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row1" class="row_heading level0 row1" >Consumer Discretionary ETF</th>
#                         <td id="T_fd3f3_row1_col0" class="data row1 col0" >0.103945</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row2" class="row_heading level0 row2" >Energy ETF</th>
#                         <td id="T_fd3f3_row2_col0" class="data row2 col0" >0.083099</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row3" class="row_heading level0 row3" >Materials ETF</th>
#                         <td id="T_fd3f3_row3_col0" class="data row3 col0" >0.071426</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row4" class="row_heading level0 row4" >SP1500</th>
#                         <td id="T_fd3f3_row4_col0" class="data row4 col0" >0.070498</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row5" class="row_heading level0 row5" >SP500</th>
#                         <td id="T_fd3f3_row5_col0" class="data row5 col0" >0.069644</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row6" class="row_heading level0 row6" >SP600</th>
#                         <td id="T_fd3f3_row6_col0" class="data row6 col0" >0.069416</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row7" class="row_heading level0 row7" >SP400</th>
#                         <td id="T_fd3f3_row7_col0" class="data row7 col0" >0.069126</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row8" class="row_heading level0 row8" >Health Care ETF</th>
#                         <td id="T_fd3f3_row8_col0" class="data row8 col0" >0.067854</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row9" class="row_heading level0 row9" >Communication Services ETF</th>
#                         <td id="T_fd3f3_row9_col0" class="data row9 col0" >0.065505</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row10" class="row_heading level0 row10" >Real Estate ETF</th>
#                         <td id="T_fd3f3_row10_col0" class="data row10 col0" >0.065298</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row11" class="row_heading level0 row11" >Financials ETF</th>
#                         <td id="T_fd3f3_row11_col0" class="data row11 col0" >0.052571</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row12" class="row_heading level0 row12" >Industrials ETF</th>
#                         <td id="T_fd3f3_row12_col0" class="data row12 col0" >0.050194</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row13" class="row_heading level0 row13" >Consumer Staples ETF</th>
#                         <td id="T_fd3f3_row13_col0" class="data row13 col0" >0.030500</td>
#             </tr>
#             <tr>
#                         <th id="T_fd3f3_level0_row14" class="row_heading level0 row14" >Utilities ETF</th>
#                         <td id="T_fd3f3_row14_col0" class="data row14 col0" >0.022444</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# #T_a3ef9_row0_col0,#T_a3ef9_row1_col0,#T_a3ef9_row2_col0,#T_a3ef9_row3_col0,#T_a3ef9_row4_col0,#T_a3ef9_row5_col0,#T_a3ef9_row6_col0,#T_a3ef9_row7_col0,#T_a3ef9_row8_col0,#T_a3ef9_row9_col0,#T_a3ef9_row10_col0,#T_a3ef9_row11_col0,#T_a3ef9_row12_col0,#T_a3ef9_row13_col0,#T_a3ef9_row14_col0{
#             background-color:  #000000;
#         }#T_a3ef9_row0_col1,#T_a3ef9_row5_col4,#T_a3ef9_row6_col17,#T_a3ef9_row12_col14,#T_a3ef9_row14_col13{
#             background-color:  #b8dc00;
#         }#T_a3ef9_row0_col2{
#             background-color:  #78bc00;
#         }#T_a3ef9_row0_col3,#T_a3ef9_row1_col2,#T_a3ef9_row6_col14,#T_a3ef9_row7_col14,#T_a3ef9_row7_col19{
#             background-color:  #9cce00;
#         }#T_a3ef9_row0_col4,#T_a3ef9_row3_col5,#T_a3ef9_row5_col3,#T_a3ef9_row6_col3,#T_a3ef9_row7_col11{
#             background-color:  #acd600;
#         }#T_a3ef9_row0_col5,#T_a3ef9_row6_col19,#T_a3ef9_row11_col15,#T_a3ef9_row11_col21,#T_a3ef9_row12_col15{
#             background-color:  #98cc00;
#         }#T_a3ef9_row0_col6,#T_a3ef9_row8_col16{
#             background-color:  #80c000;
#         }#T_a3ef9_row0_col7,#T_a3ef9_row6_col5,#T_a3ef9_row6_col10,#T_a3ef9_row6_col20,#T_a3ef9_row7_col5,#T_a3ef9_row9_col4,#T_a3ef9_row10_col17,#T_a3ef9_row13_col11{
#             background-color:  #c8e400;
#         }#T_a3ef9_row0_col8{
#             background-color:  #3e9f00;
#         }#T_a3ef9_row0_col9,#T_a3ef9_row2_col20,#T_a3ef9_row9_col6,#T_a3ef9_row9_col11,#T_a3ef9_row11_col14{
#             background-color:  #b0d800;
#         }#T_a3ef9_row0_col10,#T_a3ef9_row5_col19{
#             background-color:  #96cb00;
#         }#T_a3ef9_row0_col11,#T_a3ef9_row14_col8{
#             background-color:  #7ebf00;
#         }#T_a3ef9_row0_col12{
#             background-color:  #f6fb00;
#         }#T_a3ef9_row0_col13,#T_a3ef9_row0_col15{
#             background-color:  #249200;
#         }#T_a3ef9_row0_col14,#T_a3ef9_row6_col13,#T_a3ef9_row9_col8{
#             background-color:  #66b300;
#         }#T_a3ef9_row0_col16{
#             background-color:  #1e8f00;
#         }#T_a3ef9_row0_col17,#T_a3ef9_row2_col2,#T_a3ef9_row3_col11,#T_a3ef9_row4_col11,#T_a3ef9_row8_col19{
#             background-color:  #a0d000;
#         }#T_a3ef9_row0_col18,#T_a3ef9_row1_col4,#T_a3ef9_row2_col4,#T_a3ef9_row3_col17,#T_a3ef9_row4_col2,#T_a3ef9_row5_col2,#T_a3ef9_row6_col6,#T_a3ef9_row7_col3,#T_a3ef9_row7_col6,#T_a3ef9_row8_col3,#T_a3ef9_row8_col6,#T_a3ef9_row8_col11,#T_a3ef9_row10_col14{
#             background-color:  #aed700;
#         }#T_a3ef9_row0_col19,#T_a3ef9_row1_col21,#T_a3ef9_row7_col16,#T_a3ef9_row13_col8{
#             background-color:  #7cbe00;
#         }#T_a3ef9_row0_col20{
#             background-color:  #008000;
#         }#T_a3ef9_row0_col21{
#             background-color:  #7abd00;
#         }#T_a3ef9_row1_col1,#T_a3ef9_row1_col18,#T_a3ef9_row7_col17,#T_a3ef9_row8_col17,#T_a3ef9_row10_col2,#T_a3ef9_row11_col2,#T_a3ef9_row13_col14{
#             background-color:  #badd00;
#         }#T_a3ef9_row1_col3,#T_a3ef9_row1_col17,#T_a3ef9_row4_col6,#T_a3ef9_row5_col11,#T_a3ef9_row13_col15,#T_a3ef9_row13_col16,#T_a3ef9_row13_col21{
#             background-color:  #a4d200;
#         }#T_a3ef9_row1_col5,#T_a3ef9_row2_col17,#T_a3ef9_row5_col6,#T_a3ef9_row9_col19,#T_a3ef9_row14_col15{
#             background-color:  #a6d300;
#         }#T_a3ef9_row1_col6,#T_a3ef9_row12_col13,#T_a3ef9_row13_col13{
#             background-color:  #94ca00;
#         }#T_a3ef9_row1_col7,#T_a3ef9_row14_col20{
#             background-color:  #eef700;
#         }#T_a3ef9_row1_col8,#T_a3ef9_row2_col13{
#             background-color:  #46a300;
#         }#T_a3ef9_row1_col9,#T_a3ef9_row3_col4,#T_a3ef9_row6_col2,#T_a3ef9_row9_col3,#T_a3ef9_row10_col11,#T_a3ef9_row11_col19,#T_a3ef9_row14_col16{
#             background-color:  #b2d900;
#         }#T_a3ef9_row1_col10,#T_a3ef9_row2_col6,#T_a3ef9_row3_col6,#T_a3ef9_row5_col14,#T_a3ef9_row11_col16,#T_a3ef9_row12_col21{
#             background-color:  #9acd00;
#         }#T_a3ef9_row1_col11,#T_a3ef9_row3_col21,#T_a3ef9_row4_col19,#T_a3ef9_row4_col21,#T_a3ef9_row5_col21,#T_a3ef9_row6_col21,#T_a3ef9_row9_col15,#T_a3ef9_row10_col15{
#             background-color:  #8ec700;
#         }#T_a3ef9_row1_col12{
#             background-color:  #fcfe00;
#         }#T_a3ef9_row1_col13{
#             background-color:  #309800;
#         }#T_a3ef9_row1_col14{
#             background-color:  #82c100;
#         }#T_a3ef9_row1_col15{
#             background-color:  #269300;
#         }#T_a3ef9_row1_col16{
#             background-color:  #44a200;
#         }#T_a3ef9_row1_col19,#T_a3ef9_row2_col21,#T_a3ef9_row8_col15,#T_a3ef9_row9_col16{
#             background-color:  #88c400;
#         }#T_a3ef9_row1_col20{
#             background-color:  #a2d100;
#         }#T_a3ef9_row2_col1,#T_a3ef9_row3_col10,#T_a3ef9_row9_col17,#T_a3ef9_row10_col3{
#             background-color:  #c0e000;
#         }#T_a3ef9_row2_col3,#T_a3ef9_row2_col5,#T_a3ef9_row3_col3,#T_a3ef9_row6_col11,#T_a3ef9_row10_col19{
#             background-color:  #a8d400;
#         }#T_a3ef9_row2_col7,#T_a3ef9_row13_col1{
#             background-color:  #f0f800;
#         }#T_a3ef9_row2_col8{
#             background-color:  #48a400;
#         }#T_a3ef9_row2_col9,#T_a3ef9_row3_col20,#T_a3ef9_row8_col2,#T_a3ef9_row9_col2,#T_a3ef9_row10_col6,#T_a3ef9_row11_col6{
#             background-color:  #b6db00;
#         }#T_a3ef9_row2_col10,#T_a3ef9_row3_col2,#T_a3ef9_row4_col3,#T_a3ef9_row9_col14,#T_a3ef9_row14_col21{
#             background-color:  #aad500;
#         }#T_a3ef9_row2_col11,#T_a3ef9_row7_col21,#T_a3ef9_row8_col21{
#             background-color:  #90c800;
#         }#T_a3ef9_row2_col12{
#             background-color:  #fffa00;
#         }#T_a3ef9_row2_col14,#T_a3ef9_row3_col14,#T_a3ef9_row3_col19,#T_a3ef9_row10_col16,#T_a3ef9_row11_col13{
#             background-color:  #8cc600;
#         }#T_a3ef9_row2_col15,#T_a3ef9_row2_col16{
#             background-color:  #4ca600;
#         }#T_a3ef9_row2_col18,#T_a3ef9_row3_col1,#T_a3ef9_row11_col3,#T_a3ef9_row12_col6,#T_a3ef9_row13_col6,#T_a3ef9_row14_col6{
#             background-color:  #c2e100;
#         }#T_a3ef9_row2_col19{
#             background-color:  #8ac500;
#         }#T_a3ef9_row3_col7,#T_a3ef9_row4_col12{
#             background-color:  #fff000;
#         }#T_a3ef9_row3_col8,#T_a3ef9_row4_col8,#T_a3ef9_row4_col13{
#             background-color:  #52a900;
#         }#T_a3ef9_row3_col9,#T_a3ef9_row4_col1,#T_a3ef9_row4_col5,#T_a3ef9_row4_col10,#T_a3ef9_row5_col10,#T_a3ef9_row8_col4,#T_a3ef9_row12_col3,#T_a3ef9_row13_col19{
#             background-color:  #c4e200;
#         }#T_a3ef9_row3_col12{
#             background-color:  #fff800;
#         }#T_a3ef9_row3_col13{
#             background-color:  #50a800;
#         }#T_a3ef9_row3_col15,#T_a3ef9_row6_col8{
#             background-color:  #5aad00;
#         }#T_a3ef9_row3_col16,#T_a3ef9_row10_col8,#T_a3ef9_row11_col8{
#             background-color:  #6cb600;
#         }#T_a3ef9_row3_col18,#T_a3ef9_row7_col10,#T_a3ef9_row8_col5,#T_a3ef9_row8_col10,#T_a3ef9_row9_col5,#T_a3ef9_row9_col10,#T_a3ef9_row11_col17{
#             background-color:  #cae500;
#         }#T_a3ef9_row4_col4,#T_a3ef9_row4_col17,#T_a3ef9_row5_col17,#T_a3ef9_row7_col2,#T_a3ef9_row11_col11{
#             background-color:  #b4da00;
#         }#T_a3ef9_row4_col7{
#             background-color:  #ffec00;
#         }#T_a3ef9_row4_col9,#T_a3ef9_row4_col18,#T_a3ef9_row5_col9,#T_a3ef9_row5_col18,#T_a3ef9_row6_col9,#T_a3ef9_row6_col18,#T_a3ef9_row7_col9,#T_a3ef9_row10_col5,#T_a3ef9_row10_col10,#T_a3ef9_row10_col20,#T_a3ef9_row11_col5,#T_a3ef9_row11_col10,#T_a3ef9_row14_col3{
#             background-color:  #cee700;
#         }#T_a3ef9_row4_col14,#T_a3ef9_row9_col21,#T_a3ef9_row10_col21{
#             background-color:  #92c900;
#         }#T_a3ef9_row4_col15{
#             background-color:  #5cae00;
#         }#T_a3ef9_row4_col16{
#             background-color:  #6eb700;
#         }#T_a3ef9_row4_col20,#T_a3ef9_row7_col4{
#             background-color:  #bedf00;
#         }#T_a3ef9_row5_col1,#T_a3ef9_row6_col1,#T_a3ef9_row8_col9,#T_a3e

# %%
index_performance = []
for v in spdr_indexes['Symbol'].values:
    index_performance.append([v,screener.loc[v]['risk_trend_factor']])
temp_i = pd.DataFrame(index_performance,index=spdr_indexes.index)
temp_i.columns = ['Symbol','risk_trend_factor']
index_risk_sorted = pd.DataFrame(index_performance,columns=['Symbol','risk_trend_factor'],index=spdr_indexes.index).sort_values(by='risk_trend_factor',ascending=False).reset_index()
index_risk_sorted.columns = ['Index','Symbol','risk_trend_factor']
index_risk_sorted
# Out:
#     Index Symbol  risk_trend_factor
# 0   SP500    SPY          -3.791861
# 1  SP1500   SPTM          -3.879022
# 2   SP400   MDYG          -5.134573
# 3   SP600    SLY          -5.242200

# %%
sector_performance = []
for v in vanguard_sectors['Symbol'].values:
    sector_performance.append([v,screener.loc[v]['risk_trend_factor']])
temp_v = vanguard_sectors.reset_index()
temp_v.columns = ['Sector','Symbol']
sectors_risk_sorted = pd.DataFrame(sector_performance,columns=['Symbol','risk_trend_factor']).merge(temp_v, on='Symbol', how='left').sort_values(by='risk_trend_factor',ascending=False)    
sectors_risk_sorted
# Out:
#    Symbol  risk_trend_factor                      Sector
# 3     VDE          -0.123306                  Energy ETF
# 2     VDC          -2.283970        Consumer Staples ETF
# 10    VPU          -2.520459               Utilities ETF
# 9     VNQ          -3.053370             Real Estate ETF
# 8     VAW          -3.165271               Materials ETF
# 5     VHT          -3.323632             Health Care ETF
# 6     VIS          -4.514668             Industrials ETF
# 4     VFH          -4.617891              Financials ETF
# 1     VCR          -4.721407  Consumer Discretionary ETF
# 7     VGT          -4.954472  Information Technology ETF
# 0     VOX          -8.783598  Communication Services ETF

# %%
print("Rolling Quarterly Mean Return")
plt.plot(sector_performance_Q_smoothed_return)
plt.legend([*[i for i in spdr_indexes.index],*[v for v in vanguard_sectors.index]],loc=2,fontsize=7)
plt.show()
# Out:
# Rolling Quarterly Mean Return

# %%
print ("Quarterly Returns")
for v in sector_performance_return.T.index:
    subset = pd.DataFrame(sector_performance_return.T.loc[v])
    subset.columns = ['Return']
    plt.plot(subset)
    plt.xticks(subset.index, rotation=45)
plt.legend(sector_performance_return.T.index,loc=2)    
plt.show()
# Out:
# Quarterly Returns

# %%
plt.plot(seasonal_indexes[si].T)
plt.legend(seasonal_indexes[si].T.columns,loc=2,fontsize=8)
plt.show()

# %%
threshold = .975

# %%
screener_sorted_ = screener_sorted.reset_index().merge(stock_indexes,on='Symbol',how='left')

screener_good = screener_sorted_[screener_sorted_['risk_trend_factor']!='missing']

risk_trend_threshold = screener_good['risk_trend_factor'].quantile(q=[threshold]).values[0]

# %%
risk_trend_threshold
# Out:
# 0.051078501531639196

# %%
stock_sectors = stock_fundamentals['sector']

# %%
temp = stock_sectors.reset_index()
temp.columns = ['Symbol','Sector']
sector_merged = screener[['risk_trend_factor']].merge(temp, on='Symbol', how='right')
temp_sm = sector_merged.merge(sp1500_index_df, on='Symbol', how='left').set_index('Symbol')
temp_sm.columns = ['risk_trend_factor', 'Sector', 'index']
temp_sm = temp_sm.merge(spdr_indexes.reset_index(), on='index', how='left')
temp_sm.columns = ['risk_trend_factor', 'Sector', 'index','index_Symbol']
temp_sm.index = sector_merged['Symbol']

for spdr_ in range(0,len(spdr_indexes['Symbol'].values)):
    spdr__ = spdr_indexes['Symbol'].values[spdr_]
    spdr__i = spdr_indexes['Symbol'].index[spdr_]
    temp_sm.iloc[np.where(temp_sm.index==spdr__)][['index']] = spdr__i
    temp_sm.iloc[np.where(temp_sm.index==spdr__)][['index_Symbol']] = spdr__

# %%
screener[['risk_trend_factor']].replace(['missing','error'], np.NaN).dropna().hist()
# Out:
# array([[<AxesSubplot:title={'center':'risk_trend_factor'}>]], dtype=object)

# %%
len(screener)
# Out:
# 1520

# %%
prices_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Symbol',
#        'trailing_1yr_max', 'MIN_Lookback_One_Year', 'MIN_Lookback_2_Months',
#        'MIN_Lookback_1_Months', 'trailing_1yr_min', 'supply_trend_1yr',
#        'supply_trend_60d', 'supply_trend_30d', 'trailing_60d_max',
#        'trailing_60d_min', 'trailing_30d_max', 'trailing_30d_min', '90dSMA',
#        '90dSDev', 'TP', '21dstdTP', '21dMA-TP', '21dBOLU', '21dBOLD',
#        'trailing_risk_40d_max', 'trailing_risk_40d_min', 'risk_per_share',
#        '30d_vol', '30d_vol_2yr', 'volume_factor', '1YMF', 'risk_trend_factor'],
#       dtype='object')

# %%
risk_screened = screener_good[(screener_good['risk_trend_factor']>risk_trend_threshold) & (screener_good['volume_factor']!= 'missing')]
risk_screened = risk_screened.merge(temp, on='Symbol', how='left')
print(risk_screened.columns)
temp_df = risk_screened[['Symbol','latest_p','MIN_Lookback_One_Year', 'MIN_Lookback_2_Months', 'MIN_Lookback_1_Months','risk_trend_factor','volume_factor','adf','hurst','Sector','Market Index']]
temp_df.set_index('Symbol',inplace=True)
pd.concat([temp_df,temp_sm],axis=0)
# Out:
# Index(['Symbol', 'max_2y', 'min_2y', 'std_2y', 'mean_2y', 'max_1y', 'min_1y',
#        'std_1y', 'mean_1y', 'latest_p', '2yr_close_0pct', '2yr_close_2pct',
#        '2yr_close_9pct', '2yr_close_25pct', '2yr_close_50pct',
#        '2yr_close_75pct', '2yr_close_91pct', '2yr_close_98pct',
#        '2yr_close_100pct', '1yr_close_0pct', '1yr_close_2pct',
#        '1yr_close_9pct', '1yr_close_25pct', '1yr_close_50pct',
#        '2yr_close_75pct', '1yr_close_91pct', '1yr_close_98pct',
#        '1yr_close_100pct', 'risk_trend_factor', 'supply_trend_1yr',
#        'supply_trend_60d', 'supply_trend_30d', 'vol_30d_2yr', 'pct_1yr',
#        'pct_2yr', 'MIN_Lookback_One_Year', 'MIN_Lookback_2_Months',
#        'MIN_Lookback_1_Months', 'vol_30d', 'volume_factor', 'adf', 'hurst',
#        '1YMF', 'Market Index', 'Sector'],
#       dtype='object')
#          latest_p MIN_Lookback_One_Year MIN_Lookback_2_Months  \
# Symbol
# ACC     64.230003             49.209999             65.019997
# MTOR    35.939999                 32.93             36.279999
# TVTY    32.130001             27.870001             32.889999
# BANF    94.860001             77.379997                 86.82
# Y           830.5            737.890015            862.869995
# ...           ...                   ...                   ...
# ODFL          NaN                   NaN                   NaN
# EW            NaN                   NaN                   NaN
# PCRX          NaN                   NaN                   NaN
# CBOE          NaN                   NaN                   NaN
# PCAR          NaN                   NaN                   NaN
#
#        MIN_Lookback_1_Months risk_trend_factor volume_factor       adf  \
# Symbol
# ACC                65.019997         10.926848      2.134689  0.978004
# MTOR               36.279999          5.065223      1.664475  0.319063
# TVTY               32.889999          2.341879      1.643789  0.518794
# BANF                   86.82          2.011991      1.135864  0.955166
# Y                 862.869995          1.771776       1.56538  0.382688
# ...                      ...               ...           ...       ...
# ODFL                     NaN         -5.178995           NaN       NaN
# EW                       NaN         -2.677285           NaN       NaN
# PCRX                     NaN         -2.849253           NaN       NaN
# CBOE                     NaN         -4.539896           NaN       NaN
# PCAR                     NaN         -4.010257           NaN       NaN
#
#            hurst              Sector Market Index  index index_Symbol
# Symbol
# ACC     0.420279         Real Estate        SP400    NaN          NaN
# MTOR     0.43585               error        SP600    NaN          NaN
# TVTY    0.448871               error        SP600    NaN          NaN
# BANF    0.536352               error        SP600    NaN          NaN
# Y       0.459685  Financial Services        SP400    NaN          NaN
# ...          ...                 ...          ...    ...          ...
# ODFL         NaN         Industrials          NaN  SP500          SPY
# EW           NaN          Healthcare          NaN  SP500          SPY
# PCRX         NaN          Healthcare          NaN  SP600          SLY
# CBOE         NaN  Financial Services          NaN  SP500          SPY
# PCAR         NaN         Industrials          NaN  SP500          SPY
#
# [1555 rows x 12 columns]

# %%
screened_final_set = risk_screened

# %%
fundamentals_quarterlies = pickle.load(open('./fundamental.pkl', 'rb'))

# %%
fundamental_entries = [e[0] for e in fundamentals_quarterlies]

# %%
list_ = []
for i in index_risk_sorted['Symbol'].values:
    list_.append(i)
for i in sectors_risk_sorted['Symbol'].values:
    list_.append(i)
for i in screened_final_set['Symbol'].values:
    list_.append(i)
indexes = np.unique(list_, return_index=True)[1]
list__ = [list_[index] for index in sorted(indexes)]

# %%
summary = pd.DataFrame()

# %%
summary = pd.DataFrame()
for name_ in np.unique(prices_df['Symbol'].values):
    summary = pd.concat([summary,pd.DataFrame(prices_df[prices_df['Symbol']==name_][['Symbol','MIN_Lookback_One_Year', 'MIN_Lookback_2_Months', 'MIN_Lookback_1_Months','risk_trend_factor','volume_factor']].iloc[-1]).T.reset_index().set_index('Symbol')],axis=0)

# %%
threshold
# Out:
# 0.975

# %%
threshold_value = summary.dropna()['risk_trend_factor'].quantile([threshold])

# %% [markdown]
# temp_sm

# %%
summary
# Out:
#             index MIN_Lookback_One_Year MIN_Lookback_2_Months  \
# Symbol
# A      2022-06-17            147.679993            179.570007
# AA     2022-06-17             44.419998             98.089996
# AAL    2022-06-17             22.549999             22.549999
# AAN    2022-06-17                   NaN             35.439999
# AAON   2022-06-17                 81.25             83.790001
# ...           ...                   ...                   ...
# ZIMV   2022-06-17                   NaN                   NaN
# ZION   2022-06-17             60.650002             75.440002
# ZTS    2022-06-17            187.320007            249.270004
# ZUMZ   2022-06-17             50.060001             55.099998
# ZYXI   2022-06-17             16.263636             16.263636
#
#        MIN_Lookback_1_Months risk_trend_factor volume_factor
# Symbol
# A                 179.570007         -9.088903      1.131711
# AA                 98.089996         -3.704472       0.98632
# AAL                22.549999         -3.126898      0.707794
# AAN                35.439999               NaN           NaN
# AAON               83.790001         -10.22921      1.041044
# ...                      ...               ...           ...
# ZIMV                     NaN               NaN           NaN
# ZION               75.440002         -4.600841      0.978199
# ZTS               249.270004          -6.71488      1.095466
# ZUMZ               55.099998         -5.921479      1.674903
# ZYXI               16.263636        -10.695845      0.673641
#
# [1519 rows x 6 columns]

# %%
temp_sm.columns
# Out:
# Index(['risk_trend_factor', 'Sector', 'index', 'index_Symbol'], dtype='object')

# %%
risk_trend_factor_sector_dict = dict()
for s in sectors['Symbol']:
    risk_trend_factor_sector_dict[s] = prices_df[prices_df['Symbol']==s]['risk_trend_factor'].values[-1]
    
risk_trend_factor_sector_dict['error']='error'

# %%
inv_dict_map = {v: k for k, v in dict_indexes.items()}
inv_dict_map[np.nan] = 'error'
in_ = [inv_dict_map[t[0]] for t in temp_sm[['index']].values]
se_ = [dict_sectors[t[0]] for t in temp_sm[['Sector']].values]
#temp_sm[['Sector','index']]
symbols_w_index_sector = pd.concat([pd.DataFrame(se_,columns=['index'],index=temp_sm.index),pd.DataFrame(in_,columns=['sector'],index=temp_sm.index)],axis=1)

# %%
symbols_w_sector_rtf = pd.DataFrame([risk_trend_factor_sector_dict[s] for s in symbols_w_index_sector['index'].values],columns=['sector_risk_trend_factor'],index=symbols_w_index_sector.index)

# %%
rick_screener = pd.concat([summary.sort_values(by='risk_trend_factor',ascending=False).iloc[:,1:],symbols_w_index_sector,symbols_w_sector_rtf,temp_sm[['index','Sector']]],axis=1)

# %%
rick_screener_final = rick_screener.dropna()[rick_screener.dropna()['risk_trend_factor'].values > threshold_value.values[0]]

# %%
rick_screener_final
# Out:
#        MIN_Lookback_One_Year MIN_Lookback_2_Months MIN_Lookback_1_Months  \
# Symbol
# ACC                49.209999             65.019997             65.019997
# MTOR                   32.93             36.279999             36.279999
# TVTY               27.870001             32.889999             32.889999
# BANF               77.379997                 86.82                 86.82
# Y                 737.890015            862.869995            862.869995
# SAFM              177.479996                 200.0                 200.0
# SJI                    29.24                 35.32                 35.32
# LNTH               25.790001             64.139999             69.738998
# ROG               206.130005             274.51001             274.51001
# TWI                    11.82                 15.77             18.889999
# PBF                18.780001             30.129999                 32.41
# GO                     36.77                 36.77                 37.82
# HRB                    26.23                 28.17             34.959999
# AZPN              162.559998            169.220001            191.460007
# CEIX                   18.93             50.389999             55.259998
# PSB               165.850006            189.229996            189.830002
# MCK               204.660004            333.440002            339.940002
# GCP                27.780001             32.279999             32.279999
# WRB                54.953335             71.269997             71.529999
# FCN               147.380005            167.279999            170.649994
# XOM                64.800003             91.510002             92.919998
# MANT                    92.0                  92.0             94.730003
# SM                 24.780001             43.689999             43.689999
# DINO               39.389999             40.950001             48.290001
# PLAB                   14.56             20.299999             20.299999
# MPC                64.839996             91.879997             98.290001
# LLY               235.850006                 314.0                 314.0
# VLO                84.949997            111.519997            131.690002
# APA                24.299999             45.220001                 45.27
# PPC                26.280001             29.700001             30.559999
# MRO                    14.16             27.719999                  29.0
# DVN                    31.99             64.980003                 73.18
# UTHR              212.619995            218.380005            218.380005
# VIVO               27.450001             28.719999             28.719999
# ROCC                   25.59                 42.66                 42.66
# COP                61.779999            107.519997            108.300003
# OXY                    32.52             63.240002             69.169998
# MGPI                   76.68             97.610001                 104.0
#
#        risk_trend_factor volume_factor  index sector sector_risk_trend_factor  \
# Symbol
# ACC            10.926848      2.134689    VNQ   MDYG                 -3.05337
# MTOR            5.065223      1.664475  error    SLY                    error
# TVTY            2.341879      1.643789  error    SLY                    error
# BANF            2.011991      1.135864  error    SLY                    error
# Y               1.771776       1.56538    VFH   MDYG                -4.617891
# SAFM            1.751569      1.334104    VDC   MDYG                 -2.28397
# SJI             1.295238      0.791297  error    SLY                    error
# LNTH            1.178774      1.823238    VHT    SLY                -3.323632
# ROG             1.068804      0.980653  error    SLY                    error
# TWI             0.931088      1.389288    VIS    SLY                -4.514668
# PBF             0.887657      0.835417    VDE    SLY                -0.123306
# GO              0.842135      1.191531    VDC   MDYG                 -2.28397
# HRB             0.731411      0.963511    VCR   MDYG                -4.721407
# AZPN            0.719312      0.677612    VGT   MDYG                -4.954472
# CEIX            0.677246      1.548727    VDE    SLY                -0.123306
# PSB              0.57675      2.540601  error   MDYG                    error
# MCK             0.573819      1.048139    VHT    SPY                -3.323632
# GCP             0.502796       1.87078  error    SLY                    error
# WRB             0.374885      1.220256    VFH    SPY                -4.617891
# FCN             0.359043      0.694756  error   MDYG                    error
# XOM             0.347413      1.153813    VDE    SPY                -0.123306
# MANT            0.320637      2.782348    VGT    SLY                -4.954472
# SM              0.305033      0.640686    VDE    SLY                -0.123306
# DINO            0.269915      1.094012    VDE   MDYG                -0.123306
# PLAB            0.264129      2.163783    VGT    SLY                -4.954472
# MPC             0.209274      1.221452    VDE    SPY                -0.123306
# LLY             0.187301      0.967658    VHT    SPY                -3.323632
# VLO             0.182835        1.3872    VDE    SPY                -0.123306
# APA             0.181301      0.999608    VDE    SPY                -0.123306
# PPC             0.177885      1.275425    VDC   MDYG                 -2.28397
# MRO             0.151107      1.000459    VDE    SPY                -0.123306
# DVN             0.148782      1.104104    VDE    SPY                -0.123306
# UTHR            0.139402      1.481235    VHT   MDYG                -3.323632
# VIVO            0.109712      0.591657  error    SLY                    error
# ROCC            0.108216      1.213679    VDE    SLY                -0.123306
# COP              0.10252       0.95084    VDE    SPY                -0.123306
# OXY             0.093736      1.190976    VDE    SPY                -0.123306
# MGPI            0.074244      1.204144  error    SLY                    error
#
#         index              Sector
# Symbol
# ACC     SP400         Real Estate
# MTOR    SP600               error
# TVTY    SP600               error
# BANF    SP600               error
# Y       SP400  Financial Services
# SAFM    SP400  Consumer Defensive
# SJI     SP600               error
# LNTH    SP600          Healthcare
# ROG     SP600               error
# TWI     SP600         Industrials
# PBF     SP600              Energy
# GO      SP400  Consumer Defensive
# HRB     SP400   Consumer Cyclical
# AZPN    SP400          Technology
# CEIX    SP600              Energy
# PSB     SP400               error
# MCK     SP500          Healthcare
# GCP     SP600               error
# WRB     SP500  Financial Services
# FCN     SP400               error
# XOM     SP500              Energy
# MANT    SP600          Technology
# SM      SP600              Energy
# DINO    SP400              Energy
# PLAB    SP600          Technology
# MPC     SP500              Energy
# LLY     SP500          Healthcare
# VLO     SP500              Energy
# APA     SP500              Energy
# PPC     SP400  Consumer Defensive
# MRO     SP500              Energy
# DVN     SP500              Energy
# UTHR    SP400          Healthcare
# VIVO    SP600               error
# ROCC    SP600              Energy
# COP     SP500              Energy
# OXY     SP500              Energy
# MGPI    SP600               error

# %%
rick_screener_final.to_csv('rick_screener_final.csv')

# %%
#completed_fred_pvt_df = completed_fred_pvt.asfreq('D').reindex(nyse_dates.index).interpolate(method='time')
completed_fred_pvt_df = completed_fred_pvt

temp_new = completed_fred_pvt.asfreq('D').interpolate(method='time',limit_area='inside').reindex(nyse_dates.index)
temp_dates = pd.date_range(completed_fred_pvt.index[0].strftime('%Y-%m-%d'), completed_fred_pvt.index[-1].strftime('%Y-%m-%d'), freq='D').map(lambda t: t.strftime('%Y-%m-%d'))
nyse_inbetween_temp_dates = nyse_dates.index[(nyse_dates.index >= temp_dates[0]) & (nyse_dates.index <= temp_dates[-1])]
temp_new = temp_new.reindex(nyse_inbetween_temp_dates)

completed_fred_pvt_df = temp_new
completed_fred_pvt_df.columns = [name[1] for name in completed_fred_pvt_df.columns]

# %%
fred_friendly_names = ['Market volatility','Consumer Confidence','Unemployment','Inflation','Interest Rates','10 Year to 3 Month','Recession Indicator']
fred_names = ['VIXCLS','UMCSENT','UNRATE','FPCPITOTLZGUSA','FEDFUNDS','T10Y3M','USREC']
print('nominal,','pct_change,','pct_change().cumsum')
for pos in range(0,len(fred_names)):
    print(fred_friendly_names[pos])
    name = fred_names[pos]
    
    f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=False,figsize=(15,6))
    ax1.plot(completed_fred_pvt_df[name])
    ax2.plot(completed_fred_pvt_df[name].pct_change())
    ax3.plot(completed_fred_pvt_df[name].pct_change().cumsum())
    plt.show()
# Out:
# nominal, pct_change, pct_change().cumsum
# Market volatility
# Consumer Confidence
# Unemployment
# Inflation
# Interest Rates
# 10 Year to 3 Month
# Recession Indicator

# %%
#screener['vol_30d_2yr']

# %%
# Out:
# Index(['2022-06-19', '2022-06-26', '2022-07-03', '2022-07-10', '2022-07-17',
#        '2022-07-24', '2022-07-31', '2022-08-07', '2022-08-14', '2022-08-21',
#        '2022-08-28', '2022-09-04', '2022-09-11'],
#       dtype='object')

# %%
#pd.DataFrame(np.mean(np.exp(final_model.get_prediction(start=end,end=(end + dt.timedelta(92)).strftime('%Y-%m-%d')).summary_frame())[['mean','pi_lower']],axis=1)).iloc[0].values[0]
#[s,e_return,s_date,stop_loss_price,days_delta,discounted_return,qtr_return,test_score_mean,test_score_std,mean_revert_flag,p_metrics['pi_lower'].values[0],p_metrics['pi_upper'].values[0]]
#screener['latest_p'].loc[decision_metrics_df.index]
# Out:
# 87.44243789162297

# %%
# Out:
# 'Fri'

# %%
# Out:
#             Adj Close
# 2017-02-24  44.051205
# 2017-03-03  44.145416
# 2017-03-10  43.639832
# 2017-03-17  44.116169
# 2017-03-24  43.316540
# ...               ...
# 2022-05-20  64.260002
# 2022-05-27  68.790001
# 2022-06-03  68.489998
# 2022-06-10  64.839996
# 2022-06-17  59.930000
#
# [278 rows x 1 columns]

# %%
import statsmodels
from statsmodels.tsa.exponential_smoothing.ets import ETSModel

client = Client('192.168.3.100:8786')

#tscv = expanding_window(initial =52*2, horizon = 13,period = 26)

batchClearLimit = round(len(list__)/7)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
 
decision_metrics = []

print("adf < .05 or .01, mean reverting")
print("Hurst")
print("> .5 - The time series is mean reverting.")
print("= .5 - The time series is a Geometric Brownian Motion.")
print("< .5 - The time series is trending.")
"""*spdr_indexes['Symbol'].values,*vanguard_sectors['Symbol'].values,"""
for s in list__:

    #for s in ['CEIX']:
    msize = 2
    date_form = DateFormatter("%Y-%m-%d")

    metrics_df_ = pd.DataFrame(pd.DataFrame(screener.loc[s].dropna()).T[['volume_factor','latest_p','vol_30d_2yr','pct_2yr','adf','hurst']])

    subset=prices[prices['Symbol']==s]

    dates = []
    for t in subset.index.values:
        d = pd.Timestamp(t).strftime('%Y-%m-%d')
        dates.append(d)
        dto = datetime.strptime(d, '%Y-%m-%d').date()

    old_ordinal = [datetime.strptime(i, '%Y-%m-%d').toordinal() for i in dates]
    new_ordinal = old_ordinal + md.date2num(np.datetime64('0000-12-31'))
    x = new_ordinal    

    lookup_index_ = []

    labels = list()
    print("symbol:",s)   

    try:
        symbol_sector = dict_sectors[sector_merged[sector_merged['Symbol']==s]['Sector'].values[0]]
        print("sector:",dict_sectors_reverse[symbol_sector])
    except:
        if(symbol_sector=='error'):
            if(np.sum([vanguard_sectors['Symbol'].values==s])):
                symbol_sector = s
                print("sector:",dict_sectors_reverse[symbol_sector])
        else:
            symbol_sector = 'error'
    if(symbol_sector=='error'):
        if(np.sum([vanguard_sectors['Symbol'].values==s])):
            symbol_sector = s
            print("sector:",dict_sectors_reverse[symbol_sector])
        else:
            symbol_sector = 'error'
            print("sector:",'error')

    symbol_index = temp_sm.loc[s]['index_Symbol']

    try:
        matched_index_name = spdr_indexes.iloc[np.where(spdr_indexes['Symbol'].values==s)].index[0]
    except:
        try:
            matched_index_name = temp_sm.loc[s]['index']
        except:
            matched_index_name = "none"

    print("Index:",matched_index_name)

    print("vol_30d_2yr:",screener.iloc[np.where(screener.index==s)]['vol_30d_2yr'][0])
    #print("1YMF:",subset['1YMF'].values[-1])
    print("Sector 1YMF:",screener[screener.index==s]['1YMF'][0])
    print("1YMF:",screener.iloc[np.where(screener.index==s)]['1YMF'][0])
    print("risk trend factor:",screener.iloc[np.where(screener.index==s)]['risk_trend_factor'][0])

    temp = pd.DataFrame(stock_fundamentals.loc[s])
    print(temp[np.array(temp!='error')].replace([np.inf,'inf','error', -np.inf], np.nan).dropna().T)

    last_date = pd.DataFrame(subset.iloc[-1][['21dBOLD','21dMA-TP','21dBOLU']],index=[prices[prices['Symbol']==s].index[-1].strftime('%Y-%m-%d')]).index[0]

    bbands = pd.DataFrame(subset.iloc[-1][['Adj Close','21dBOLD','21dMA-TP','21dBOLU','90dSMA','90dSDev']]).T
    bbands['90d_lower'] = bbands['90dSMA']-bbands['90dSDev']*2
    bbands['90d_upper'] = bbands['90dSMA']+bbands['90dSDev']*2

    bbands.index = [last_date]
    display(bbands)

    display(metrics_df_)

    mean_revert_flag = False

    if(metrics_df_['adf'][0]<.05):
        print("ADFuller H0 rejected @ .05, Mean Reverting TS")
        if(bbands['Adj Close'][0]<bbands['90d_lower'][0]):
            colored_text = colored(255, 0, 0, "Quarter Mean Reverting buy signal")
            print(colored_text)
            mean_revert_flag = True
        if(bbands['Adj Close'][0]<bbands['21dBOLU'][0]):
            colored_text = colored(255, 0, 0, "Month Mean Reverting buy signal")
            print(colored_text)
            mean_revert_flag = True    

    l_axis_legend = pd.DataFrame(['symbol', 'trailing_1yr_max', 'trailing_1yr_min', '30d_vol_2yr','risk_trend_factor/linear','supply_trend_1yr'],index=['blue','green','red','orange','black','yellow'],columns=['legend'])

    r_axis_legend = pd.DataFrame(['sector','index'],index=['magenta','cyan'],columns=['legend'])

    display_side_by_side([l_axis_legend, r_axis_legend], ['l axis', 'r axis'])        

    f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=False,figsize=(22,5))
    ax1.plot(subset['30d_vol_2yr'],color='orange')
    ax1.set_xticklabels(subset[['30d_vol_2yr']].dropna().index, rotation = 45)

    locator = matplotlib.dates.AutoDateLocator()
    formatter = matplotlib.dates.ConciseDateFormatter(locator)

    ax1.xaxis.set_major_locator(locator)
    ax1.xaxis.set_major_formatter(formatter)


    ax1.xaxis.set_major_formatter(date_form)

    #plt.title('30d_vol_2yr')
    ax2.plot(subset['risk_trend_factor'],color='black')
    ax2.set_xticklabels(subset[['risk_trend_factor']].dropna().index, rotation = 45)

    locator = matplotlib.dates.AutoDateLocator()
    formatter = matplotlib.dates.ConciseDateFormatter(locator)

    ax2.xaxis.set_major_locator(locator)
    ax2.xaxis.set_major_formatter(formatter)

    ax2.xaxis.set_major_formatter(date_form)
    #plt.title('risk_trend_factor')

    #fig, ax1 = plt.subplots()   

    ax4 = ax3.twinx()

    if(symbol_sector=='error'):
        pass
    else:
        if(np.sum(vanguard_sectors['Symbol'].values==s)>0):
            pass
        else:
            #print("sector",)
            #print("else_sector:",dict_sectors_reverse[s])            
            print("Sector 1YMF:",screener[screener.index==symbol_sector]['1YMF'][0])
            print("Sector Volume Factor:",screener.iloc[np.where(screener.index==symbol_sector)]['volume_factor'][0])
            print("Sector Risk Trend Factor:",screener.iloc[np.where(screener.index==symbol_sector)]['risk_trend_factor'][0])
            ax4.plot(x, (prices[prices['Symbol']==symbol_sector]['Adj Close']).iloc[-len(subset):],marker = '.',markersize=msize,color='m',linestyle=(0, (3, 10, 1, 10)))
            #ax2.plot(x, prices[prices['Symbol']==symbol_sector]['Adj Close'],marker = '.',markersize=msize,color='m',linestyle=(0, (3, 10, 1, 10)))        
            #plt.legend([temp_sm.loc[s]['Sector']])
            #labels_ax2.append(temp_sm.loc[s]['Sector'])
            #plt.show()

    if(str(temp_sm.loc[s]['index_Symbol'])!='nan'):
        if(temp_sm.loc[s]['index_Symbol']!='error'):
            #print(temp_sm.loc[s]['index_Symbol'])
            print("Index 1YMF:",screener[screener.index==temp_sm.loc[s]['index_Symbol']]['1YMF'][0])
            print("Index Volume Factor:",screener.iloc[np.where(screener.index==temp_sm.loc[s]['index_Symbol'])]['volume_factor'][0])
            print("Index Risk Trend Factor:",screener.iloc[np.where(screener.index==temp_sm.loc[s]['index_Symbol'])]['risk_trend_factor'][0])

            ax4.plot(x, prices[prices['Symbol']==temp_sm.loc[s]['index_Symbol']]['Adj Close'].iloc[-len(subset):],marker = '.',markersize=msize,color='c',linestyle=(0, (1, 10)))
            #plt.plot()
            #plt.legend([temp_sm.loc[s]['index']])
            #labels_ax2.append(temp_sm.loc[s]['index'])
            #plt.show()

    y= subset['Adj Close']

    slope, intercept, r, p, std_err = stats.linregress(x, y)

    mymodel = list(map(myfunc, x))

    ax3.plot(x, y,marker = '.',markersize=msize, color = 'b')
    ax3.plot(x, subset['trailing_1yr_max'],marker = '.',markersize=msize, color = 'g')
    ax3.plot(x, subset['trailing_1yr_min'],marker = '.',markersize=msize, color = 'r')
    #ax1.plot(x, subset['risk_trend_factor'],marker = '.',markersize=msize, color = 'orange')

    ax3.plot(x, subset['supply_trend_1yr'],marker = '.',markersize=msize, color = 'y')

    ax3.plot(x, mymodel, color = 'k')

    #for l in ['symbol','1yrMax','1yrMin','risk_trend_factor','supply_trend_1yr','linear']:
        #labels.append(l)

    l = matplotlib.dates.AutoDateLocator()
    f = matplotlib.dates.ConciseDateFormatter(l)    

    ax3.set_xticklabels(ax3.get_xticks(), rotation = 45)

    locator = matplotlib.dates.AutoDateLocator()
    formatter = matplotlib.dates.ConciseDateFormatter(locator)

    ax3.xaxis.set_major_locator(locator)
    ax3.xaxis.set_major_formatter(formatter)

    ax3.xaxis.set_major_formatter(date_form)
    plt.show()

    print("ets next 13 weeks")

    #take last nyse date and extrapolate weeks from that point
    #starting from next week
    newDates = pd.date_range((subset.index[-1] + dt.timedelta(7)).strftime('%Y-%m-%d'), (subset.index[-1] + dt.timedelta(92)).strftime('%Y-%m-%d'), freq='W-'+nyse_dates.index[-1].strftime('%a')).map(lambda t: t.strftime('%Y-%m-%d'))

    data = subset[['Adj Close']].asfreq('D').interpolate().asfreq('W-'+subset.index[-1].strftime('%a'))

    if(np.where(np.array(list__)==s)[0][0]%batchClearLimit==0):        
        client.restart()

    cv_inner = TimeSeriesSplit(n_splits=11,test_size=13)

    #has to be different makeup than cv_inner because there is no randomization.  Recommend a number that isn't a divisor of cv_inner's n_splits to ensure training is mixed up and not aligned
    cv_outer = TimeSeriesSplit(n_splits=10,test_size=13)

    outer_results = []

    #sm.tsa.statespace.ExponentialSmoothing
    """
    flags = []
    seasonal_flags1 = ['add','mul',None]

    trend_flags2 = ['add','mul',None]

    damped__trend_flags3 = [True,False]

    for sf in seasonal_flags1:
        for dt_ in trend_flags2:
            if(dt_ is None):          
                for d_ in damped__trend_flags3:
                    flags.append([sf,dt_,d_])
    """

    flags = [['add', 'add', True],\
     ['add', 'add', False],\
     ['add', 'mul', True],\
     ['add', 'mul', False],\
     ['add', None],\
     ['mul', 'add', True],\
     ['mul', 'add', False],\
     ['mul', 'mul', True],\
     ['mul', 'mul', False],\
     ['mul', None],\
     [None, 'add', True],\
     [None, 'add', False],\
     [None, 'mul', True],\
     [None, 'mul', False],\
     [None, None]]

    #print(flags)

    #flags = [['T','T'],['T','F'],['F','F'],['F','T']]       

    rmse_inner_flags = []

    for flag in flags:

        npa = []

        for trainv_ix, test_ix in cv_inner.split(data.index):

            npa.append([data.iloc[trainv_ix],data.iloc[test_ix],ETSModel,flag])

        future = client.map(evaluate_ets, npa)        

        rmses_inner = []
        #flag_order = []
        #my intent was to capture future objects vs results and this gave me results
        for f in as_completed(future):
            #exclude errors
            if(f.status=="error"):
                #pass
                #this causes errors with [flag,rmse] being passed by evaluate_ets
                rmses_inner.append([np.nan])
            else:
                rmses_inner.append(f.result())

        #I don't want to keep track of flag here
        #flag_order = [r[0] for r in results_rmses].copy()

        rmse_ = [r[1] for r in rmses_inner].copy()
        #print(rmse_)
        #print(flag)
        rmse_inner_flags.append([flag,np.nanmean(rmse_),np.nanstd(rmse_)])

    #rmse_scores = []
    #flag_rmses = []

    #for fn_ in range(0,len(flags)):
        #flag_ = flags[fn_]
        #rmse_scores.append([flag_rmses[fn_],rmses[fn_][1]])

    print("inner cv scores:")
    inner_rmse_df = pd.DataFrame(rmse_inner_flags,columns=['flags','mean','std'])
    #print("inner cv scores:",[r[rmses)
    #print("inner cv sdevs:",sdevs)

    scores = inner_rmse_df['mean'].values
    sdevs = inner_rmse_df['std'].values
    best_model = inner_rmse_df['flags'].values[np.argmin(scores)]

    print("best model:",best_model)
    print("best inner cv score, sdev (11 folds):",scores[np.argmin(scores)],sdevs[np.argmin(scores)])

    npa = []

    for trainv_ix, test_ix in cv_outer.split(data.index):

        npa.append([data.iloc[trainv_ix],data.iloc[test_ix],ETSModel,best_model])

    future = client.map(evaluate_ets, npa)
    results_rmses_outer = []

    #my intent was to capture future objects vs results and this gave me results
    for f in as_completed(future):
        #exclude errors
        if(f.status=="error"):
            #pass
            results_rmses_outer.append([np.nan])
        else:
            results_rmses_outer.append(f.result()) 

    test_score_mean = np.nanmean([r[1] for r in results_rmses_outer])
    test_score_std = np.nanstd([r[1] for r in results_rmses_outer])

    #test_score = [np.nanmean(rmse_outer_df['mean'].values),np.nanstd(rmse_outer_df['mean'].values)]
    print("test cv mean error, stdev (10 folds):",test_score_mean,test_score_std)
    
    #final_model=ETSModel(np.log(data),initialization_method='heuristic',seasonal=52,trend=F1,damped_trend=F2).fit()    
    flag = best_model
    if(len(flag)==2):
        if(flag[1] is None):
            final_model = ETSModel(np.log(data['Adj Close']),initialization_method='heuristic',seasonal=flag[0],trend=flag[1],dates=data.index).fit()
        else:
            final_model = ETSModel(np.log(data['Adj Close']),initialization_method='heuristic',seasonal=flag[0],seasonal_periods=52,trend=flag[1],dates=data.index).fit()
    else:
        final_model = ETSModel(np.log(data['Adj Close']),initialization_method='heuristic',seasonal=flag[0],seasonal_periods=52,trend=flag[1],damped_trend=flag[2],dates=data.index).fit()
        
    df_pred = np.exp(final_model.get_prediction(start=end,end=(end + dt.timedelta(92)).strftime('%Y-%m-%d')).summary_frame())
    #df_conf = np.exp(final_model.get_prediction(start=end,end=(end + dt.timedelta(92)).strftime('%Y-%m-%d')).pred_int(alpha = .05))
    #df_conf.columns = ['ci_lower','ci_upper']
    
    #final_model = ETSModel(np.log(data['Adj Close']),initialization_method='heuristic',seasonal=['add','mul','None'][0],seasonal_periods=52,trend=['add','mul','None'][0],damped_trend=['True','False'][0],dates=data.index).fit()
    #pred = final_model.get_prediction(start=end,end=(end + dt.timedelta(92)).strftime('%Y-%m-%d'))
    
    #final_model.get_prediction(start=end,end=(end + dt.timedelta(92)).strftime('%Y-%m-%d')).summary_frame()
    
    #df_pred = np.exp(pred.summary_frame(alpha=0.05))
    #df_pred = np.exp(pred.summary(alpha=0.05))
    s_date = df_pred.index[np.argmax(df_pred['mean'].values)].strftime('%Y-%m-%d')
    
    print("sell date:",s_date)
    e_return = np.array((np.max(df_pred['mean'].values)-metrics_df_['latest_p'])/metrics_df_['latest_p'])[0]
    p_metrics = pd.DataFrame(df_pred.iloc[np.argmax(df_pred['mean'].values)]).T
    #c_metrics = pd.DataFrame(df_conf.iloc[np.argmax(df_pred['mean'].values)]).T
    #print(c_metrics)
    print("expected return:",e_return)
        
    days_delta = (datetime.strptime(s_date, '%Y-%m-%d') - datetime.strptime(end.strftime('%Y-%m-%d'), '%Y-%m-%d')).days
    discounted_return = (1+e_return)**(1/days_delta)-1
    qtr_return = (1+discounted_return)**92

    print("discounted return:",discounted_return)
    
    print("quarter return:",qtr_return)
    
    #used to help filter at the end, not sdevs is chosen based on min score
    stop_loss_price = pd.DataFrame(np.mean(np.exp(final_model.get_prediction(start=end,end=(end + dt.timedelta(92)).strftime('%Y-%m-%d')).summary_frame())[['mean','pi_lower']],axis=1)).iloc[0].values[0]
    decision_metrics.append([s,e_return,s_date,stop_loss_price,days_delta,discounted_return,qtr_return,test_score_mean,test_score_std,mean_revert_flag,p_metrics['pi_lower'].values[0],p_metrics['pi_upper'].values[0]])
    
    plt.plot(data.tail(13))
    plt.plot(df_pred)
    #plt.plot(df_conf)
    plt.xticks([*data.tail(13).index.map(lambda t: t.strftime('%Y-%m-%d')),*newDates],rotation = 45,size=8)
    plt.show()

    if(np.sum(np.array(fundamental_entries)==s)>0):
        loc = np.where(np.array(fundamental_entries)==s)[0][0]
        #print(fundamentals_quarterlies[loc[0]][0])
        #fundamentals_quarterlies[loc][1]
        for item in fundamentals_quarterlies[loc][1]:
            if(type(item[1]) == type(None)):
                pass
            else:
                if(len(item[1])>0):
                    #print(len(item[1]))
                    print(item)
client.close()
# Out:
# adf < .05 or .01, mean reverting
# Hurst
# > .5 - The time series is mean reverting.
# = .5 - The time series is a Geometric Brownian Motion.
# < .5 - The time series is trending.
# symbol: SPY
# sector: error
# sector: error
# Index: SP500
# vol_30d_2yr: 1719938470.5078125
# Sector 1YMF: -287.8400573730469
# 1YMF: -287.8400573730469
# risk trend factor: -3.791860877423899
#       totalAssets  trailingPE
# SPY  3.781762e+11    3.819317
#              Adj Close     21dBOLD    21dMA-TP     21dBOLU      90dSMA  \
# 2022-06-17  365.859985  364.518828  396.470318  428.421808  419.420001
#
#               90dSDev   90d_lower   90d_upper
# 2022-06-17  25.514981  368.390039  470.449963
#     volume_factor    latest_p        vol_30d_2yr   pct_2yr       adf     hurst
# SPY      1.183517  365.859985  1719938470.507812  0.369677  0.658465  0.422658
# <style  type="text/css" >
# </style><table id="T_5e3e5_" style='display:inline'><caption>l axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e3e5_level0_row0" class="row_heading level0 row0" >blue</th>
#                         <td id="T_5e3e5_row0_col0" class="data row0 col0" >symbol</td>
#             </tr>
#             <tr>
#                         <th id="T_5e3e5_level0_row1" class="row_heading level0 row1" >green</th>
#                         <td id="T_5e3e5_row1_col0" class="data row1 col0" >trailing_1yr_max</td>
#             </tr>
#             <tr>
#                         <th id="T_5e3e5_level0_row2" class="row_heading level0 row2" >red</th>
#                         <td id="T_5e3e5_row2_col0" class="data row2 col0" >trailing_1yr_min</td>
#             </tr>
#             <tr>
#                         <th id="T_5e3e5_level0_row3" class="row_heading level0 row3" >orange</th>
#                         <td id="T_5e3e5_row3_col0" class="data row3 col0" >30d_vol_2yr</td>
#             </tr>
#             <tr>
#                         <th id="T_5e3e5_level0_row4" class="row_heading level0 row4" >black</th>
#                         <td id="T_5e3e5_row4_col0" class="data row4 col0" >risk_trend_factor/linear</td>
#             </tr>
#             <tr>
#                         <th id="T_5e3e5_level0_row5" class="row_heading level0 row5" >yellow</th>
#                         <td id="T_5e3e5_row5_col0" class="data row5 col0" >supply_trend_1yr</td>
#             </tr>
#     </tbody></table>     <style  type="text/css" >
# </style><table id="T_e404a_" style='display:inline'><caption>r axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e404a_level0_row0" class="row_heading level0 row0" >magenta</th>
#                         <td id="T_e404a_row0_col0" class="data row0 col0" >sector</td>
#             </tr>
#             <tr>
#                         <th id="T_e404a_level0_row1" class="row_heading level0 row1" >cyan</th>
#                         <td id="T_e404a_row1_col0" class="data row1 col0" >index</td>
#             </tr>
#     </tbody></table>
# ets next 13 weeks
# inner cv scores:
# best model: ['add', 'add', False]
# best inner cv score, sdev (11 folds): 1596.0716629023389 2394.562470290511
# test cv mean error, stdev (10 folds): 1700.9872109246935 2487.2162019064376
# sell date: 2022-08-26
# expected return: 0.0731737994251005
# discounted return: 0.0010240083703010328
# quarter return: 1.098736153276629
# ['options', ('2022-06-30', '2022-09-16', '2022-09-30', '2022-12-16', '2023-01-20', '2023-03-17', '2023-06-16', '2023-12-15', '2024-01-19', '2024-12-20')]
# symbol: SPTM
# sector: error
# sector: error
# Index: SP1500
# vol_30d_2yr: 10189559.1796875
# Sector 1YMF: -34.95000076293945
# 1YMF: -34.95000076293945
# risk trend factor: -3.8790224724143685
#        totalAssets
# SPTM  5.538233e+09
#             Adj Close    21dBOLD   21dMA-TP    21dBOLU     90dSMA   90dSDev  \
# 2022-06-17  45.310001  44.984943  48.919841  52.854739  51.683968  3.088065
#
#             90d_lower  90d_upper
# 2022-06-17  45.507837  57.860099
#      volume_factor   latest_p      vol_30d_2yr   pct_2yr       adf     hurst
# SPTM      1.653055  45.310001  10189559.179688  0.388272  0.658826  0.429487
# <style  type="text/css" >
# </style><table id="T_1a505_" style='display:inline'><caption>l axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a505_level0_row0" class="row_heading level0 row0" >blue</th>
#                         <td id="T_1a505_row0_col0" class="data row0 col0" >symbol</td>
#             </tr>
#             <tr>
#                         <th id="T_1a505_level0_row1" class="row_heading level0 row1" >green</th>
#                         <td id="T_1a505_row1_col0" class="data row1 col0" >trailing_1yr_max</td>
#             </tr>
#             <tr>
#                         <th id="T_1a505_level0_row2" class="row_heading level0 row2" >red</th>
#                         <td id="T_1a505_row2_col0" class="data row2 col0" >trailing_1yr_min</td>
#             </tr>
#             <tr>
#                         <th id="T_1a505_level0_row3" class="row_heading level0 row3" >orange</th>
#                         <td id="T_1a505_row3_col0" class="data row3 col0" >30d_vol_2yr</td>
#             </tr>
#             <tr>
#                         <th id="T_1a505_level0_row4" class="row_heading level0 row4" >black</th>
#                         <td id="T_1a505_row4_col0" class="data row4 col0" >risk_trend_factor/linear</td>
#             </tr>
#             <tr>
#                         <th id="T_1a505_level0_row5" class="row_heading level0 row5" >yellow</th>
#                         <td id="T_1a505_row5_col0" class="data row5 col0" >supply_trend_1yr</td>
#             </tr>
#     </tbody></table>     <style  type="text/css" >
# </style><table id="T_4e242_" style='display:inline'><caption>r axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e242_level0_row0" class="row_heading level0 row0" >magenta</th>
#                         <td id="T_4e242_row0_col0" class="data row0 col0" >sector</td>
#             </tr>
#             <tr>
#                         <th id="T_4e242_level0_row1" class="row_heading level0 row1" >cyan</th>
#                         <td id="T_4e242_row1_col0" class="data row1 col0" >index</td>
#             </tr>
#     </tbody></table>
# ets next 13 weeks
# inner cv scores:
# best model: ['mul', 'mul', False]
# best inner cv score, sdev (11 folds): 26.39441799788848 42.330559315089545
# test cv mean error, stdev (10 folds): 28.190470373038277 43.99527812342293
# sell date: 2022-08-26
# expected return: 0.07943706638168399
# discounted return: 0.001108435171041089
# quarter return: 1.1072943979956897
# symbol: MDYG
# sector: error
# sector: error
# Index: SP400
# vol_30d_2yr: 4938966.40625
# Sector 1YMF: -69.05999755859375
# 1YMF: -69.05999755859375
# risk trend factor: -5.134573474205833
# Empty DataFrame
# Columns: []
# Index: [MDYG]
#            Adj Close    21dBOLD   21dMA-TP    21dBOLU     90dSMA   90dSDev  \
# 2022-06-17     59.93  59.511554  65.413016  71.314478  69.046349  4.323319
#
#             90d_lower  90d_upper
# 2022-06-17  60.399712  77.692987
#      volume_factor latest_p    vol_30d_2yr   pct_2yr       adf     hurst
# MDYG      0.576598    59.93  4938966.40625  0.256027  0.494117  0.451147
# <style  type="text/css" >
# </style><table id="T_3ffb4_" style='display:inline'><caption>l axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ffb4_level0_row0" class="row_heading level0 row0" >blue</th>
#                         <td id="T_3ffb4_row0_col0" class="data row0 col0" >symbol</td>
#             </tr>
#             <tr>
#                         <th id="T_3ffb4_level0_row1" class="row_heading level0 row1" >green</th>
#                         <td id="T_3ffb4_row1_col0" class="data row1 col0" >trailing_1yr_max</td>
#             </tr>
#             <tr>
#                         <th id="T_3ffb4_level0_row2" class="row_heading level0 row2" >red</th>
#                         <td id="T_3ffb4_row2_col0" class="data row2 col0" >trailing_1yr_min</td>
#             </tr>
#             <tr>
#                         <th id="T_3ffb4_level0_row3" class="row_heading level0 row3" >orange</th>
#                         <td id="T_3ffb4_row3_col0" class="data row3 col0" >30d_vol_2yr</td>
#             </tr>
#             <tr>
#                         <th id="T_3ffb4_level0_row4" class="row_heading level0 row4" >black</th>
#                         <td id="T_3ffb4_row4_col0" class="data row4 col0" >risk_trend_factor/linear</td>
#             </tr>
#             <tr>
#                         <th id="T_3ffb4_level0_row5" class="row_heading level0 row5" >yellow</th>
#                         <td id="T_3ffb4_row5_col0" class="data row5 col0" >supply_trend_1yr</td>
#             </tr>
#     </tbody></table>     <style  type="text/css" >
# </style><table id="T_896b3_" style='display:inline'><caption>r axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_896b3_level0_row0" class="row_heading level0 row0" >magenta</th>
#                         <td id="T_896b3_row0_col0" class="data row0 col0" >sector</td>
#             </tr>
#             <tr>
#                         <th id="T_896b3_level0_row1" class="row_heading level0 row1" >cyan</th>
#                         <td id="T_896b3_row1_col0" class="data row1 col0" >index</td>
#             </tr>
#     </tbody></table>
# ets next 13 weeks
# inner cv scores:
# best model: ['add', None]
# best inner cv score, sdev (11 folds): 85.23639741479961 165.19312912990566
# test cv mean error, stdev (10 folds): 92.56630163538853 171.54196149677145
# sell date: 2022-08-26
# expected return: 0.0531767837463806
# discounted return: 0.0007511675628262271
# quarter return: 1.071523505983349
# symbol: SLY
# sector: error
# sector: error
# Index: SP600
# vol_30d_2yr: 1808137.109375
# Sector 1YMF: -77.27001953125
# 1YMF: -77.27001953125
# risk trend factor: -5.242200185196592
# Empty DataFrame
# Columns: []
# Index: [SLY]
#             Adj Close    21dBOLD   21dMA-TP    21dBOLU     90dSMA   90dSDev  \
# 2022-06-17  78.089996  78.068302  85.071269  92.074236  88.226349  4.474948
#
#             90d_lower  90d_upper
# 2022-06-17  79.276452  97.176246
#     volume_factor   latest_p     vol_30d_2yr   pct_2yr       adf    hurst
# SLY       1.23276  78.089996  1808137.109375  0.449524  0.532018  0.51304
# <style  type="text/css" >
# </style><table id="T_70048_" style='display:inline'><caption>l axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70048_level0_row0" class="row_heading level0 row0" >blue</th>
#                         <td id="T_70048_row0_col0" class="data row0 col0" >symbol</td>
#             </tr>
#             <tr>
#                         <th id="T_70048_level0_row1" class="row_heading level0 row1" >green</th>
#                         <td id="T_70048_row1_col0" class="data row1 col0" >trailing_1yr_max</td>
#             </tr>
#             <tr>
#                         <th id="T_70048_level0_row2" class="row_heading level0 row2" >red</th>
#                         <td id="T_70048_row2_col0" class="data row2 col0" >trailing_1yr_min</td>
#             </tr>
#             <tr>
#                         <th id="T_70048_level0_row3" class="row_heading level0 row3" >orange</th>
#                         <td id="T_70048_row3_col0" class="data row3 col0" >30d_vol_2yr</td>
#             </tr>
#             <tr>
#                         <th id="T_70048_level0_row4" class="row_heading level0 row4" >black</th>
#                         <td id="T_70048_row4_col0" class="data row4 col0" >risk_trend_factor/linear</td>
#             </tr>
#             <tr>
#                         <th id="T_70048_level0_row5" class="row_heading level0 row5" >yellow</th>
#                         <td id="T_70048_row5_col0" class="data row5 col0" >supply_trend_1yr</td>
#             </tr>
#     </tbody></table>     <style  type="text/css" >
# </style><table id="T_ee102_" style='display:inline'><caption>r axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ee102_level0_row0" class="row_heading level0 row0" >magenta</th>
#                         <td id="T_ee102_row0_col0" class="data row0 col0" >sector</td>
#             </tr>
#             <tr>
#                         <th id="T_ee102_level0_row1" class="row_heading level0 row1" >cyan</th>
#                         <td id="T_ee102_row1_col0" class="data row1 col0" >index</td>
#             </tr>
#     </tbody></table>
# ets next 13 weeks
# inner cv scores:
# best model: ['add', 'add', True]
# best inner cv score, sdev (11 folds): 128.19891410392745 187.56519320285497
# test cv mean error, stdev (10 folds): 137.65292691556047 194.20507134370564
# sell date: 2022-08-26
# expected return: 0.04681992421538783
# discounted return: 0.0006633637682367244
# quarter return: 1.062908728251203
# symbol: VDE
# sector: error
# sector: Energy
# Index: nan
# vol_30d_2yr: 25785341.015625
# Sector 1YMF: -3.82000732421875
# 1YMF: -3.82000732421875
# risk trend factor: -0.12330558135216596
#       totalAssets  trailingPE
# VDE  1.106882e+10    8.493072
#              Adj Close     21dBOLD   21dMA-TP     21dBOLU      90dSMA  \
# 2022-06-17  102.349998  106.909959  119.43381  131.957661  112.539048
#
#              90dSDev 90d_lower   90d_upper
# 2022-06-17  6.727104  99.08484  125.993256
#     volume_factor    latest_p      vol_30d_2yr  pct_2yr       adf     hurst
# VDE      0.896641  102.349998  25785341.015625  0.70127  0.621023  0.512979
# <style  type="text/css" >
# </style><table id="T_3aa60_" style='display:inline'><caption>l axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3aa60_level0_row0" class="row_heading level0 row0" >blue</th>
#                         <td id="T_3aa60_row0_col0" class="data row0 col0" >symbol</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa60_level0_row1" class="row_heading level0 row1" >green</th>
#                         <td id="T_3aa60_row1_col0" class="data row1 col0" >trailing_1yr_max</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa60_level0_row2" class="row_heading level0 row2" >red</th>
#                         <td id="T_3aa60_row2_col0" class="data row2 col0" >trailing_1yr_min</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa60_level0_row3" class="row_heading level0 row3" >orange</th>
#                         <td id="T_3aa60_row3_col0" class="data row3 col0" >30d_vol_2yr</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa60_level0_row4" class="row_heading level0 row4" >black</th>
#                         <td id="T_3aa60_row4_col0" class="data row4 col0" >risk_trend_factor/linear</td>
#             </tr>
#             <tr>
#                         <th id="T_3aa60_level0_row5" class="row_heading level0 row5" >yellow</th>
#                         <td id="T_3aa60_row5_col0" class="data row5 col0" >supply_trend_1yr</td>
#             </tr>
#     </tbody></table>     <style  type="text/css" >
# </style><table id="T_11364_" style='display:inline'><caption>r axis</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >legend</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11364_level0_row0" class="row_heading level0 row0" >magenta</th>
#                         <td id="T_11364_row0_col0" class="data row0 col0" >sector</td>
#             </tr>
#             <tr>
#                         <th id="T_11364_level0_row1" class="row_heading level0 row1" >cyan</th>
#                         <td id="T_11364_row1_col0" class="data row1 col0" >index</td>
#             </tr>
#     </tbody></table>
# ets next 13 weeks

# %%
decision_metrics_df = pd.DataFrame(decision_metrics,columns=['SYMBOL','exp_return','sell_date','stop_loss_price','days_delta','disc_rtn','qtr_rtn','outer_cv_avg_rmse_n11','outer_cv_std_n11','mean_revert_flag','pi_lower','pi_upper'])
decision_metrics_df = decision_metrics_df.set_index('SYMBOL').sort_values(by='disc_rtn',ascending=False)
decision_metrics_df['price'] = screener['latest_p'].loc[decision_metrics_df.index]
decision_metrics_df['Sector'] = temp_sm['Sector'].loc[decision_metrics_df.index]
decision_metrics_df['Index'] = temp_sm['index'].loc[decision_metrics_df.index]
decision_metrics_df['error_price_ratio'] = decision_metrics_df['outer_cv_avg_rmse_n11']/screener['latest_p'].loc[decision_metrics_df.index]
decision_metrics_df['std_price_ratio'] = decision_metrics_df['outer_cv_std_n11']/screener['latest_p'].loc[decision_metrics_df.index]

# %%
display(decision_metrics_df.style.applymap(highlight_cells, color_if_false='yellow', color_if_true='#C6E2E9', 
                  subset=['error_price_ratio','mean_revert_flag','std_price_ratio'], threshold_=.75))
# Out:
# <style  type="text/css" >
# #T_d224e_row0_col8,#T_d224e_row1_col8,#T_d224e_row1_col14,#T_d224e_row1_col15,#T_d224e_row2_col8,#T_d224e_row3_col8,#T_d224e_row4_col8,#T_d224e_row5_col8,#T_d224e_row6_col8,#T_d224e_row7_col8,#T_d224e_row8_col8,#T_d224e_row8_col15,#T_d224e_row9_col8,#T_d224e_row9_col14,#T_d224e_row9_col15,#T_d224e_row10_col8,#T_d224e_row11_col8,#T_d224e_row12_col8,#T_d224e_row12_col14,#T_d224e_row12_col15,#T_d224e_row13_col8,#T_d224e_row14_col8,#T_d224e_row15_col8,#T_d224e_row16_col8,#T_d224e_row16_col14,#T_d224e_row17_col8,#T_d224e_row18_col8,#T_d224e_row19_col8,#T_d224e_row20_col8,#T_d224e_row21_col8,#T_d224e_row22_col8,#T_d224e_row22_col14,#T_d224e_row22_col15,#T_d224e_row23_col8,#T_d224e_row23_col15,#T_d224e_row24_col8,#T_d224e_row25_col8,#T_d224e_row26_col8,#T_d224e_row27_col8,#T_d224e_row28_col8,#T_d224e_row29_col8,#T_d224e_row30_col8,#T_d224e_row30_col14,#T_d224e_row30_col15,#T_d224e_row31_col8,#T_d224e_row32_col8,#T_d224e_row33_col8,#T_d224e_row33_col14,#T_d224e_row33_col15,#T_d224e_row34_col8,#T_d224e_row35_col8,#T_d224e_row36_col8,#T_d224e_row36_col14,#T_d224e_row36_col15,#T_d224e_row37_col8,#T_d224e_row37_col14,#T_d224e_row38_col8,#T_d224e_row39_col8,#T_d224e_row39_col14,#T_d224e_row39_col15,#T_d224e_row40_col8,#T_d224e_row40_col14,#T_d224e_row40_col15,#T_d224e_row41_col8,#T_d224e_row41_col14,#T_d224e_row41_col15,#T_d224e_row42_col8,#T_d224e_row43_col8,#T_d224e_row44_col8,#T_d224e_row44_col14,#T_d224e_row44_col15,#T_d224e_row45_col8,#T_d224e_row45_col15,#T_d224e_row46_col8,#T_d224e_row47_col8,#T_d224e_row48_col8,#T_d224e_row49_col8,#T_d224e_row49_col14,#T_d224e_row49_col15,#T_d224e_row50_col8,#T_d224e_row50_col14,#T_d224e_row50_col15,#T_d224e_row51_col8,#T_d224e_row51_col14,#T_d224e_row51_col15,#T_d224e_row52_col8,#T_d224e_row52_col14,#T_d224e_row52_col15{
#             background-color:  yellow;
#         }#T_d224e_row0_col14,#T_d224e_row0_col15,#T_d224e_row2_col14,#T_d224e_row2_col15,#T_d224e_row3_col14,#T_d224e_row3_col15,#T_d224e_row4_col14,#T_d224e_row4_col15,#T_d224e_row5_col14,#T_d224e_row5_col15,#T_d224e_row6_col14,#T_d224e_row6_col15,#T_d224e_row7_col14,#T_d224e_row7_col15,#T_d224e_row8_col14,#T_d224e_row10_col14,#T_d224e_row10_col15,#T_d224e_row11_col14,#T_d224e_row11_col15,#T_d224e_row13_col14,#T_d224e_row13_col15,#T_d224e_row14_col14,#T_d224e_row14_col15,#T_d224e_row15_col14,#T_d224e_row15_col15,#T_d224e_row16_col15,#T_d224e_row17_col14,#T_d224e_row17_col15,#T_d224e_row18_col14,#T_d224e_row18_col15,#T_d224e_row19_col14,#T_d224e_row19_col15,#T_d224e_row20_col14,#T_d224e_row20_col15,#T_d224e_row21_col14,#T_d224e_row21_col15,#T_d224e_row23_col14,#T_d224e_row24_col14,#T_d224e_row24_col15,#T_d224e_row25_col14,#T_d224e_row25_col15,#T_d224e_row26_col14,#T_d224e_row26_col15,#T_d224e_row27_col14,#T_d224e_row27_col15,#T_d224e_row28_col14,#T_d224e_row28_col15,#T_d224e_row29_col14,#T_d224e_row29_col15,#T_d224e_row31_col14,#T_d224e_row31_col15,#T_d224e_row32_col14,#T_d224e_row32_col15,#T_d224e_row34_col14,#T_d224e_row34_col15,#T_d224e_row35_col14,#T_d224e_row35_col15,#T_d224e_row37_col15,#T_d224e_row38_col14,#T_d224e_row38_col15,#T_d224e_row42_col14,#T_d224e_row42_col15,#T_d224e_row43_col14,#T_d224e_row43_col15,#T_d224e_row45_col14,#T_d224e_row46_col14,#T_d224e_row46_col15,#T_d224e_row47_col14,#T_d224e_row47_col15,#T_d224e_row48_col14,#T_d224e_row48_col15{
#             background-color:  #C6E2E9;
#         }</style><table id="T_d224e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >exp_return</th>        <th class="col_heading level0 col1" >sell_date</th>        <th class="col_heading level0 col2" >stop_loss_price</th>        <th class="col_heading level0 col3" >days_delta</th>        <th class="col_heading level0 col4" >disc_rtn</th>        <th class="col_heading level0 col5" >qtr_rtn</th>        <th class="col_heading level0 col6" >outer_cv_avg_rmse_n11</th>        <th class="col_heading level0 col7" >outer_cv_std_n11</th>        <th class="col_heading level0 col8" >mean_revert_flag</th>        <th class="col_heading level0 col9" >pi_lower</th>        <th class="col_heading level0 col10" >pi_upper</th>        <th class="col_heading level0 col11" >price</th>        <th class="col_heading level0 col12" >Sector</th>        <th class="col_heading level0 col13" >Index</th>        <th class="col_heading level0 col14" >error_price_ratio</th>        <th class="col_heading level0 col15" >std_price_ratio</th>    </tr>    <tr>        <th class="index_name level0" >SYMBOL</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d224e_level0_row0" class="row_heading level0 row0" >VPU</th>
#                         <td id="T_d224e_row0_col0" class="data row0 col0" >0.076822</td>
#                         <td id="T_d224e_row0_col1" class="data row0 col1" >2022-06-19</td>
#                         <td id="T_d224e_row0_col2" class="data row0 col2" >147.621984</td>
#                         <td id="T_d224e_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_d224e_row0_col4" class="data row0 col4" >0.076822</td>
#                         <td id="T_d224e_row0_col5" class="data row0 col5" >906.245463</td>
#                         <td id="T_d224e_row0_col6" class="data row0 col6" >172.246362</td>
#                         <td id="T_d224e_row0_col7" class="data row0 col7" >373.069681</td>
#                         <td id="T_d224e_row0_col8" class="data row0 col8" >False</td>
#                         <td id="T_d224e_row0_col9" class="data row0 col9" >143.355682</td>
#                         <td id="T_d224e_row0_col10" class="data row0 col10" >161.712862</td>
#                         <td id="T_d224e_row0_col11" class="data row0 col11" >141.440002</td>
#                         <td id="T_d224e_row0_col12" class="data row0 col12" >error</td>
#                         <td id="T_d224e_row0_col13" class="data row0 col13" >nan</td>
#                         <td id="T_d224e_row0_col14" class="data row0 col14" >1.217805</td>
#                         <td id="T_d224e_row0_col15" class="data row0 col15" >2.637653</td>
#             </tr>
#             <tr>
#                         <th id="T_d224e_level0_row1" class="row_heading level0 row1" >VDC</th>
#                         <td id="T_d224e_row1_col0" class="data row1 col0" >0.028968</td>
#                         <td id="T_d224e_row1_col1" class="data row1 col1" >2022-06-19</td>
#                         <td id="T_d224e_row1_col2" class="data row1 col2" >178.612370</td>
#                         <td id="T_d224e_row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_d224e_row1_col4" class="data row1 col4" >0.028968</td>
#                         <td id="T_d224e_row1_col5" class="data row1 col5" >13.834763</td>
#                         <td id="T_d224e_row1_col6" class="data row1 col6" >95.349890</td>
#                         <td id="T_d224e_row1_col7" class="data row1 col7" >81.134142</td>
#                         <td id="T_d224e_row1_col8" class="data row1 col8" >False</td>
#                         <td id="T_d224e_row1_col9" class="data row1 col9" >175.035670</td>
#                         <td id="T_d224e_row1_col10" class="data row1 col10" >189.634819</td>
#                         <td id="T_d224e_row1_col11" class="data row1 col11" >177.059998</td>
#                         <td id="T_d224e_row1_col12" class="data row1 col12" >error</td>
#                         <td id="T_d224e_row1_col13" class="data row1 col13" >nan</td>
