# %%
import pandas as pd

train = pd.read_csv("c:/train2.csv", header = 0)
print(train)
# Out:
#       Id  groupId  matchId  assists  boosts  damageDealt  DBNOs  \
# 0      0       24        0        0       5      247.300      2
# 1      1   440875        1        1       0       37.650      1
# 2      2   878242        2        0       1       93.730      1
# 3      3  1319841        3        0       0       95.880      0
# 4      4  1757883        4        0       1        0.000      0
# 5      5  2200824        5        0       2      128.100      0
# 6      6  2568717        6        1       0      130.300      0
# 7      7  2612473        7        1       1      661.800      2
# 8      8  2656377        8        0       3       94.720      0
# 9      9  2700597        9        0       0      137.600      0
# 10    10    45059       10        0       1      166.000      0
# 11    11    89377       11        0       0      219.100      0
# 12    12   132815       12        0       1      196.500      0
# 13    13   179095       13        0       5      473.400      0
# ...
