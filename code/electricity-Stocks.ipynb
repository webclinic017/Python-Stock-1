# %%
#using these guides
#https://medium.com/swlh/a-technical-guide-on-rnn-lstm-gru-for-stock-price-prediction-bce2f7f30346
#https://github.com/dataman-git/codes_for_articles/blob/master/From%20regression%20to%20RNN.ipynb
#https://datascience.stackexchange.com/questions/93180/trying-to-extend-this-code-to-include-additional-feature-volume-in-addition-to
#https://datascience.stackexchange.com/questions/91147/problems-to-understand-how-to-create-the-input-data-for-time-series-forecasting/92395?noredirect=1#comment97317_92395
#https://towardsdatascience.com/recurrent-neural-networks-for-electricity-price-prediction-a26f8411ea44
#https://github.com/Carterbouley/ElectricityPricePrediction
#https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import sklearn
from yahoofinancials import YahooFinancials
AMZN = yf.download('GOLD', 
                      start='2013-01-01', 
                      progress=False)
# AMZN = yf.download('AMZN') for all 
all_data = AMZN[['Adj Close','Open','High','Low','Close','Volume']].round(2)
#all_data = AMZN[['Adj Close']].round(2)
all_data.head(10)
# Out:
#             Adj Close   Open   High    Low  Close   Volume
# Date
# 2013-01-02      32.08  35.92  36.08  35.38  35.53  7048000
# 2013-01-03      31.11  35.47  35.55  34.32  34.45  6611600
# 2013-01-04      31.24  34.06  34.70  33.94  34.60  6942400
# 2013-01-07      30.78  34.34  34.45  33.99  34.09  6081800
# 2013-01-08      30.26  34.04  34.06  33.32  33.51  9684000
# 2013-01-09      30.35  33.56  33.72  33.31  33.61  7252400
# 2013-01-10      31.15  33.97  34.66  33.91  34.50  8636000
# 2013-01-11      30.93  34.49  34.51  34.02  34.25  8236700
# 2013-01-14      30.86  34.42  34.62  34.09  34.18  6118000
# 2013-01-15      31.23  34.45  35.06  34.15  34.59  8214800

# %%
len(all_data)
#len(all_data.columns)
# Out:
# 2088

# %%
plt.plot(all_data['Adj Close'])

# %%
n_steps = 20
n_ahead = 1
epochs_ = 100
batch_size_ = 150

import tensorflow as tf

from tensorflow import keras
from matplotlib import pyplot as plt

# Read the data for the parameters from a csv file
import urllib.request
#Delete the first column as it is not used in the tutorial for forecasting


training = ((len(all_data)-n_steps-n_ahead)*.714)
validation = ((len(all_data)-n_steps-n_ahead)*.856)

#can handle both features!
#from sklearn.preprocessing import MinMaxScaler
#sc1 = MinMaxScaler(feature_range=(0,1))
#from sklearn.preprocessing import RobustScaler
#sc1 = RobustScaler().fit(all_data.iloc[:, 0:][0:int(validation)])

from sklearn.preprocessing import StandardScaler
sc1 = StandardScaler().fit(all_data.iloc[:, 0:][0:int(validation)])
ts_train_scaled_1 = sc1.fit_transform(all_data.iloc[:, 0:][0:int(validation)])
ts_test_scaled_1 = sc1.transform(all_data.iloc[:, 0:][int(validation):])

#data = all_data.values
#ts_train_scaled_1 = sc1.fit_transform(all_data.iloc[:, 1][0:int(training)])
#data = np.concatenate((ts_train_scaled_1, all_data[int(validation):].values), axis=0)
data = np.concatenate((ts_train_scaled_1, ts_test_scaled_1), axis=0)

series_reshaped =  np.array([data[i:i + (n_steps+n_ahead)].copy() for i in range(len(data) - (n_steps+n_ahead))])
#series_reshaped2 =  np.array([all_data.values[i:i + (n_steps+n_ahead)].copy() for i in range(len(all_data.values) - (n_steps+n_ahead))])

X_train = series_reshaped[:int(training), :n_steps] 
X_valid = series_reshaped[int(training):int(validation), :n_steps] 
X_test = series_reshaped[int(validation):, :n_steps] 

#assumes first column?
#based on https://raw.githubusercontent.com/Carterbouley/ElectricityPricePrediction/master/re_fixed_multivariate_timeseires.csv
#price is 1st column
Y = np.empty(((len(all_data) - n_steps - n_ahead), n_steps, n_ahead))  
for step_ahead in range(1, n_ahead + 1):     
   Y[..., step_ahead - 1] =   series_reshaped[..., step_ahead:step_ahead + n_steps, 0]
    
Y_train = Y[:int(training)] 
Y_valid = Y[int(training):int(validation)] 
Y_test = Y[int(validation):]

# %%
np.random.seed(42)
tf.random.set_seed(42)

from keras.layers import Dense, SimpleRNN, GRU, LSTM
from keras.optimizers import SGD

model6 = keras.models.Sequential([
    
    keras.layers.SimpleRNN(32, return_sequences=True, input_shape=[None, len(all_data.columns)]),
    keras.layers.SimpleRNN(32, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
])

#model6.compile(loss="mean_squared_error", optimizer="adam", metrics=['mean_absolute_percentage_error'])

model6.compile(loss="mean_squared_error", optimizer="rmsprop",metrics=['mean_squared_error'])

#history = model6.fit(X_train, Y_train, epochs=epochs_,batch_size=batch_size_,validation_data=(X_valid, Y_valid))
history = model6.fit(X_train, Y_train, epochs=epochs_,batch_size=batch_size_,validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 34ms/step - loss: 0.7362 - mean_squared_error: 0.7362 - val_loss: 0.0757 - val_mean_squared_error: 0.0757
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1023 - mean_squared_error: 0.1023 - val_loss: 0.0453 - val_mean_squared_error: 0.0453
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0722 - mean_squared_error: 0.0722 - val_loss: 0.0530 - val_mean_squared_error: 0.0530
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0757 - mean_squared_error: 0.0757 - val_loss: 0.0424 - val_mean_squared_error: 0.0424
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0501 - mean_squared_error: 0.0501 - val_loss: 0.0496 - val_mean_squared_error: 0.0496
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0439 - mean_squared_error: 0.0439 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0955 - val_mean_squared_error: 0.0955
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0560 - mean_squared_error: 0.0560 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0439 - mean_squared_error: 0.0439 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0301 - val_mean_squared_error: 0.0301
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 16/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 17/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.0307 - val_mean_squared_error: 0.0307
# Epoch 18/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 19/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 20/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0312 - mean_squared_error: 0.0312 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0310 - val_mean_squared_error: 0.0310
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 28/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 29/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 30/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 32/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 33/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 35/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 36/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 37/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 38/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 40/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 41/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 42/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 43/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 46/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 47/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 48/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 49/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 50/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 51/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 52/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 53/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 54/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 55/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 56/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 57/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 58/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 59/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 60/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 61/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0109 - val_mean_squared_error: 0.0109
# Epoch 62/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 63/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 64/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 66/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 67/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 70/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 71/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 72/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 73/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 74/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 75/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 76/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 77/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0131 - val_mean_squared_error: 0.0131
# Epoch 78/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 81/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0103 - val_mean_squared_error: 0.0103
# Epoch 83/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 84/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 85/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 87/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 88/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 91/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 92/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 93/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 94/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 95/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 96/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 97/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 98/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 99/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 100/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0083 - val_mean_squared_error: 0.0083

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
# - scaler   = the scaler object (it needs an inverse_transform method)
# - data     = the data to be inverse transformed as a Series, ndarray, ... 
#              (a 1d object you can assign to a df column)
# - ftName   = the name of the column to which the data belongs
# - colNames = all column names of the data on which scaler was fit 
#              (necessary because scaler will only accept a df of the same shape as the one it was fit on)
def invTransform(scaler, data, colName, colNames):
    dummy = pd.DataFrame(np.zeros((len(data), len(colNames))), columns=colNames)
    dummy[colName] = data
    dummy = pd.DataFrame(scaler.inverse_transform(dummy), columns=colNames)
    return dummy[colName].values

# %%
Y_pred = model6.predict(X_test)

last_list=[]

for i in range (0, len(Y_pred)):
  last_list.append((Y_pred[i][0][n_ahead-1]))
    
actual = pd.DataFrame((sc1.inverse_transform(X_test[:,0])))
actual.rename(columns = {0:'actual'}, inplace = True)
actual['predictions'] = last_list
actual['predictions'] = invTransform(sc1,actual["predictions"],"Adj Close",all_data.columns)
actual['difference'] = (actual['predictions'] - actual['actual']).abs()
actual['difference_percentage'] = ((actual['difference'])/(actual['actual']))*100

# %%
import matplotlib.pyplot as plt
plt.scatter(actual["actual"],actual["predictions"])

# %%
from matplotlib import pyplot as plt
plt.plot(actual["actual"],label="actual")
plt.plot(actual["predictions"],label="predictions")
plt.legend()
plt.show()

# %%
np.random.seed(42)
tf.random.set_seed(42)

model8 = keras.models.Sequential([
    keras.layers.LSTM(50, return_sequences=True, input_shape=[None, len(all_data.columns)], activation='tanh'),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
])

#model8.compile(loss="mape", optimizer="adam")
model8.compile(tf.keras.optimizers.SGD(learning_rate=0.01, decay=1e-7, momentum=0.9, nesterov=False, name="SGD"),loss='mean_squared_error')
history = model8.fit(X_train, Y_train, epochs=epochs_,batch_size=batch_size_,
                    validation_data=(X_valid, Y_valid))

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
Y_pred = model8.predict(X_test)

last_list=[]

for i in range (0, len(Y_pred)):
  last_list.append((Y_pred[i][0][n_ahead-1]))
    

actual = pd.DataFrame((sc1.inverse_transform(X_test[:,0])))
actual.rename(columns = {0:'actual'}, inplace = True)
actual['predictions'] = last_list
actual['predictions'] = invTransform(sc1,actual["predictions"],"Adj Close",all_data.columns)
actual['difference'] = (actual['predictions'] - actual['actual']).abs()
actual['difference_percentage'] = ((actual['difference'])/(actual['actual']))*100

# from google.colab import files
# actual.to_csv('simplelstmresults.csv') 
# files.download('simplelstmresults.csv')

# %%
from matplotlib import pyplot as plt
plt.plot(actual["actual"],label="actual")
plt.plot(actual["predictions"],label="predictions")
plt.legend()
plt.show()

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor = 'val_loss')

np.random.seed(42)
tf.random.set_seed(42)

model9 = keras.models.Sequential([
    keras.layers.LSTM(80, return_sequences= True, input_shape=(n_steps,len(all_data.columns))),
    keras.layers.Dropout(0.2),
    keras.layers.LSTM(40, return_sequences= True),
    keras.layers.Dropout(0.2),
    keras.layers.LSTM(30, return_sequences= True),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
])

model9.compile(loss="mape", optimizer="adam")
history9 = model9.fit(X_train, Y_train, epochs=epochs_,batch_size=batch_size_,
                    validation_data=(X_valid, Y_valid))#, callbacks = [es] )

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
Y_pred = model9.predict(X_test)

last_list=[]

for i in range (0, len(Y_pred)):
  last_list.append((Y_pred[i][0][n_ahead-1]))
    

actual = pd.DataFrame((sc1.inverse_transform(X_test[:,0])))
actual.rename(columns = {0:'actual'}, inplace = True)
actual['predictions'] = last_list
actual['predictions'] = invTransform(sc1,actual["predictions"],"Adj Close",all_data.columns)
actual['difference'] = (actual['predictions'] - actual['actual']).abs()
actual['difference_percentage'] = ((actual['difference'])/(actual['actual']))*100

# from google.colab import files
# actual.to_csv('simplelstmresults.csv') 
# files.download('simplelstmresults.csv')

# %%
from matplotlib import pyplot as plt
plt.plot(actual["actual"],label="actual")
plt.plot(actual["predictions"],label="predictions")
plt.legend()
plt.show()

# %%
Y_train[:, 3::2]

# %%
np.random.seed(42)
tf.random.set_seed(42)

model10 = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, len(all_data.columns)]),
    keras.layers.GRU(60, return_sequences=True),
    keras.layers.GRU(40, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(n_ahead))
])

model10.compile(loss="mape", optimizer="adam")
history2 = model10.fit(X_train, Y_train[:, 3::2], epochs=epochs_,batch_size=batch_size_,
                    validation_data=(X_valid, Y_valid[:, 3::2]))#, callbacks = [es])

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
Y_pred = model10.predict(X_test)

last_list=[]

for i in range (0, len(Y_pred)):
  last_list.append((Y_pred[i][0][n_ahead-1]))
    

actual = pd.DataFrame((sc1.inverse_transform(X_test[:,0])))
actual.rename(columns = {0:'actual'}, inplace = True)
actual['predictions'] = last_list
actual['predictions'] = invTransform(sc1,actual["predictions"],"Adj Close",all_data.columns)
actual['difference'] = (actual['predictions'] - actual['actual']).abs()
actual['difference_percentage'] = ((actual['difference'])/(actual['actual']))*100

from matplotlib import pyplot as plt
plt.plot(actual["actual"],label="actual")
plt.plot(actual["predictions"],label="predictions")
plt.legend()
plt.show()
