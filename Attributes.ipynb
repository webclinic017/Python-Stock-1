# %%
import pandas as pd
import scipy
attributes = pd.read_csv('/mnt/distvol/5000Attributes.csv')
#skills = pd.read_csv('/mnt/distvol/5000Skills.csv')

# %%
from sklearn.preprocessing import PowerTransformer

def testNormal (x):    
    
    k2, p = stats.normaltest(x)
    alpha = .001
    #print("p = {:g}".format(p))    
    if p < alpha:  # null hypothesis: x comes from a normal distribution
        #print(p)
        #print(alpha)
        print("The null hypothesis can be rejected")
        xt, _ = stats.yeojohnson(x)
        #xt, _ = stats.boxcox(x)        
        print(_)
        xt = pd.DataFrame(xt)
        
        return _, pd.DataFrame(xt).set_index(x.index)
    else:
        print("The null hypothesis cannot be rejected")    
        return 1, pd.DataFrame(x)

def inverse_boxcox (data, lambdas):
    power = PowerTransformer(method='yeo-johnson')
    power.lambdas_ = lambdas.values
    return(power.inverse_transform([data]))
    #return inv_boxcox(data, lambdas.values)
    
def transform_boxcox_l(data, l_):
    transformed = pd.DataFrame()

    for i in range(0,len(data.columns)):
        #print(i)
        if l_.iloc[i].values == 1:
            inner_scale = data.iloc[:,i]            
        else:
            inner_scale = pd.DataFrame(stats.yeojohnson((data.iloc[:,i]), lmbda=l_.iloc[i].values))
            
        inner_scale.index = data.index
        transformed = pd.concat([transformed,inner_scale],axis=1)
        
    transformed.columns = data.columns
    return transformed

def transform_boxcox (data):
    transformed = pd.DataFrame()
    transformed_lambdas = pd.DataFrame()

    for i in range(0,len(data.columns)):
        l, inner_scale = testNormal(data.iloc[:,i])
        inner_scale.set_index(data.index)

        transformed_lambdas = pd.concat([transformed_lambdas,pd.DataFrame(pd.Series(l))],axis=0)
        transformed = pd.concat([transformed,inner_scale],axis=1)
        
    transformed.columns = data.columns
    return transformed, transformed_lambdas

def inverse_yeo(og, data_, lambda_):
    values = []
    for i in range(0,len(og)):
        X = og[i]
        X_trans = data_[i]
        if X >= 0 and lambda_ == 0:
            X = exp(X_trans) - 1
        elif X >= 0 and lambda_ != 0:
            X = (X_trans * lambda_ + 1) ** (1 / lambda_) - 1
        elif X < 0 and lambda_ != 2:
            X = 1 - (-(2 - lambda_) * X_trans + 1) ** (1 / (2 - lambda_))
        elif X < 0 and lambda_ == 2:
            X = 1 - exp(-X_trans)
        
        values.append(X)
    return(pd.DataFrame(values))


def revert_yeo (og, data_, lambdas):
    reverted = pd.DataFrame()

    for i in range(0,len(data_.columns)):        
        if lambdas.iloc[i].values == 1 :
            revert = data_.iloc[:,i]
        else:
            p#ower = PowerTransformer(method='yeo-johnson')
            #power.lambdas_ = lambdas.iloc[i].values
            #revert = pd.DataFrame(power.inverse_transform([data.iloc[:,i].values]))
            #return inv_boxcox(data, lambdas.values)
            revert = pd.DataFrame(inverse_yeo(og.iloc[:,i].values,data_.iloc[:,i].values, lambdas.iloc[i].values))            
        revert.index = data_.index
        reverted = pd.concat([reverted,revert],axis=1)
        
    reverted.columns = data_.columns
    return reverted

# %%
import numpy as np
m = np.median(np.matrix.flatten(np.array((attributes.iloc[:,1:]))))
mad = stats.median_absolute_deviation(np.matrix.flatten(np.array((attributes.iloc[:,1:]))))
# Out:
# <ipython-input-98-d372311e6a9c>:3: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.
#
#   mad = stats.median_absolute_deviation(np.matrix.flatten(np.array((attributes.iloc[:,1:]))))

# %%
m
# Out:
# 1108.0

# %%
import statistics
from scipy import stats
#statistics.median(skills.iloc[:,1:])
attributes.iloc[:,1:].apply(statistics.median,axis=0)

median_transformed = (attributes.iloc[:,1:]-m)/mad
#(attributes.iloc[:,1:]-attributes.iloc[:,1:].apply(statistics.median,axis=0))/attributes.iloc[:,1:].apply(stats.median_absolute_deviation,axis=0)

transformed_, lambdas = transform_boxcox(pd.DataFrame(np.matrix.flatten(np.array(median_transformed))))
# Out:
# The null hypothesis can be rejected
# 0.7499028287870247

# %%
new = pd.DataFrame(np.array(transformed_).reshape(len(attributes),len(attributes.columns)-1))
new.columns = attributes.iloc[:,1:].columns
new.index = attributes.iloc[:,0]
new

norm_cdf = scipy.stats.norm.cdf(new) # calculate the cdf - also discrete

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])

bp = ax.boxplot(pd.DataFrame(norm_cdf))
plt.show()

# %%
display(pd.DataFrame(new,columns=attributes.iloc[:,1:].columns).describe().loc[pd.DataFrame(new).describe().index[1:]].style.background_gradient(cmap ='viridis',axis=None))

display(pd.DataFrame(norm_cdf,columns=attributes.iloc[:,1:].columns).describe().loc[pd.DataFrame(norm_cdf).describe().index[1:]].style.background_gradient(cmap ='viridis',axis=None))
# Out:
# <style  type="text/css" >
#     #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col0 {
#             background-color:  #297a8e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col1 {
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col2 {
#             background-color:  #297a8e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col3 {
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col4 {
#             background-color:  #2e6d8e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col5 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col6 {
#             background-color:  #297a8e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col7 {
#             background-color:  #297a8e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col8 {
#             background-color:  #31678e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col9 {
#             background-color:  #238a8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col10 {
#             background-color:  #31678e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col11 {
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col12 {
#             background-color:  #31678e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col13 {
#             background-color:  #29798e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col14 {
#             background-color:  #31678e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col15 {
#             background-color:  #29798e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col16 {
#             background-color:  #31678e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col17 {
#             background-color:  #228b8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row0_col18 {
#             background-color:  #2e6f8e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col0 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col1 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col2 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col3 {
#             background-color:  #21908d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col4 {
#             background-color:  #1f958b;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col5 {
#             background-color:  #218e8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col6 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col7 {
#             background-color:  #228b8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col8 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col9 {
#             background-color:  #23898e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col10 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col11 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col12 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col13 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col14 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col15 {
#             background-color:  #228c8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col16 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col17 {
#             background-color:  #23898e;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row1_col18 {
#             background-color:  #1f948c;
#             color:  #000000;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col0 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col2 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col3 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col4 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col5 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col6 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col7 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col8 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col9 {
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col10 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col11 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col12 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col13 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col14 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col15 {
#             background-color:  #472d7b;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col16 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col17 {
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row2_col18 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row3_col0 {
#             background-color:  #2f6c8e;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row3_col1 {
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }    #T_8a3e516c_c026_11eb_aeda_525400b25cf3row3_col2 {
#             background-color:  #2f6c8e;
# <style  type="text/css" >
#     #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col0 {
#             background-color:  #24aa83;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col1 {
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col2 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col3 {
#             background-color:  #287d8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col4 {
#             background-color:  #25858e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col5 {
#             background-color:  #2a788e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col6 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col7 {
#             background-color:  #24aa83;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col8 {
#             background-color:  #297b8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col9 {
#             background-color:  #65cb5e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col10 {
#             background-color:  #297a8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col11 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col12 {
#             background-color:  #297b8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col13 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col14 {
#             background-color:  #297b8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col15 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col16 {
#             background-color:  #297b8e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col17 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row0_col18 {
#             background-color:  #24878e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col0 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col1 {
#             background-color:  #3c508b;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col2 {
#             background-color:  #38588c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col3 {
#             background-color:  #355e8d;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col4 {
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col5 {
#             background-color:  #375b8d;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col6 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col7 {
#             background-color:  #39568c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col8 {
#             background-color:  #38588c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col9 {
#             background-color:  #3d4d8a;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col10 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col11 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col12 {
#             background-color:  #38588c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col13 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col14 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col15 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col16 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col17 {
#             background-color:  #3e4c8a;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row1_col18 {
#             background-color:  #355f8d;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col0 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col2 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col6 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col7 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col8 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col9 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col11 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col12 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col13 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col14 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col15 {
#             background-color:  #450559;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col16 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col17 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row2_col18 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row3_col0 {
#             background-color:  #27808e;
#             color:  #000000;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row3_col1 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_8a54a07a_c026_11eb_aeda_525400b25cf3row3_col2 {
#             background-color:  #26828e;
