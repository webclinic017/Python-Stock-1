# %%
import pandas as pd
import scipy
attributes = pd.read_csv('/mnt/distvol/5000Attributes.csv')
#skills = pd.read_csv('/mnt/distvol/5000Skills.csv')

# %%
from sklearn.preprocessing import PowerTransformer

def testNormal (x):    
    
    k2, p = stats.normaltest(x)
    alpha = .001
    #print("p = {:g}".format(p))    
    if p < alpha:  # null hypothesis: x comes from a normal distribution
        #print(p)
        #print(alpha)
        print("The null hypothesis can be rejected")
        xt, _ = stats.yeojohnson(x)
        #xt, _ = stats.boxcox(x)        
        print(_)
        xt = pd.DataFrame(xt)
        
        return _, pd.DataFrame(xt).set_index(x.index)
    else:
        print("The null hypothesis cannot be rejected")    
        return 1, pd.DataFrame(x)

def inverse_boxcox (data, lambdas):
    power = PowerTransformer(method='yeo-johnson')
    power.lambdas_ = lambdas.values
    return(power.inverse_transform([data]))
    #return inv_boxcox(data, lambdas.values)
    
def transform_boxcox_l(data, l_):
    transformed = pd.DataFrame()

    for i in range(0,len(data.columns)):
        #print(i)
        if l_.iloc[i].values == 1:
            inner_scale = data.iloc[:,i]            
        else:
            inner_scale = pd.DataFrame(stats.yeojohnson((data.iloc[:,i]), lmbda=l_.iloc[i].values))
            
        inner_scale.index = data.index
        transformed = pd.concat([transformed,inner_scale],axis=1)
        
    transformed.columns = data.columns
    return transformed

def transform_boxcox (data):
    transformed = pd.DataFrame()
    transformed_lambdas = pd.DataFrame()

    for i in range(0,len(data.columns)):
        l, inner_scale = testNormal(data.iloc[:,i])
        inner_scale.set_index(data.index)

        transformed_lambdas = pd.concat([transformed_lambdas,pd.DataFrame(pd.Series(l))],axis=0)
        transformed = pd.concat([transformed,inner_scale],axis=1)
        
    transformed.columns = data.columns
    return transformed, transformed_lambdas

def inverse_yeo(og, data_, lambda_):
    values = []
    for i in range(0,len(og)):
        X = og[i]
        X_trans = data_[i]
        if X >= 0 and lambda_ == 0:
            X = exp(X_trans) - 1
        elif X >= 0 and lambda_ != 0:
            X = (X_trans * lambda_ + 1) ** (1 / lambda_) - 1
        elif X < 0 and lambda_ != 2:
            X = 1 - (-(2 - lambda_) * X_trans + 1) ** (1 / (2 - lambda_))
        elif X < 0 and lambda_ == 2:
            X = 1 - exp(-X_trans)
        
        values.append(X)
    return(pd.DataFrame(values))


def revert_yeo (og, data_, lambdas):
    reverted = pd.DataFrame()

    for i in range(0,len(data_.columns)):        
        if lambdas.iloc[i].values == 1 :
            revert = data_.iloc[:,i]
        else:
            p#ower = PowerTransformer(method='yeo-johnson')
            #power.lambdas_ = lambdas.iloc[i].values
            #revert = pd.DataFrame(power.inverse_transform([data.iloc[:,i].values]))
            #return inv_boxcox(data, lambdas.values)
            revert = pd.DataFrame(inverse_yeo(og.iloc[:,i].values,data_.iloc[:,i].values, lambdas.iloc[i].values))            
        revert.index = data_.index
        reverted = pd.concat([reverted,revert],axis=1)
        
    reverted.columns = data_.columns
    return reverted

# %%
import numpy as np
m = np.median(np.matrix.flatten(np.array((attributes.iloc[:,1:]))))
mad = stats.median_absolute_deviation(np.matrix.flatten(np.array((attributes.iloc[:,1:]))))
# Out:
# <ipython-input-50-d372311e6a9c>:3: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.
#
#   mad = stats.median_absolute_deviation(np.matrix.flatten(np.array((attributes.iloc[:,1:]))))

# %%
m
# Out:
# 1108.0

# %%
# Out:
#       Strength   Agility  Toughness  Endurance  Recuperation  \
# 0    -1.507685 -0.031174  -1.314974  -0.515787     -0.697163
# 1    -0.155870 -0.705665   0.646151  -0.850198      0.561131
# 2    -0.430767  1.045744   0.748175  -0.614977     -0.036842
# 3     0.668823 -0.331577   0.450605   1.768413     -0.246558
# 4     1.343314 -2.570433   3.086220   0.235222     -0.736839
# ...        ...       ...        ...        ...           ...
# 4995 -1.513353 -0.051012   0.510119  -2.556263     -0.459107
# 4996 -0.393925 -0.260728   0.663155  -0.198380     -1.870437
# 4997  1.762745  0.759511   2.462741  -0.042510     -0.065182
# 4998  0.382589 -0.552629   0.280565  -1.927116     -0.028340
# 4999  2.717801 -0.609309  -0.110526   0.362751      0.841696
#
#       Disease resistance  Analytical Ability  Creativity   Empathy     Focus  \
# 0              -0.688661            2.595939   -0.580969  2.471243  1.210116
# 1              -1.989464            0.938052    1.941286 -0.263562  1.042910
# 2               0.113360            0.708499   -0.150202 -0.906878  0.960724
# 3              -0.433601            0.240890   -0.422265 -0.717001  1.244124
# 4              -0.082186            0.206882    0.444937 -1.714567 -0.583803
# ...                  ...                 ...         ...       ...       ...
# 4995           -0.374087            3.210916    2.570433 -0.600807 -0.201214
# 4996           -0.408095           -1.425499   -0.011336 -1.210116 -0.838862
# 4997           -1.113760            2.902011    0.569633 -0.654653  0.853032
# 4998            0.053846            1.238456    2.068816 -0.512953  1.830761
# 4999           -0.484613            1.065582    0.130364 -2.241690  0.875704
#
#       Intuition  Kinesthetic Sense  Linguistic Ability    Memory  Musicality  \
# 0      0.226720           0.011336           -0.181376  0.552629    1.989464
# 1      0.396759          -0.138866           -0.844530  0.365585   -0.303237
# 2     -0.819024           1.280966           -0.450605  1.079752    1.609709
# 3     -0.643317          -0.368419           -1.448171 -0.660321   -2.539259
# 4     -0.218218           0.490281           -2.553429 -1.371653   -0.334411
# ...         ...                ...                 ...       ...         ...
# 4995  -0.391091           1.674891           -0.646151  0.362751    1.847765
# 4996  -0.714167          -0.082186           -0.229554 -1.037242   -0.385423
# 4997  -0.785017          -0.677325           -1.119428 -0.546961   -0.093522
# 4998   2.326710           0.096356           -2.037642  0.204048   -1.915780
# 4999  -2.564765          -0.660321           -0.844530  0.731171   -0.776515
#
#       Patience  Social Awareness  Spatial Sense  Willpower
# 0    -1.482179          0.127530       0.467609   0.637649
# 1     0.393925         -0.314573       0.408095  -0.745341
# 2     1.453839         -2.224686       1.110926   0.354249
# 3     0.555463         -1.195946       1.289468   0.025506
# 4     0.096356         -0.068016       1.057080   0.427933
# ...        ...               ...            ...        ...
# 4995  3.009702          0.184210       1.082586  -0.580969
# 4996  1.297970         -0.680159       1.431167  -0.320241
# 4997  1.402827         -2.026306       1.640883  -2.151002
# 4998 -0.977728         -0.365585       2.159504   0.184210
# 4999  1.314974         -2.516587       0.904044   0.153036
#
# [5000 rows x 19 columns]

# %%
import statistics
from scipy import stats
#statistics.median(skills.iloc[:,1:])
attributes.iloc[:,1:].apply(statistics.median,axis=0)

median_transformed = (attributes.iloc[:,1:]-m)/mad
#(attributes.iloc[:,1:]-attributes.iloc[:,1:].apply(statistics.median,axis=0))/attributes.iloc[:,1:].apply(stats.median_absolute_deviation,axis=0)

transformed_, lambdas = transform_boxcox(pd.DataFrame(np.matrix.flatten(np.array(median_transformed))))
# Out:
# The null hypothesis can be rejected
# 0.7499028287870247

# %%
new = pd.DataFrame(np.array(transformed_).reshape(len(attributes),len(attributes.columns)-1))
new.columns = attributes.iloc[:,1:].columns
new.index = attributes.iloc[:,0]
new

norm_cdf = scipy.stats.norm.cdf(new) # calculate the cdf - also discrete

# %%
#transformed_.hist()

#print(pd.DataFrame(norm_cdf).mean())
display(pd.DataFrame(new,columns=attributes.iloc[:,1:].columns).describe().loc[pd.DataFrame(new).describe().index[1:]].style.background_gradient(cmap ='viridis'))

display(pd.DataFrame(norm_cdf,columns=attributes.iloc[:,1:].columns).describe().loc[pd.DataFrame(norm_cdf).describe().index[1:]].style.background_gradient(cmap ='viridis'))
# Out:
# <style  type="text/css" >
#     #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col0 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col1 {
#             background-color:  #365d8d;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col2 {
#             background-color:  #31678e;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col3 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col4 {
#             background-color:  #306a8e;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col5 {
#             background-color:  #1f968b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col6 {
#             background-color:  #1f978b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col7 {
#             background-color:  #1f988b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col8 {
#             background-color:  #1f998a;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col9 {
#             background-color:  #1f948c;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col10 {
#             background-color:  #1f988b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col11 {
#             background-color:  #1f9a8a;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col12 {
#             background-color:  #1f998a;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col13 {
#             background-color:  #1f978b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col14 {
#             background-color:  #1f998a;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col15 {
#             background-color:  #1f978b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col16 {
#             background-color:  #1f998a;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col17 {
#             background-color:  #1f958b;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row0_col18 {
#             background-color:  #2f6b8e;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col0 {
#             background-color:  #297b8e;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col1 {
#             background-color:  #218f8d;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col2 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col3 {
#             background-color:  #218f8d;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col4 {
#             background-color:  #20938c;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col5 {
#             background-color:  #81d34d;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col6 {
#             background-color:  #37b878;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col7 {
#             background-color:  #34b679;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col8 {
#             background-color:  #7cd250;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col9 {
#             background-color:  #20928c;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col10 {
#             background-color:  #7cd250;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col11 {
#             background-color:  #7fd34e;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col12 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col13 {
#             background-color:  #37b878;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col14 {
#             background-color:  #7cd250;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col15 {
#             background-color:  #37b878;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col16 {
#             background-color:  #7cd250;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col17 {
#             background-color:  #20928c;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row1_col18 {
#             background-color:  #20928c;
#             color:  #000000;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col8 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col9 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col11 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col12 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col14 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col15 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col16 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col17 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row2_col18 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row3_col0 {
#             background-color:  #3a538b;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row3_col1 {
#             background-color:  #3e4c8a;
#             color:  #f1f1f1;
#         }    #T_988c184a_c025_11eb_aeda_525400b25cf3row3_col2 {
#             background-color:  #39558c;
# <style  type="text/css" >
#     #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col0 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col1 {
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col2 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col3 {
#             background-color:  #287d8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col4 {
#             background-color:  #25848e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col5 {
#             background-color:  #297a8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col6 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col7 {
#             background-color:  #24aa83;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col8 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col9 {
#             background-color:  #58c765;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col10 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col11 {
#             background-color:  #277e8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col12 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col13 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col14 {
#             background-color:  #287d8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col15 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col16 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col17 {
#             background-color:  #5cc863;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row0_col18 {
#             background-color:  #24878e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col0 {
#             background-color:  #39558c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col1 {
#             background-color:  #3c508b;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col2 {
#             background-color:  #3a548c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col3 {
#             background-color:  #355e8d;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col4 {
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col5 {
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col6 {
#             background-color:  #39568c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col7 {
#             background-color:  #3a548c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col8 {
#             background-color:  #38598c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col9 {
#             background-color:  #46337f;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col10 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col11 {
#             background-color:  #375b8d;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col12 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col13 {
#             background-color:  #39568c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col14 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col15 {
#             background-color:  #39568c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col16 {
#             background-color:  #375a8c;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col17 {
#             background-color:  #46327e;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row1_col18 {
#             background-color:  #355f8d;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col8 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col9 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col11 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col12 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col14 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col15 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col16 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col17 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row2_col18 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row3_col0 {
#             background-color:  #277e8e;
#             color:  #000000;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row3_col1 {
#             background-color:  #482475;
#             color:  #f1f1f1;
#         }    #T_98a54478_c025_11eb_aeda_525400b25cf3row3_col2 {
#             background-color:  #27808e;
